# %% [markdown]
# # Import necessary packages

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from random import sample

import re

from sklearn.metrics import mean_absolute_error, mean_squared_error

from timeit import default_timer as timer

# %% [markdown]
# # Import original data and preprocessed data

# %%
INPUT_DIR = r'C:\Users\ASUS\Desktop\Academic Work\Academic Research\DEMAND PATTERN\M5 Forecasting\Estimate the unit sales of Walmart retail goods\m5-forecasting-accuracy_unzip files'
sales_train_val = pd.read_csv(f'{INPUT_DIR}/sales_train_validation.csv')
calendar = pd.read_csv(f'{INPUT_DIR}/calendar.csv')

# %% [markdown]
# ### Note: This Step is for the extraction of California State and Household category

# %%
sales_train_val = sales_train_val[(sales_train_val['state_id'] == 'CA') & (sales_train_val['cat_id'] == 'HOUSEHOLD')]

# %%
INPUT_DIR_2 = r'C:\Users\ASUS\Desktop\Academic Work\Academic Research\DEMAND PATTERN\CRUNCH TIME (WEEKLY AGGREGATION)\California\Household\Demand Pattern Categorization'
list_intermittent = pd.read_csv(f'{INPUT_DIR_2}/Intermittent_ID.csv')
list_lumpy = pd.read_csv(f'{INPUT_DIR_2}/Lumpy_ID.csv')
list_erratic = pd.read_csv(f'{INPUT_DIR_2}/Erratic_ID.csv')
list_smooth = pd.read_csv(f'{INPUT_DIR_2}/Smooth_ID.csv')

list_intermittent = list_intermittent['0'].values.tolist()
list_lumpy = list_lumpy['0'].values.tolist()
list_erratic = list_erratic['0'].values.tolist()
list_smooth = list_smooth['0'].values.tolist()

sales_intermittent = sales_train_val[sales_train_val.id.isin(list_intermittent)]
sales_lumpy = sales_train_val[sales_train_val.id.isin(list_lumpy)]
sales_erratic = sales_train_val[sales_train_val.id.isin(list_erratic)]
sales_smooth = sales_train_val[sales_train_val.id.isin(list_smooth)]

# %% [markdown]
# **Check by looking at column "id" to verify if we choose the right product (FOODS or HOBBIES or HOUSEHOLD)**

# %%
sales_smooth
# Out:
#                                     id          item_id      dept_id  \
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 568    HOUSEHOLD_1_004_CA_1_validation  HOUSEHOLD_1_004  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# 570    HOUSEHOLD_1_006_CA_1_validation  HOUSEHOLD_1_006  HOUSEHOLD_1
# 571    HOUSEHOLD_1_007_CA_1_validation  HOUSEHOLD_1_007  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10742  HOUSEHOLD_2_500_CA_4_validation  HOUSEHOLD_2_500  HOUSEHOLD_2
# 10747  HOUSEHOLD_2_505_CA_4_validation  HOUSEHOLD_2_505  HOUSEHOLD_2
# 10752  HOUSEHOLD_2_510_CA_4_validation  HOUSEHOLD_2_510  HOUSEHOLD_2
# 10753  HOUSEHOLD_2_511_CA_4_validation  HOUSEHOLD_2_511  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 568    HOUSEHOLD     CA_1       CA    4    0    8   11  ...       0       5
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# 570    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       3       4
# 571    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       3
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10742  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       1
# 10747  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10752  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10753  HOUSEHOLD     CA_4       CA    0    0    2    1  ...       1       1
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 567         1       2       1       0       0       0       1       0
# 568         0       0       0       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# 570         2       6       3       2       2       1       3       4
# 571         1       1       1       3       0       5       3       2
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10742       0       1       0       0       1       0       0       1
# 10747       0       0       0       2       0       0       0       0
# 10752       0       2       1       1       0       1       0       0
# 10753       1       0       0       3       1       0       0       1
# 10755       0       0       0       0       0       0       0       0
#
# [2391 rows x 1919 columns]

# %% [markdown]
# # User-defined functions to calculate Metrics and Algorithm

# %%
ROUNDING_DECIMAL = 4

def mase_calculation(ts, prediction):
    divisor = 0
    for i in range(1, ts.shape[0]):
        divisor = divisor + abs(ts.iloc[i] - ts.iloc[i-1])
    divisor = divisor/(ts.shape[0] - 1)
    diff    = abs(ts - prediction[:ts.shape[0]])/divisor
    mase    = diff.mean()
    return mase

def mape_calculation(actual, pred): 
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    mask = (actual != 0)
    return round((np.fabs(actual - pred)/actual)[mask].mean()*100, ROUNDING_DECIMAL)

def wmape_calculation(actual, pred):
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    return round((np.sum(np.absolute(actual-pred))/np.sum(actual))*100, ROUNDING_DECIMAL)

def smape_calculation(actual, predicted):
    if not all([isinstance(actual, np.ndarray), isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, ROUNDING_DECIMAL)

# %%
def Croston_TSB(ts,extra_periods=1,alpha=0.4,beta=0.4):
    d = np.array(ts) # Transform the input into a numpy array
    cols = len(d) # Historical period length
    d = np.append(d,[np.nan]*extra_periods) # Append np.nan into the demand array to cover future periods
    
    #level (a), probability(p) and forecast (f)
    a,p,f = np.full((3,cols+extra_periods),np.nan)
# Initialization
    first_occurence = np.argmax(d[:cols]>0)
    a[0] = d[first_occurence]
    p[0] = 1/(1 + first_occurence)
    f[0] = p[0]*a[0]
                 
    # Create all the t+1 forecasts
    for t in range(0,cols): 
        if d[t] > 0:
            a[t+1] = alpha*d[t] + (1-alpha)*a[t] 
            p[t+1] = beta*(1) + (1-beta)*p[t]  
        else:
            a[t+1] = a[t]
            p[t+1] = (1-beta)*p[t]       
        f[t+1] = p[t+1]*a[t+1]
        
    # Future Forecast
    a[cols+1:cols+extra_periods] = a[cols]
    p[cols+1:cols+extra_periods] = p[cols]
    f[cols+1:cols+extra_periods] = f[cols]
                      
    df = pd.DataFrame.from_dict({"Demand":d,"Forecast":f,"Period":p,"Level":a,"Error":d-f})
    return df

# %% [markdown]
# # Format sales data and then merge with calendar data

# %%
sales_pattern = sales_smooth.copy()

# %%
sales_pattern_py = sales_pattern.copy()

list_pattern_py = sales_pattern_py.id.unique().tolist()
list_pattern_py = [(re.sub(r'_validation', r"", x)) for x in list_pattern_py]

sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
df_pattern.drop('Date', axis=1, inplace=True)
df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
df_pattern.index.names = ['Date']
df_pattern = df_pattern.astype('float64')

df_pattern.iloc[:, 1:].columns = df_pattern.iloc[:, 1:].columns.str.rstrip('_validation')
df_pattern.columns = df_pattern.columns.str.replace(r'_validation', '')
df_pattern.reset_index(inplace=True)

calendar['Date'] = pd.to_datetime(calendar['date'])

dataframe = pd.merge(df_pattern,
                     calendar[['wm_yr_wk', 'Date']],
                     on = 'Date')

not_enough_seven_days = dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})[dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})['Date'] < 7].index.tolist()
dataframe = dataframe[~dataframe['wm_yr_wk'].isin(not_enough_seven_days)]

dataframe.set_index('wm_yr_wk', inplace=True)

dataframe.drop('Date', axis=1, inplace=True)

dataframe_weekly = dataframe.groupby('wm_yr_wk').sum().reset_index()

# %%
start_train_week = 11318
end_train_week = 11610
n_pred_weeks = 2
num_train_needed = 50
validation_training_ratio = 0.95
num_id_sample_for_tuning = 200

# %%
list_params_alpha = [round(item, 2) for item in list(np.arange(0.05, 0.95, 0.05))]
list_params_beta = [round(item, 2) for item in list(np.arange(0.05, 0.95, 0.05))]

# %%
len(list_pattern_py)
# Out:
# 3594

# %%
sample_list = sample(list_pattern_py, num_id_sample_for_tuning)

dataframe_check = dataframe_weekly[sample_list].iloc[-10:-2, :].T
dataframe_check['Check'] = np.where((dataframe_check==0).all(axis=1), 1, 0)

sample_removed = dataframe_check[dataframe_check['Check'] == 1].index.tolist()
sample_list_filtered = [x for x in sample_list if (x not in sample_removed)]

# %%
len(sample_list_filtered)
# Out:
# 150

# %% [markdown]
# # Hyperparameter tuning for Croston TSB

# %%
train_data = dataframe_weekly[(dataframe_weekly['wm_yr_wk'] >= start_train_week) & (dataframe_weekly['wm_yr_wk'] <= end_train_week)]
test_data = dataframe_weekly.iloc[n_pred_weeks*-1:]

train_data_first_part = train_data.iloc[:int(len(train_data)*validation_training_ratio), :]
train_data_second_part = train_data.iloc[int(len(train_data)*validation_training_ratio):, :]

# %%
start = timer()

df_result_all_params = pd.DataFrame()

for product in sample_list_filtered:
    
    print('Currently Running: %s' % product)
    print('Progressing: {0} %'.format(round(sample_list_filtered.index(product) / len(sample_list_filtered) * 100, 2)))

    train_first = train_data_first_part[product]
    train_second = train_data_second_part[product]
    
    for i in list_params_alpha:
        for j in list_params_beta:
            predictions = list()
            history = [x for x in train_first[num_train_needed*-1:]]
            for t in train_second.index.tolist():
                yhat = Croston_TSB(history, extra_periods=1, alpha = i, beta = j)['Forecast'].iloc[-1]
                predictions.append(yhat)
                history.append(train_second[t])
            df_result_temp = pd.DataFrame({'Product': [product for count in range(len(train_second))],
                                           'Actual Data': train_second,
                                           'Forecast': predictions,
                                           'Alpha': [i for count_i in range(len(train_second))],
                                           'Beta': [j for count_j in range(len(train_second))]})
            df_result_all_params = df_result_all_params.append(df_result_temp, ignore_index=True)    
            
end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: FOODS_2_103_CA_1
# Progressing: 0.0 %
# Currently Running: FOODS_1_018_CA_1
# Progressing: 0.67 %
# Currently Running: FOODS_2_342_CA_3
# Progressing: 1.33 %
# Currently Running: FOODS_1_054_CA_3
# Progressing: 2.0 %
# Currently Running: FOODS_3_717_CA_2
# Progressing: 2.67 %
# Currently Running: FOODS_1_218_CA_1
# Progressing: 3.33 %
# Currently Running: FOODS_3_196_CA_1
# Progressing: 4.0 %
# Currently Running: FOODS_3_158_CA_1
# Progressing: 4.67 %
# Currently Running: FOODS_3_586_CA_3
# Progressing: 5.33 %
# Currently Running: FOODS_3_139_CA_4
# Progressing: 6.0 %
# Currently Running: FOODS_3_406_CA_3
# Progressing: 6.67 %
# Currently Running: FOODS_2_332_CA_1
# Progressing: 7.33 %
# Currently Running: FOODS_3_268_CA_1
# Progressing: 8.0 %
# Currently Running: FOODS_1_103_CA_3
# Progressing: 8.67 %
# Currently Running: FOODS_3_204_CA_4
# Progressing: 9.33 %
# Currently Running: FOODS_3_479_CA_1
# Progressing: 10.0 %
# Currently Running: FOODS_3_369_CA_1
# Progressing: 10.67 %
# Currently Running: FOODS_3_536_CA_3
# Progressing: 11.33 %
# Currently Running: FOODS_1_012_CA_2
# Progressing: 12.0 %
# Currently Running: FOODS_3_201_CA_1
# Progressing: 12.67 %
# Currently Running: FOODS_1_144_CA_1
# Progressing: 13.33 %
# Currently Running: FOODS_3_542_CA_4
# Progressing: 14.0 %
# Currently Running: FOODS_3_708_CA_3
# Progressing: 14.67 %
# Currently Running: FOODS_1_086_CA_2
# Progressing: 15.33 %
# Currently Running: FOODS_3_724_CA_3
# Progressing: 16.0 %
# Currently Running: FOODS_1_154_CA_4
# Progressing: 16.67 %
# Currently Running: FOODS_3_234_CA_3
# Progressing: 17.33 %
# Currently Running: FOODS_3_723_CA_3
# Progressing: 18.0 %
# Currently Running: FOODS_2_175_CA_1
# Progressing: 18.67 %
# Currently Running: FOODS_3_641_CA_4
# Progressing: 19.33 %
# Currently Running: FOODS_2_161_CA_4
# Progressing: 20.0 %
# Currently Running: FOODS_3_820_CA_4
# Progressing: 20.67 %
# Currently Running: FOODS_3_550_CA_4
# Progressing: 21.33 %
# Currently Running: FOODS_2_126_CA_3
# Progressing: 22.0 %
# Currently Running: FOODS_3_394_CA_3
# Progressing: 22.67 %
# Currently Running: FOODS_2_018_CA_3
# Progressing: 23.33 %
# Currently Running: FOODS_3_128_CA_3
# Progressing: 24.0 %
# Currently Running: FOODS_3_577_CA_2
# Progressing: 24.67 %
# Currently Running: FOODS_3_734_CA_2
# Progressing: 25.33 %
# Currently Running: FOODS_3_759_CA_2
# Progressing: 26.0 %
# Currently Running: FOODS_1_101_CA_2
# Progressing: 26.67 %
# Currently Running: FOODS_1_175_CA_1
# Progressing: 27.33 %
# Currently Running: FOODS_3_115_CA_1
# Progressing: 28.0 %
# Currently Running: FOODS_2_199_CA_4
# Progressing: 28.67 %
# Currently Running: FOODS_2_034_CA_1
# Progressing: 29.33 %
# Currently Running: FOODS_2_232_CA_4
# Progressing: 30.0 %
# Currently Running: FOODS_3_090_CA_3
# Progressing: 30.67 %
# Currently Running: FOODS_3_624_CA_4
# Progressing: 31.33 %
# Currently Running: FOODS_3_775_CA_4
# Progressing: 32.0 %
# Currently Running: FOODS_3_542_CA_1
# Progressing: 32.67 %
# Currently Running: FOODS_3_349_CA_3
# Progressing: 33.33 %
# Currently Running: FOODS_3_346_CA_4
# Progressing: 34.0 %
# Currently Running: FOODS_3_437_CA_1
# Progressing: 34.67 %
# Currently Running: FOODS_2_093_CA_4
# Progressing: 35.33 %
# Currently Running: FOODS_3_561_CA_1
# Progressing: 36.0 %
# Currently Running: FOODS_2_105_CA_1
# Progressing: 36.67 %
# Currently Running: FOODS_2_196_CA_4
# Progressing: 37.33 %
# Currently Running: FOODS_2_112_CA_3
# Progressing: 38.0 %
# Currently Running: FOODS_3_652_CA_3
# Progressing: 38.67 %
# Currently Running: FOODS_2_217_CA_3
# Progressing: 39.33 %
# Currently Running: FOODS_1_086_CA_1
# Progressing: 40.0 %
# Currently Running: FOODS_2_183_CA_1
# Progressing: 40.67 %
# Currently Running: FOODS_3_230_CA_4
# Progressing: 41.33 %
# Currently Running: FOODS_1_185_CA_3
# Progressing: 42.0 %
# Currently Running: FOODS_3_615_CA_4
# Progressing: 42.67 %
# Currently Running: FOODS_2_359_CA_1
# Progressing: 43.33 %
# Currently Running: FOODS_3_502_CA_3
# Progressing: 44.0 %
# Currently Running: FOODS_3_301_CA_2
# Progressing: 44.67 %
# Currently Running: FOODS_3_424_CA_2
# Progressing: 45.33 %
# Currently Running: FOODS_2_347_CA_3
# Progressing: 46.0 %
# Currently Running: FOODS_3_086_CA_4
# Progressing: 46.67 %
# Currently Running: FOODS_3_456_CA_2
# Progressing: 47.33 %
# Currently Running: FOODS_2_143_CA_3
# Progressing: 48.0 %
# Currently Running: FOODS_2_396_CA_4
# Progressing: 48.67 %
# Currently Running: FOODS_3_801_CA_2
# Progressing: 49.33 %
# Currently Running: FOODS_2_349_CA_3
# Progressing: 50.0 %
# Currently Running: FOODS_1_153_CA_2
# Progressing: 50.67 %
# Currently Running: FOODS_3_581_CA_2
# Progressing: 51.33 %
# Currently Running: FOODS_3_054_CA_2
# Progressing: 52.0 %
# Currently Running: FOODS_3_031_CA_1
# Progressing: 52.67 %
# Currently Running: FOODS_3_310_CA_3
# Progressing: 53.33 %
# Currently Running: FOODS_1_063_CA_2
# Progressing: 54.0 %
# Currently Running: FOODS_3_566_CA_2
# Progressing: 54.67 %
# Currently Running: FOODS_2_234_CA_3
# Progressing: 55.33 %
# Currently Running: FOODS_3_141_CA_4
# Progressing: 56.0 %
# Currently Running: FOODS_3_428_CA_2
# Progressing: 56.67 %
# Currently Running: FOODS_2_144_CA_3
# Progressing: 57.33 %
# Currently Running: FOODS_3_179_CA_4
# Progressing: 58.0 %
# Currently Running: FOODS_2_356_CA_1
# Progressing: 58.67 %
# Currently Running: FOODS_1_052_CA_3
# Progressing: 59.33 %
# Currently Running: FOODS_3_519_CA_2
# Progressing: 60.0 %
# Currently Running: FOODS_3_638_CA_1
# Progressing: 60.67 %
# Currently Running: FOODS_3_363_CA_1
# Progressing: 61.33 %
# Currently Running: FOODS_1_026_CA_2
# Progressing: 62.0 %
# Currently Running: FOODS_2_041_CA_3
# Progressing: 62.67 %
# Currently Running: FOODS_1_073_CA_4
# Progressing: 63.33 %
# Currently Running: FOODS_3_328_CA_3
# Progressing: 64.0 %
# Currently Running: FOODS_3_133_CA_2
# Progressing: 64.67 %
# Currently Running: FOODS_2_142_CA_3
# Progressing: 65.33 %
# Currently Running: FOODS_3_023_CA_4
# Progressing: 66.0 %
# Currently Running: FOODS_3_410_CA_4
# Progressing: 66.67 %
# Currently Running: FOODS_1_047_CA_2
# Progressing: 67.33 %
# Currently Running: FOODS_3_283_CA_3
# Progressing: 68.0 %
# Currently Running: FOODS_1_186_CA_3
# Progressing: 68.67 %
# Currently Running: FOODS_3_234_CA_4
# Progressing: 69.33 %
# Currently Running: FOODS_3_765_CA_4
# Progressing: 70.0 %
# Currently Running: FOODS_2_079_CA_1
# Progressing: 70.67 %
# Currently Running: FOODS_2_175_CA_3
# Progressing: 71.33 %
# Currently Running: FOODS_3_794_CA_2
# Progressing: 72.0 %
# Currently Running: FOODS_3_826_CA_4
# Progressing: 72.67 %
# Currently Running: FOODS_2_267_CA_3
# Progressing: 73.33 %
# Currently Running: FOODS_1_129_CA_3
# Progressing: 74.0 %
# Currently Running: FOODS_3_089_CA_2
# Progressing: 74.67 %
# Currently Running: FOODS_3_677_CA_2
# Progressing: 75.33 %
# Currently Running: FOODS_3_242_CA_4
# Progressing: 76.0 %
# Currently Running: FOODS_2_228_CA_1
# Progressing: 76.67 %
# Currently Running: FOODS_3_412_CA_3
# Progressing: 77.33 %
# Currently Running: FOODS_3_734_CA_1
# Progressing: 78.0 %
# Currently Running: FOODS_3_026_CA_3
# Progressing: 78.67 %
# Currently Running: FOODS_3_503_CA_4
# Progressing: 79.33 %
# Currently Running: FOODS_1_152_CA_3
# Progressing: 80.0 %
# Currently Running: FOODS_2_233_CA_3
# Progressing: 80.67 %
# Currently Running: FOODS_3_502_CA_1
# Progressing: 81.33 %
# Currently Running: FOODS_3_612_CA_2
# Progressing: 82.0 %
# Currently Running: FOODS_3_786_CA_1
# Progressing: 82.67 %
# Currently Running: FOODS_3_398_CA_3
# Progressing: 83.33 %
# Currently Running: FOODS_3_751_CA_1
# Progressing: 84.0 %
# Currently Running: FOODS_1_140_CA_1
# Progressing: 84.67 %
# Currently Running: FOODS_3_731_CA_1
# Progressing: 85.33 %
# Currently Running: FOODS_3_392_CA_1
# Progressing: 86.0 %
# Currently Running: FOODS_2_049_CA_3
# Progressing: 86.67 %
# Currently Running: FOODS_3_203_CA_4
# Progressing: 87.33 %
# Currently Running: FOODS_3_817_CA_3
# Progressing: 88.0 %
# Currently Running: FOODS_2_075_CA_3
# Progressing: 88.67 %
# Currently Running: FOODS_3_106_CA_1
# Progressing: 89.33 %
# Currently Running: FOODS_2_176_CA_3
# Progressing: 90.0 %
# Currently Running: FOODS_3_513_CA_3
# Progressing: 90.67 %
# Currently Running: FOODS_3_504_CA_3
# Progressing: 91.33 %
# Currently Running: FOODS_3_332_CA_4
# Progressing: 92.0 %
# Currently Running: FOODS_3_551_CA_3
# Progressing: 92.67 %
# Currently Running: FOODS_1_016_CA_3
# Progressing: 93.33 %
# Currently Running: FOODS_3_622_CA_4
# Progressing: 94.0 %
# Currently Running: FOODS_3_559_CA_4
# Progressing: 94.67 %
# Currently Running: FOODS_3_460_CA_3
# Progressing: 95.33 %
# Currently Running: FOODS_1_062_CA_1
# Progressing: 96.0 %
# Currently Running: FOODS_3_354_CA_4
# Progressing: 96.67 %
# Currently Running: FOODS_3_708_CA_4
# Progressing: 97.33 %
# Currently Running: FOODS_3_405_CA_2
# Progressing: 98.0 %
# Currently Running: FOODS_3_746_CA_2
# Progressing: 98.67 %
# Currently Running: FOODS_1_215_CA_1
# Progressing: 99.33 %
# This line of code took 6.200140411666667 minutes

# %%
df_result_all_params
# Out:
#                  Product  Actual Data   Forecast  Alpha  Beta
# 0       FOODS_2_103_CA_1          1.0   6.256245   0.05  0.05
# 1       FOODS_2_103_CA_1          0.0   5.999970   0.05  0.05
# 2       FOODS_2_103_CA_1          0.0   5.699971   0.05  0.05
# 3       FOODS_2_103_CA_1          0.0   5.414973   0.05  0.05
# 4       FOODS_2_103_CA_1          4.0   5.144224   0.05  0.05
# ...                  ...          ...        ...    ...   ...
# 388795  FOODS_1_215_CA_1         23.0  27.218601   0.90  0.90
# 388796  FOODS_1_215_CA_1         14.0  23.421860   0.90  0.90
# 388797  FOODS_1_215_CA_1         12.0  14.942186   0.90  0.90
# 388798  FOODS_1_215_CA_1         12.0  12.294219   0.90  0.90
# 388799  FOODS_1_215_CA_1         16.0  12.029422   0.90  0.90
#
# [388800 rows x 5 columns]

# %% [markdown]
# # Summay all metrics

# %%
def get_metrics_result_all_params(data):
    metrics_df = {}
    metrics_df['MASE'] = mase_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['WMAPE'] = wmape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['SMAPE'] = smape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAPE'] = mape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAE'] = mean_absolute_error(data['Actual Data'], data['Forecast'])
    metrics_df['RMSE'] = np.sqrt(mean_squared_error(data['Actual Data'], data['Forecast']))
    return pd.Series(metrics_df)

# %%
start = timer()

df_result_metrics_all_params = df_result_all_params.groupby(['Product', 'Alpha', 'Beta']).apply(get_metrics_result_all_params).reset_index()

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 1.2792296583333334 minutes

# %%
df_result_metrics_all_params
# Out:
#                 Product  Alpha  Beta      MASE    WMAPE    SMAPE     MAPE  \
# 0      FOODS_1_012_CA_2   0.05  0.05  0.700890  17.2510  17.6080  16.0510
# 1      FOODS_1_012_CA_2   0.05  0.10  0.700890  17.2510  17.6080  16.0510
# 2      FOODS_1_012_CA_2   0.05  0.15  0.700890  17.2510  17.6080  16.0510
# 3      FOODS_1_012_CA_2   0.05  0.20  0.700890  17.2510  17.6080  16.0510
# 4      FOODS_1_012_CA_2   0.05  0.25  0.700890  17.2510  17.6080  16.0510
# ...                 ...    ...   ...       ...      ...      ...      ...
# 48595  FOODS_3_826_CA_4   0.90  0.70  0.974352  53.2565  58.1387  60.2219
# 48596  FOODS_3_826_CA_4   0.90  0.75  0.974352  53.2565  58.1387  60.2219
# 48597  FOODS_3_826_CA_4   0.90  0.80  0.974352  53.2565  58.1387  60.2219
# 48598  FOODS_3_826_CA_4   0.90  0.85  0.974352  53.2565  58.1387  60.2219
# 48599  FOODS_3_826_CA_4   0.90  0.90  0.974352  53.2565  58.1387  60.2219
#
#              MAE       RMSE
# 0      15.719953  19.931454
# 1      15.719953  19.931454
# 2      15.719953  19.931454
# 3      15.719953  19.931454
# 4      15.719953  19.931454
# ...          ...        ...
# 48595   6.124499   6.525090
# 48596   6.124499   6.525090
# 48597   6.124499   6.525090
# 48598   6.124499   6.525090
# 48599   6.124499   6.525090
#
# [48600 rows x 9 columns]

# %% [markdown]
# # Check what products has unexpected metrics result

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MASE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %%
df_result_metrics_all_params[df_result_metrics_all_params['WMAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %%
df_result_metrics_all_params[df_result_metrics_all_params['SMAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
#                 Product  Alpha  Beta      MASE    WMAPE  SMAPE     MAPE  \
# 33048  FOODS_3_437_CA_1   0.05  0.05  1.281158  94.1259    NaN  93.4310
# 33049  FOODS_3_437_CA_1   0.05  0.10  1.212829  89.1058    NaN  87.6608
# 33050  FOODS_3_437_CA_1   0.05  0.15  1.153192  84.7243    NaN  82.4534
# 33051  FOODS_3_437_CA_1   0.05  0.20  1.101675  80.9394    NaN  77.8001
# 33052  FOODS_3_437_CA_1   0.05  0.25  1.057313  77.6801    NaN  73.6490
# ...                 ...    ...   ...       ...      ...    ...      ...
# 42439  FOODS_3_677_CA_2   0.90  0.70  0.940625  86.0000    NaN  91.2500
# 42440  FOODS_3_677_CA_2   0.90  0.75  0.929688  85.0000    NaN  90.6250
# 42441  FOODS_3_677_CA_2   0.90  0.80  0.918750  84.0000    NaN  90.0000
# 42442  FOODS_3_677_CA_2   0.90  0.85  0.907813  83.0000    NaN  89.3750
# 42443  FOODS_3_677_CA_2   0.90  0.90  0.896875  82.0000    NaN  88.7500
#
#             MAE      RMSE
# 33048  4.941608  6.324751
# 33049  4.678057  6.005847
# 33050  4.448026  5.735132
# 33051  4.249320  5.507450
# 33052  4.078208  5.316485
# ...         ...       ...
# 42439  0.537500  1.219119
# 42440  0.531250  1.202212
# 42441  0.525000  1.185327
# 42442  0.518750  1.168466
# 42443  0.512500  1.151629
#
# [1296 rows x 9 columns]

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %%
df_result_metrics_all_params[df_result_metrics_all_params['RMSE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MAE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %% [markdown]
# # Metrics Statistics

# %%
list_metrics = ['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE']

# %%
for mts in list_metrics:
    print('Percentage of unexpected values of', mts, 'is: {}'.format(df_result_metrics_all_params[df_result_metrics_all_params[mts].isin([np.nan, np.inf, -np.inf])].Product.nunique() / df_result_metrics_all_params.Product.nunique() * 100), "%")
# Out:
# Percentage of unexpected values of MASE is: 0.0 %
# Percentage of unexpected values of WMAPE is: 0.0 %
# Percentage of unexpected values of SMAPE is: 2.666666666666667 %
# Percentage of unexpected values of MAPE is: 0.0 %
# Percentage of unexpected values of MAE is: 0.0 %
# Percentage of unexpected values of RMSE is: 0.0 %

# %% [markdown]
# ### Filter all rows that have unexpected metrics values

# %%
df_result_metrics_all_params = df_result_metrics_all_params[~df_result_metrics_all_params.isin([np.nan, np.inf, -np.inf]).any(1)]

# %% [markdown]
# # Get MEAN metrics value of each Alpha and Beta

# %%
df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].mean()
# Out:
#                 MASE      WMAPE      SMAPE       MAPE        MAE       RMSE
# Alpha Beta
# 0.05  0.05  1.207945  63.310895  57.871558  71.295734  13.916993  16.804076
#       0.10  1.157842  60.025216  55.649342  69.835125  13.704021  16.600018
#       0.15  1.127600  57.680301  54.886986  69.359690  13.605743  16.509325
#       0.20  1.109660  56.212870  54.651904  69.286519  13.552504  16.453783
#       0.25  1.095667  55.118027  54.484082  69.139317  13.511341  16.414756
# ...              ...        ...        ...        ...        ...        ...
# 0.90  0.70  0.978923  50.126096  56.259964  60.678815  12.894023  15.112939
#       0.75  0.979046  50.163874  56.384338  60.751512  12.897516  15.114168
#       0.80  0.979519  50.212692  56.549365  60.856886  12.901881  15.116173
#       0.85  0.980232  50.273257  56.769673  60.997297  12.906901  15.118870
#       0.90  0.980870  50.327187  57.000198  61.117366  12.911523  15.122189
#
# [324 rows x 6 columns]

# %%
for mts in list_metrics:
    print('The optimum Alpha and Beta based on Mean', mts, 'is: {}'.format(df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].mean()[mts].idxmin()))
# Out:
# The optimum Alpha and Beta based on Mean MASE is: (0.35, 0.9)
# The optimum Alpha and Beta based on Mean WMAPE is: (0.35, 0.9)
# The optimum Alpha and Beta based on Mean SMAPE is: (0.25, 0.5)
# The optimum Alpha and Beta based on Mean MAPE is: (0.5, 0.1)
# The optimum Alpha and Beta based on Mean MAE is: (0.45, 0.65)
# The optimum Alpha and Beta based on Mean RMSE is: (0.6, 0.7)

# %% [markdown]
# # Get MEDIAN metrics value of each Alpha and Beta

# %%
df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].median()
# Out:
#                 MASE     WMAPE     SMAPE      MAPE       MAE      RMSE
# Alpha Beta
# 0.05  0.05  0.923186  44.63535  47.85750  50.48805  4.632454  5.268129
#       0.10  0.906273  43.82610  45.57965  48.81245  4.353024  5.244178
#       0.15  0.896091  42.90965  44.96800  48.06485  4.084203  5.244178
#       0.20  0.896614  42.25060  44.96760  49.77365  4.074035  5.248945
#       0.25  0.894901  42.07625  44.68210  49.78520  4.077261  5.238303
# ...              ...       ...       ...       ...       ...       ...
# 0.90  0.70  0.957075  45.87095  47.16290  48.89475  4.424632  5.417955
#       0.75  0.958330  45.92845  47.16290  49.42620  4.424639  5.443530
#       0.80  0.959624  45.97540  47.16290  49.50360  4.424641  5.464206
#       0.85  0.964099  45.68340  47.16290  49.85895  4.424641  5.464207
#       0.90  0.964502  45.29080  47.16290  50.31920  4.424641  5.464207
#
# [324 rows x 6 columns]

# %%
for mts in list_metrics:
    print('The optimum Alpha and Beta based on Median of', mts, 'is: {}'.format(df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].median()[mts].idxmin()))
# Out:
# The optimum Alpha and Beta based on Median of MASE is: (0.15, 0.85)
# The optimum Alpha and Beta based on Median of WMAPE is: (0.25, 0.65)
# The optimum Alpha and Beta based on Median of SMAPE is: (0.25, 0.55)
# The optimum Alpha and Beta based on Median of MAPE is: (0.15, 0.55)
# The optimum Alpha and Beta based on Median of MAE is: (0.1, 0.85)
# The optimum Alpha and Beta based on Median of RMSE is: (0.35, 0.75)

# %% [markdown]
# # Run Croston TSB model after decide best paramaters

# %%
best_alpha = 0.5
best_beta = 0.1

# %%
start = timer()

df_result_best_params = pd.DataFrame()
for product in list_pattern_py:
    train_product = train_data[product]
    test_product = test_data[product]
    predictions = list()
    history = [x for x in train_product[num_train_needed*-1:]]
    for t in test_product.index.tolist():
        yhat = Croston_TSB(history, extra_periods=1, alpha=best_alpha, beta = best_beta)['Forecast'].iloc[-1]
        predictions.append(yhat)
        history.append(test_product[t])
    df_result_temp = pd.DataFrame({'Product': [product for count in range(len(test_product))],
                                    'Actual Data': test_product,
                                    'Forecast': predictions})
    df_result_best_params = df_result_best_params.append(df_result_temp, ignore_index=True)
    
end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 0.07224832000000005 minutes

# %%
df_result_best_params
# Out:
#                    Product  Actual Data   Forecast
# 0     HOUSEHOLD_1_003_CA_1          4.0   5.164894
# 1     HOUSEHOLD_1_003_CA_1          2.0   4.474127
# 2     HOUSEHOLD_1_004_CA_1          7.0  10.986495
# 3     HOUSEHOLD_1_004_CA_1          9.0   8.983176
# 4     HOUSEHOLD_1_005_CA_1          9.0   7.968012
# ...                    ...          ...        ...
# 4777  HOUSEHOLD_2_510_CA_4          1.0   3.090064
# 4778  HOUSEHOLD_2_511_CA_4          6.0   4.159007
# 4779  HOUSEHOLD_2_511_CA_4          3.0   4.843692
# 4780  HOUSEHOLD_2_513_CA_4          0.0   2.319665
# 4781  HOUSEHOLD_2_513_CA_4          0.0   2.087699
#
# [4782 rows x 3 columns]

# %%
df_result_final = df_result_best_params.groupby('Product').apply(get_metrics_result_all_params).reset_index()

# %%
df_result_final
# Out:
#                    Product      MASE     WMAPE     SMAPE      MAPE        MAE  \
# 0     HOUSEHOLD_1_001_CA_3  1.072371   42.8948   36.9559   47.2519   2.144742
# 1     HOUSEHOLD_1_002_CA_3  0.664653   56.9703   51.6285   89.5380   1.993960
# 2     HOUSEHOLD_1_002_CA_4  0.608901  121.7802  132.5451   49.1080   2.435605
# 3     HOUSEHOLD_1_003_CA_1  0.909755   60.6504   50.9260   76.4144   1.819511
# 4     HOUSEHOLD_1_003_CA_2       inf  138.0489   79.2906  138.0489   4.141466
# ...                    ...       ...       ...       ...       ...        ...
# 2386  HOUSEHOLD_2_512_CA_2  1.169161   19.4860   21.3432   19.2349   2.338322
# 2387  HOUSEHOLD_2_512_CA_3  0.551924   60.2099   66.2117   56.5525   6.623090
# 2388  HOUSEHOLD_2_513_CA_3  0.560196   69.6460   79.1836   65.4091  12.884518
# 2389  HOUSEHOLD_2_513_CA_4       inf       inf  200.0000       NaN   2.203682
# 2390  HOUSEHOLD_2_514_CA_1  0.531200  106.2400  128.0736   43.8398   0.531200
#
#            RMSE
# 0      2.231659
# 1      2.389431
# 2      2.480782
# 3      1.933686
# 4      4.379777
# ...         ...
# 2386   2.403028
# 2387   7.805655
# 2388  15.593323
# 2389   2.206732
# 2390   0.539246
#
# [2391 rows x 7 columns]

# %%
df_result_final.isnull().sum()
# Out:
# Product      0
# MASE       414
# WMAPE      414
# SMAPE      418
# MAPE       485
# MAE          0
# RMSE         0
# dtype: int64

# %%
df_result_final.MAPE.mean()
# Out:
# 58.16354233997902

# %%
df_result_final.to_csv('Croston_TSB_Smooth_Metrics.csv')
