# %% [markdown]
# # Import necessary packages

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error

from timeit import default_timer as timer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import original data and preprocessed data

# %%
sales_train_val = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sales_train_validation.csv')

# %%
sales_train_val = sales_train_val[(sales_train_val['state_id'] == 'CA') & (sales_train_val['cat_id'] == 'HOUSEHOLD')]

# %%
INPUT_DIR_2 = '/content/drive/MyDrive/Colab Notebooks/List of Product ID according to 4 demand patterns/California/Household/2-year'
list_intermittent = pd.read_csv(f'{INPUT_DIR_2}/Intermittent_ID_2_Year_Data.csv')
list_lumpy = pd.read_csv(f'{INPUT_DIR_2}/Lumpy_ID_2_Year_Data.csv')
list_erratic = pd.read_csv(f'{INPUT_DIR_2}/Erratic_ID_2_Year_Data.csv')
list_smooth = pd.read_csv(f'{INPUT_DIR_2}/Smooth_ID_2_Year_Data.csv')

list_intermittent = list_intermittent['0'].values.tolist()
list_lumpy = list_lumpy['0'].values.tolist()
list_erratic = list_erratic['0'].values.tolist()
list_smooth = list_smooth['0'].values.tolist()

sales_intermittent = sales_train_val[sales_train_val.id.isin(list_intermittent)]
sales_lumpy = sales_train_val[sales_train_val.id.isin(list_lumpy)]
sales_erratic = sales_train_val[sales_train_val.id.isin(list_erratic)]
sales_smooth = sales_train_val[sales_train_val.id.isin(list_smooth)]

# %%
sales_intermittent
# Out:
#                                     id          item_id      dept_id  \
# 565    HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 566    HOUSEHOLD_1_002_CA_1_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# 570    HOUSEHOLD_1_006_CA_1_validation  HOUSEHOLD_1_006  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
# 10756  HOUSEHOLD_2_514_CA_4_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
# 10757  HOUSEHOLD_2_515_CA_4_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 10758  HOUSEHOLD_2_516_CA_4_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565    HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 566    HOUSEHOLD     CA_1       CA    1    1    2    4  ...       0       0
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# 570    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       3       4
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
# 10756  HOUSEHOLD     CA_4       CA    0    2    0    1  ...       0       0
# 10757  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10758  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565         1       1       1       0       0       0       0       1
# 566         0       0       0       1       0       0       0       1
# 567         1       2       1       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# 570         2       6       3       2       2       1       3       4
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10754       0       0       2       1       0       0       0       0
# 10755       0       0       0       0       0       0       0       0
# 10756       1       0       0       0       0       0       0       0
# 10757       0       0       0       0       0       0       2       0
# 10758       0       0       0       0       0       0       0       1
#
# [3490 rows x 1919 columns]

# %% [markdown]
# # User-defined functions to calculate Metrics and Croston_TSB algorithm

# %%
ROUNDING_DECIMAL = 4

def mase_calculation(ts, prediction):
    divisor = 0
    for i in range(1, ts.shape[0]):
        divisor = divisor + abs(ts.iloc[i] - ts.iloc[i-1])
    divisor = divisor/(ts.shape[0] - 1)
    diff    = abs(ts - prediction[:ts.shape[0]])/divisor
    mase    = diff.mean()
    return mase

def mape_calculation(actual, pred): 
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    mask = (actual != 0)
    return round((np.fabs(actual - pred)/actual)[mask].mean()*100, ROUNDING_DECIMAL)

def wmape_calculation(actual, pred):
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    return round((np.sum(np.absolute(actual-pred))/np.sum(actual))*100, ROUNDING_DECIMAL)

def smape_calculation(actual, predicted):
    if not all([isinstance(actual, np.ndarray), isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, ROUNDING_DECIMAL)

# %%
def Croston_TSB(ts,extra_periods=1,alpha=0.4,beta=0.4):
    d = np.array(ts) # Transform the input into a numpy array
    cols = len(d) # Historical period length
    d = np.append(d,[np.nan]*extra_periods) # Append np.nan into the demand array to cover future periods
    
    #level (a), probability(p) and forecast (f)
    a,p,f = np.full((3,cols+extra_periods),np.nan)
# Initialization
    first_occurence = np.argmax(d[:cols]>0)
    a[0] = d[first_occurence]
    p[0] = 1/(1 + first_occurence)
    f[0] = p[0]*a[0]
                 
    # Create all the t+1 forecasts
    for t in range(0,cols): 
        if d[t] > 0:
            a[t+1] = alpha*d[t] + (1-alpha)*a[t] 
            p[t+1] = beta*(1) + (1-beta)*p[t]  
        else:
            a[t+1] = a[t]
            p[t+1] = (1-beta)*p[t]       
        f[t+1] = p[t+1]*a[t+1]
        
    # Future Forecast
    a[cols+1:cols+extra_periods] = a[cols]
    p[cols+1:cols+extra_periods] = p[cols]
    f[cols+1:cols+extra_periods] = f[cols]
                      
    df = pd.DataFrame.from_dict({"Demand":d,"Forecast":f,"Period":p,"Level":a,"Error":d-f})
    return df

# %% [markdown]
# # Set value for parameters

# %%
list_params_alpha = [round(item, 1) for item in list(np.arange(0.1, 1, 0.1))]
list_params_beta = [round(item, 1) for item in list(np.arange(0.1, 1, 0.1))]

# %%
start_train_date = '2014-04-11'
end_train_date = '2016-04-10'
n_pred_days = 14
num_train_needed = 100
validation_training_ratio = 0.95

# %% [markdown]
# # Pipeline for Croston_TSB

# %%
def CrostonTSB_output_all_params(sales_pattern, list_params_alpha, list_params_beta, 
                                 start_train_date, end_train_date, n_pred_days, 
                                 num_train_needed, validation_training_ratio):
    
    sales_pattern_py = sales_pattern.copy()
    list_pattern_py = sales_pattern_py.id.unique().tolist()
    
    sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
    df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
    df_pattern.drop('Date', axis=1, inplace=True)
    df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
    df_pattern.index.names = ['Date']
    df_pattern = df_pattern.astype('float64')
    
    train_data = df_pattern[(df_pattern.index >= start_train_date) & (df_pattern.index <= end_train_date)]
    test_data = df_pattern.iloc[n_pred_days*-1:]
    train_data_first_part = train_data.iloc[:int(len(train_data)*validation_training_ratio), :]
    train_data_second_part = train_data.iloc[int(len(train_data)*validation_training_ratio):, :]
    
    df_result_all_params = pd.DataFrame()
    for product in list_pattern_py:
        train_first = train_data_first_part[product]
        train_second = train_data_second_part[product]
        for i in list_params_alpha:
            for j in list_params_beta:
                predictions = list()
                history = [x for x in train_first[num_train_needed*-1:]]
                for t in range(len(train_second)):
                    yhat = Croston_TSB(history, extra_periods=1, alpha = i, beta = j)['Forecast'].iloc[-1]
                    predictions.append(yhat)
                    history.append(train_second[t])
                df_result_temp = pd.DataFrame({'Product': [product for count in range(len(train_second))],
                                               'Actual Data': train_second,
                                               'Forecast': predictions,
                                               'Alpha': [i for count_i in range(len(train_second))],
                                               'Beta': [j for count_j in range(len(train_second))]})
                df_result_all_params = df_result_all_params.append(df_result_temp, ignore_index=True)
            
    return df_result_all_params

# %%
sales_intermittent
# Out:
#                                     id          item_id      dept_id  \
# 565    HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 566    HOUSEHOLD_1_002_CA_1_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# 570    HOUSEHOLD_1_006_CA_1_validation  HOUSEHOLD_1_006  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
# 10756  HOUSEHOLD_2_514_CA_4_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
# 10757  HOUSEHOLD_2_515_CA_4_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 10758  HOUSEHOLD_2_516_CA_4_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565    HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 566    HOUSEHOLD     CA_1       CA    1    1    2    4  ...       0       0
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# 570    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       3       4
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
# 10756  HOUSEHOLD     CA_4       CA    0    2    0    1  ...       0       0
# 10757  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10758  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565         1       1       1       0       0       0       0       1
# 566         0       0       0       1       0       0       0       1
# 567         1       2       1       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# 570         2       6       3       2       2       1       3       4
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10754       0       0       2       1       0       0       0       0
# 10755       0       0       0       0       0       0       0       0
# 10756       1       0       0       0       0       0       0       0
# 10757       0       0       0       0       0       0       2       0
# 10758       0       0       0       0       0       0       0       1
#
# [3490 rows x 1919 columns]

# %%
sales_intermittent.iloc[:500]
# Out:
#                                    id          item_id      dept_id  \
# 565   HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 566   HOUSEHOLD_1_002_CA_1_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 567   HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 569   HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# 570   HOUSEHOLD_1_006_CA_1_validation  HOUSEHOLD_1_006  HOUSEHOLD_1
# ...                               ...              ...          ...
# 1203  HOUSEHOLD_2_107_CA_1_validation  HOUSEHOLD_2_107  HOUSEHOLD_2
# 1204  HOUSEHOLD_2_108_CA_1_validation  HOUSEHOLD_2_108  HOUSEHOLD_2
# 1205  HOUSEHOLD_2_109_CA_1_validation  HOUSEHOLD_2_109  HOUSEHOLD_2
# 1206  HOUSEHOLD_2_110_CA_1_validation  HOUSEHOLD_2_110  HOUSEHOLD_2
# 1208  HOUSEHOLD_2_112_CA_1_validation  HOUSEHOLD_2_112  HOUSEHOLD_2
#
#          cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565   HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 566   HOUSEHOLD     CA_1       CA    1    1    2    4  ...       0       0
# 567   HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 569   HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# 570   HOUSEHOLD     CA_1       CA    0    0    0    0  ...       3       4
# ...         ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 1203  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 1204  HOUSEHOLD     CA_1       CA    2    3    2    2  ...       0       0
# 1205  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 1206  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       2       2
# 1208  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       1       0
#
#       d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565        1       1       1       0       0       0       0       1
# 566        0       0       0       1       0       0       0       1
# 567        1       2       1       0       0       0       1       0
# 569        3       1       2       0       0       1       0       1
# 570        2       6       3       2       2       1       3       4
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 1203       0       0       1       1       1       0       0       0
# 1204       0       0       0       0       0       0       0       0
# 1205       2       1       0       1       0       3       0       3
# 1206       6       3       2       0       2       1       7       4
# 1208       0       0       0       0       0       0       1       0
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[500:1000]
# Out:
#                                    id          item_id      dept_id  \
# 1209  HOUSEHOLD_2_113_CA_1_validation  HOUSEHOLD_2_113  HOUSEHOLD_2
# 1210  HOUSEHOLD_2_114_CA_1_validation  HOUSEHOLD_2_114  HOUSEHOLD_2
# 1212  HOUSEHOLD_2_116_CA_1_validation  HOUSEHOLD_2_116  HOUSEHOLD_2
# 1213  HOUSEHOLD_2_117_CA_1_validation  HOUSEHOLD_2_117  HOUSEHOLD_2
# 1214  HOUSEHOLD_2_118_CA_1_validation  HOUSEHOLD_2_118  HOUSEHOLD_2
# ...                               ...              ...          ...
# 3753  HOUSEHOLD_1_144_CA_2_validation  HOUSEHOLD_1_144  HOUSEHOLD_1
# 3754  HOUSEHOLD_1_145_CA_2_validation  HOUSEHOLD_1_145  HOUSEHOLD_1
# 3755  HOUSEHOLD_1_146_CA_2_validation  HOUSEHOLD_1_146  HOUSEHOLD_1
# 3757  HOUSEHOLD_1_148_CA_2_validation  HOUSEHOLD_1_148  HOUSEHOLD_1
# 3759  HOUSEHOLD_1_150_CA_2_validation  HOUSEHOLD_1_150  HOUSEHOLD_1
#
#          cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 1209  HOUSEHOLD     CA_1       CA    0    0    1    0  ...       0       0
# 1210  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 1212  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 1213  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 1214  HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# ...         ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 3753  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       2
# 3754  HOUSEHOLD     CA_2       CA    6    5    3    2  ...       1       1
# 3755  HOUSEHOLD     CA_2       CA    2    2    2    1  ...       2       1
# 3757  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 3759  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       1
#
#       d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 1209       0       1       1       0       0       0       1       2
# 1210       0       0       0       1       1       1       1       1
# 1212       0       0       0       0       0       0       0       0
# 1213       0       0       0       0       0       0       0       0
# 1214       0       0       1       1       0       0       0       2
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 3753       0       1       0       0       0       0       0       0
# 3754       3       6       4       2       3       3       7       1
# 3755       1       1       1       0       1       0       4       2
# 3757       0       0       0       0       0       0       0       0
# 3759       1       0       0       1       0       0       0       1
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[1000:1500]
# Out:
#                                    id          item_id      dept_id  \
# 3761  HOUSEHOLD_1_152_CA_2_validation  HOUSEHOLD_1_152  HOUSEHOLD_1
# 3763  HOUSEHOLD_1_154_CA_2_validation  HOUSEHOLD_1_154  HOUSEHOLD_1
# 3764  HOUSEHOLD_1_155_CA_2_validation  HOUSEHOLD_1_155  HOUSEHOLD_1
# 3766  HOUSEHOLD_1_157_CA_2_validation  HOUSEHOLD_1_157  HOUSEHOLD_1
# 3767  HOUSEHOLD_1_158_CA_2_validation  HOUSEHOLD_1_158  HOUSEHOLD_1
# ...                               ...              ...          ...
# 4381  HOUSEHOLD_2_237_CA_2_validation  HOUSEHOLD_2_237  HOUSEHOLD_2
# 4382  HOUSEHOLD_2_238_CA_2_validation  HOUSEHOLD_2_238  HOUSEHOLD_2
# 4383  HOUSEHOLD_2_239_CA_2_validation  HOUSEHOLD_2_239  HOUSEHOLD_2
# 4385  HOUSEHOLD_2_241_CA_2_validation  HOUSEHOLD_2_241  HOUSEHOLD_2
# 4386  HOUSEHOLD_2_242_CA_2_validation  HOUSEHOLD_2_242  HOUSEHOLD_2
#
#          cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 3761  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 3763  HOUSEHOLD     CA_2       CA    3    4    2    3  ...       0       0
# 3764  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 3766  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       1       3
# 3767  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       1
# ...         ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 4381  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 4382  HOUSEHOLD     CA_2       CA    0    2    0    0  ...       1       3
# 4383  HOUSEHOLD     CA_2       CA    0    4    0    0  ...       0       6
# 4385  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 4386  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
#
#       d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 3761       6       0       0       1       1       2       1       2
# 3763       0       0       0       0       0       0       1       1
# 3764       0       0       1       0       0       0       0       0
# 3766       4       1       5       6       2       0       3       2
# 3767       4       0       1       1       0       0       0       2
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 4381       0       1       0       0       0       1       0       0
# 4382       2       0       1       0       0       1       0       1
# 4383       0       0       0       0       0       0       0       0
# 4385       0       0       0       0       0       0       0       0
# 4386       0       0       0       0       0       0       0       0
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[1500:2000]
# Out:
#                                    id          item_id      dept_id  \
# 4387  HOUSEHOLD_2_243_CA_2_validation  HOUSEHOLD_2_243  HOUSEHOLD_2
# 4388  HOUSEHOLD_2_244_CA_2_validation  HOUSEHOLD_2_244  HOUSEHOLD_2
# 4389  HOUSEHOLD_2_245_CA_2_validation  HOUSEHOLD_2_245  HOUSEHOLD_2
# 4390  HOUSEHOLD_2_246_CA_2_validation  HOUSEHOLD_2_246  HOUSEHOLD_2
# 4391  HOUSEHOLD_2_247_CA_2_validation  HOUSEHOLD_2_247  HOUSEHOLD_2
# ...                               ...              ...          ...
# 7095  HOUSEHOLD_1_442_CA_3_validation  HOUSEHOLD_1_442  HOUSEHOLD_1
# 7097  HOUSEHOLD_1_444_CA_3_validation  HOUSEHOLD_1_444  HOUSEHOLD_1
# 7099  HOUSEHOLD_1_446_CA_3_validation  HOUSEHOLD_1_446  HOUSEHOLD_1
# 7103  HOUSEHOLD_1_450_CA_3_validation  HOUSEHOLD_1_450  HOUSEHOLD_1
# 7104  HOUSEHOLD_1_451_CA_3_validation  HOUSEHOLD_1_451  HOUSEHOLD_1
#
#          cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 4387  HOUSEHOLD     CA_2       CA    0    0    2    0  ...       0       0
# 4388  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       1
# 4389  HOUSEHOLD     CA_2       CA    0    0    0    0  ...       0       0
# 4390  HOUSEHOLD     CA_2       CA    0    0    2    0  ...       0       0
# 4391  HOUSEHOLD     CA_2       CA    0    0    1    0  ...       1       2
# ...         ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 7095  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       2       0
# 7097  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       0       1
# 7099  HOUSEHOLD     CA_3       CA    0    0    0    1  ...       0       1
# 7103  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       2       2
# 7104  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       0       0
#
#       d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 4387       0       0       0       0       0       0       1       0
# 4388       2       0       0       0       1       0       0       1
# 4389       0       0       0       0       0       0       0       0
# 4390       0       0       1       0       0       1       0       0
# 4391       0       0       0       0       0       1       0       0
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 7095       3       1       1       0       1       3       0       0
# 7097       1       1       0       2       2       1       2       0
# 7099       1       1       2       0       0       0       2       0
# 7103       4       1       3       1       2       0       0       0
# 7104       0       2       3       0       1       0       0       0
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[2000:2500]
# Out:
#                                    id          item_id      dept_id  \
# 7105  HOUSEHOLD_1_452_CA_3_validation  HOUSEHOLD_1_452  HOUSEHOLD_1
# 7107  HOUSEHOLD_1_454_CA_3_validation  HOUSEHOLD_1_454  HOUSEHOLD_1
# 7111  HOUSEHOLD_1_458_CA_3_validation  HOUSEHOLD_1_458  HOUSEHOLD_1
# 7113  HOUSEHOLD_1_460_CA_3_validation  HOUSEHOLD_1_460  HOUSEHOLD_1
# 7116  HOUSEHOLD_1_463_CA_3_validation  HOUSEHOLD_1_463  HOUSEHOLD_1
# ...                               ...              ...          ...
# 7701  HOUSEHOLD_2_508_CA_3_validation  HOUSEHOLD_2_508  HOUSEHOLD_2
# 7702  HOUSEHOLD_2_509_CA_3_validation  HOUSEHOLD_2_509  HOUSEHOLD_2
# 7704  HOUSEHOLD_2_511_CA_3_validation  HOUSEHOLD_2_511  HOUSEHOLD_2
# 7705  HOUSEHOLD_2_512_CA_3_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 7707  HOUSEHOLD_2_514_CA_3_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
#
#          cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 7105  HOUSEHOLD     CA_3       CA    5    1    3    0  ...       1       1
# 7107  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       0       0
# 7111  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       4       5
# 7113  HOUSEHOLD     CA_3       CA    2    5    5    4  ...       0       1
# 7116  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       0       0
# ...         ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 7701  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       0       0
# 7702  HOUSEHOLD     CA_3       CA    1    0    4    3  ...       1       3
# 7704  HOUSEHOLD     CA_3       CA    5    9    1    4  ...       0       0
# 7705  HOUSEHOLD     CA_3       CA    0    0    0    0  ...       1       2
# 7707  HOUSEHOLD     CA_3       CA    0    2    0    0  ...       1       0
#
#       d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 7105       0       0       0       0       0       3       1       1
# 7107       0       0       0       3       1       0       1       2
# 7111       1       3       1       0       4       2       2       2
# 7113       1       1       0       0       1       0       1       4
# 7116       0       1       3       1       1       1       0       0
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 7701       0       0       0       0       0       1       0       0
# 7702       0       2       1       1       0       2       3       4
# 7704       1       0       0       0       0       1       2       0
# 7705       0       0       6       0       5       1       3       2
# 7707       0       0       1       0       0       0       0       0
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[2500:3000]
# Out:
#                                     id          item_id      dept_id  \
# 7708   HOUSEHOLD_2_515_CA_3_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 7709   HOUSEHOLD_2_516_CA_3_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
# 9712   HOUSEHOLD_1_001_CA_4_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 9713   HOUSEHOLD_1_002_CA_4_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 9714   HOUSEHOLD_1_003_CA_4_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10245  HOUSEHOLD_2_002_CA_4_validation  HOUSEHOLD_2_002  HOUSEHOLD_2
# 10246  HOUSEHOLD_2_003_CA_4_validation  HOUSEHOLD_2_003  HOUSEHOLD_2
# 10247  HOUSEHOLD_2_004_CA_4_validation  HOUSEHOLD_2_004  HOUSEHOLD_2
# 10248  HOUSEHOLD_2_005_CA_4_validation  HOUSEHOLD_2_005  HOUSEHOLD_2
# 10249  HOUSEHOLD_2_006_CA_4_validation  HOUSEHOLD_2_006  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 7708   HOUSEHOLD     CA_3       CA    0    0    0    0  ...       1       1
# 7709   HOUSEHOLD     CA_3       CA    0    1    0    1  ...       1       0
# 9712   HOUSEHOLD     CA_4       CA    1    1    0    1  ...       0       1
# 9713   HOUSEHOLD     CA_4       CA    0    1    0    2  ...       0       2
# 9714   HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10245  HOUSEHOLD     CA_4       CA    0    2    1    0  ...       0       0
# 10246  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       1       1
# 10247  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10248  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       1
# 10249  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 7708        1       0       0       0       0       0       0       0
# 7709        0       0       0       0       0       0       0       0
# 9712        1       0       0       1       1       0       2       0
# 9713        1       1       1       1       3       1       1       0
# 9714        1       0       0       0       0       1       1       1
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10245       0       0       0       0       0       2       0       1
# 10246       0       1       0       0       0       1       0       0
# 10247       0       0       0       0       1       0       0       0
# 10248       0       0       0       0       1       0       0       0
# 10249       0       0       0       0       0       0       1       0
#
# [500 rows x 1919 columns]

# %%
sales_intermittent.iloc[3000:]
# Out:
#                                     id          item_id      dept_id  \
# 10250  HOUSEHOLD_2_007_CA_4_validation  HOUSEHOLD_2_007  HOUSEHOLD_2
# 10251  HOUSEHOLD_2_008_CA_4_validation  HOUSEHOLD_2_008  HOUSEHOLD_2
# 10252  HOUSEHOLD_2_009_CA_4_validation  HOUSEHOLD_2_009  HOUSEHOLD_2
# 10253  HOUSEHOLD_2_010_CA_4_validation  HOUSEHOLD_2_010  HOUSEHOLD_2
# 10254  HOUSEHOLD_2_011_CA_4_validation  HOUSEHOLD_2_011  HOUSEHOLD_2
# ...                                ...              ...          ...
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
# 10756  HOUSEHOLD_2_514_CA_4_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
# 10757  HOUSEHOLD_2_515_CA_4_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 10758  HOUSEHOLD_2_516_CA_4_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 10250  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10251  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10252  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       1
# 10253  HOUSEHOLD     CA_4       CA    1    0    1    0  ...       0       0
# 10254  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
# 10756  HOUSEHOLD     CA_4       CA    0    2    0    1  ...       0       0
# 10757  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10758  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 10250       0       0       0       0       0       0       0       0
# 10251       0       0       0       0       0       0       0       0
# 10252       0       0       0       0       0       1       0       1
# 10253       0       0       0       0       0       0       1       0
# 10254       2       0       0       1       0       1       2       0
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10754       0       0       2       1       0       0       0       0
# 10755       0       0       0       0       0       0       0       0
# 10756       1       0       0       0       0       0       0       0
# 10757       0       0       0       0       0       0       2       0
# 10758       0       0       0       0       0       0       0       1
#
# [490 rows x 1919 columns]

# %%
start = timer()

pattern_df_result_all_params = CrostonTSB_output_all_params(sales_intermittent.iloc[3000:],
                                                          list_params_alpha,
                                                          list_params_beta,
                                                          start_train_date,
                                                          end_train_date, 
                                                          n_pred_days,
                                                          num_train_needed,
                                                          validation_training_ratio)

end = timer()

print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 28.591983576233336 minutes

# %%
pattern_df_result_all_params
# Out:
#                                  Product  Actual Data      Forecast  Alpha  \
# 0        HOUSEHOLD_2_007_CA_4_validation          0.0  1.904884e-01    0.1
# 1        HOUSEHOLD_2_007_CA_4_validation          1.0  1.714396e-01    0.1
# 2        HOUSEHOLD_2_007_CA_4_validation          0.0  2.638891e-01    0.1
# 3        HOUSEHOLD_2_007_CA_4_validation          1.0  2.375002e-01    0.1
# 4        HOUSEHOLD_2_007_CA_4_validation          0.0  3.217624e-01    0.1
# ...                                  ...          ...           ...    ...
# 1468525  HOUSEHOLD_2_516_CA_4_validation          0.0  9.081000e-27    0.9
# 1468526  HOUSEHOLD_2_516_CA_4_validation          0.0  9.081000e-28    0.9
# 1468527  HOUSEHOLD_2_516_CA_4_validation          0.0  9.081000e-29    0.9
# 1468528  HOUSEHOLD_2_516_CA_4_validation          0.0  9.081000e-30    0.9
# 1468529  HOUSEHOLD_2_516_CA_4_validation          0.0  9.081000e-31    0.9
#
#          Beta
# 0         0.1
# 1         0.1
# 2         0.1
# 3         0.1
# 4         0.1
# ...       ...
# 1468525   0.9
# 1468526   0.9
# 1468527   0.9
# 1468528   0.9
# 1468529   0.9
#
# [1468530 rows x 5 columns]

# %%
pattern_df_result_all_params.to_csv('CrostonTSB_Intermittent_3000_End_All_Parameters_Hyperparameter_Tuning_Data.csv')

# %% [markdown]
# # Summay all metrics

# %%
def get_metrics_result_all_params(data):
    metrics_df = {}
    metrics_df['MASE'] = mase_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['WMAPE'] = wmape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['SMAPE'] = smape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAPE'] = mape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAE'] = mean_absolute_error(data['Actual Data'], data['Forecast'])
    metrics_df['RMSE'] = np.sqrt(mean_squared_error(data['Actual Data'], data['Forecast']))
    return pd.Series(metrics_df)

# %%
start = timer()

df_result_metrics_all_params = pattern_df_result_all_params.groupby(['Product', 'Alpha', 'Beta']).apply(get_metrics_result_all_params).reset_index()

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 1.6533649063166649 minutes

# %%
df_result_metrics_all_params
# Out:
#                                Product  Alpha  Beta      MASE     WMAPE  \
# 0      HOUSEHOLD_2_007_CA_4_validation    0.1   0.1  0.878456  180.5716
# 1      HOUSEHOLD_2_007_CA_4_validation    0.1   0.2  0.880690  181.0308
# 2      HOUSEHOLD_2_007_CA_4_validation    0.1   0.3  0.895469  184.0687
# 3      HOUSEHOLD_2_007_CA_4_validation    0.1   0.4  0.911082  187.2780
# 4      HOUSEHOLD_2_007_CA_4_validation    0.1   0.5  0.925791  190.3016
# ...                                ...    ...   ...       ...       ...
# 39685  HOUSEHOLD_2_516_CA_4_validation    0.9   0.5  0.979356  201.3120
# 39686  HOUSEHOLD_2_516_CA_4_validation    0.9   0.6  0.977694  200.9705
# 39687  HOUSEHOLD_2_516_CA_4_validation    0.9   0.7  0.977386  200.9071
# 39688  HOUSEHOLD_2_516_CA_4_validation    0.9   0.8  0.977353  200.9003
# 39689  HOUSEHOLD_2_516_CA_4_validation    0.9   0.9  0.977351  200.9000
#
#           SMAPE      MAPE       MAE      RMSE
# 0      191.3379   84.2920  0.292819  0.385272
# 1      193.0132   87.3893  0.293563  0.401861
# 2      194.2329   89.5206  0.298490  0.419331
# 3      195.2750   91.3054  0.303694  0.437885
# 4      196.1807   92.8824  0.308597  0.457848
# ...         ...       ...       ...       ...
# 39685  199.9993   99.9933  0.054409  0.190254
# 39686  200.0000   99.9996  0.054316  0.197026
# 39687  200.0000  100.0000  0.054299  0.204556
# 39688  200.0000  100.0000  0.054297  0.213004
# 39689  200.0000  100.0000  0.054297  0.222576
#
# [39690 rows x 9 columns]

# %% [markdown]
# # Check what products has unexpected metrics result

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MASE'].isin([np.inf, -np.inf, np.nan])]
# Out:
#                                Product  Alpha  Beta  MASE  WMAPE  SMAPE  MAPE  \
# 405    HOUSEHOLD_2_012_CA_4_validation    0.1   0.1   inf    inf  200.0   NaN
# 406    HOUSEHOLD_2_012_CA_4_validation    0.1   0.2   inf    inf  200.0   NaN
# 407    HOUSEHOLD_2_012_CA_4_validation    0.1   0.3   inf    inf  200.0   NaN
# 408    HOUSEHOLD_2_012_CA_4_validation    0.1   0.4   inf    inf  200.0   NaN
# 409    HOUSEHOLD_2_012_CA_4_validation    0.1   0.5   inf    inf  200.0   NaN
# ...                                ...    ...   ...   ...    ...    ...   ...
# 39604  HOUSEHOLD_2_515_CA_4_validation    0.9   0.5   NaN    NaN    NaN   NaN
# 39605  HOUSEHOLD_2_515_CA_4_validation    0.9   0.6   NaN    NaN    NaN   NaN
# 39606  HOUSEHOLD_2_515_CA_4_validation    0.9   0.7   NaN    NaN    NaN   NaN
# 39607  HOUSEHOLD_2_515_CA_4_validation    0.9   0.8   NaN    NaN    NaN   NaN
# 39608  HOUSEHOLD_2_515_CA_4_validation    0.9   0.9   NaN    NaN    NaN   NaN
#
#                 MAE          RMSE
# 405    5.571667e-03  7.934434e-03
# 406    2.989552e-04  6.063152e-04
# 407    1.688979e-05  4.315808e-05
# 408    6.569460e-07  1.998023e-06
# 409    1.426230e-08  5.008757e-08
# ...             ...           ...
# 39604  0.000000e+00  0.000000e+00
# 39605  0.000000e+00  0.000000e+00
# 39606  0.000000e+00  0.000000e+00
# 39607  0.000000e+00  0.000000e+00
# 39608  0.000000e+00  0.000000e+00
#
# [10935 rows x 9 columns]

# %%
df_result_metrics_all_params[df_result_metrics_all_params['WMAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
#                                Product  Alpha  Beta  MASE  WMAPE  SMAPE  MAPE  \
# 405    HOUSEHOLD_2_012_CA_4_validation    0.1   0.1   inf    inf  200.0   NaN
# 406    HOUSEHOLD_2_012_CA_4_validation    0.1   0.2   inf    inf  200.0   NaN
# 407    HOUSEHOLD_2_012_CA_4_validation    0.1   0.3   inf    inf  200.0   NaN
# 408    HOUSEHOLD_2_012_CA_4_validation    0.1   0.4   inf    inf  200.0   NaN
# 409    HOUSEHOLD_2_012_CA_4_validation    0.1   0.5   inf    inf  200.0   NaN
# ...                                ...    ...   ...   ...    ...    ...   ...
# 39604  HOUSEHOLD_2_515_CA_4_validation    0.9   0.5   NaN    NaN    NaN   NaN
# 39605  HOUSEHOLD_2_515_CA_4_validation    0.9   0.6   NaN    NaN    NaN   NaN
# 39606  HOUSEHOLD_2_515_CA_4_validation    0.9   0.7   NaN    NaN    NaN   NaN
# 39607  HOUSEHOLD_2_515_CA_4_validation    0.9   0.8   NaN    NaN    NaN   NaN
# 39608  HOUSEHOLD_2_515_CA_4_validation    0.9   0.9   NaN    NaN    NaN   NaN
#
#                 MAE          RMSE
# 405    5.571667e-03  7.934434e-03
# 406    2.989552e-04  6.063152e-04
# 407    1.688979e-05  4.315808e-05
# 408    6.569460e-07  1.998023e-06
# 409    1.426230e-08  5.008757e-08
# ...             ...           ...
# 39604  0.000000e+00  0.000000e+00
# 39605  0.000000e+00  0.000000e+00
# 39606  0.000000e+00  0.000000e+00
# 39607  0.000000e+00  0.000000e+00
# 39608  0.000000e+00  0.000000e+00
#
# [10935 rows x 9 columns]

# %%
df_result_metrics_all_params[df_result_metrics_all_params['SMAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
#                                Product  Alpha  Beta  MASE  WMAPE  SMAPE  MAPE  \
# 810    HOUSEHOLD_2_017_CA_4_validation    0.1   0.1   NaN    NaN    NaN   NaN
# 811    HOUSEHOLD_2_017_CA_4_validation    0.1   0.2   NaN    NaN    NaN   NaN
# 812    HOUSEHOLD_2_017_CA_4_validation    0.1   0.3   NaN    NaN    NaN   NaN
# 813    HOUSEHOLD_2_017_CA_4_validation    0.1   0.4   NaN    NaN    NaN   NaN
# 814    HOUSEHOLD_2_017_CA_4_validation    0.1   0.5   NaN    NaN    NaN   NaN
# ...                                ...    ...   ...   ...    ...    ...   ...
# 39604  HOUSEHOLD_2_515_CA_4_validation    0.9   0.5   NaN    NaN    NaN   NaN
# 39605  HOUSEHOLD_2_515_CA_4_validation    0.9   0.6   NaN    NaN    NaN   NaN
# 39606  HOUSEHOLD_2_515_CA_4_validation    0.9   0.7   NaN    NaN    NaN   NaN
# 39607  HOUSEHOLD_2_515_CA_4_validation    0.9   0.8   NaN    NaN    NaN   NaN
# 39608  HOUSEHOLD_2_515_CA_4_validation    0.9   0.9   NaN    NaN    NaN   NaN
#
#        MAE  RMSE
# 810    0.0   0.0
# 811    0.0   0.0
# 812    0.0   0.0
# 813    0.0   0.0
# 814    0.0   0.0
# ...    ...   ...
# 39604  0.0   0.0
# 39605  0.0   0.0
# 39606  0.0   0.0
# 39607  0.0   0.0
# 39608  0.0   0.0
#
# [7938 rows x 9 columns]

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MAPE'].isin([np.inf, -np.inf, np.nan])]
# Out:
#                                Product  Alpha  Beta  MASE  WMAPE  SMAPE  MAPE  \
# 405    HOUSEHOLD_2_012_CA_4_validation    0.1   0.1   inf    inf  200.0   NaN
# 406    HOUSEHOLD_2_012_CA_4_validation    0.1   0.2   inf    inf  200.0   NaN
# 407    HOUSEHOLD_2_012_CA_4_validation    0.1   0.3   inf    inf  200.0   NaN
# 408    HOUSEHOLD_2_012_CA_4_validation    0.1   0.4   inf    inf  200.0   NaN
# 409    HOUSEHOLD_2_012_CA_4_validation    0.1   0.5   inf    inf  200.0   NaN
# ...                                ...    ...   ...   ...    ...    ...   ...
# 39604  HOUSEHOLD_2_515_CA_4_validation    0.9   0.5   NaN    NaN    NaN   NaN
# 39605  HOUSEHOLD_2_515_CA_4_validation    0.9   0.6   NaN    NaN    NaN   NaN
# 39606  HOUSEHOLD_2_515_CA_4_validation    0.9   0.7   NaN    NaN    NaN   NaN
# 39607  HOUSEHOLD_2_515_CA_4_validation    0.9   0.8   NaN    NaN    NaN   NaN
# 39608  HOUSEHOLD_2_515_CA_4_validation    0.9   0.9   NaN    NaN    NaN   NaN
#
#                 MAE          RMSE
# 405    5.571667e-03  7.934434e-03
# 406    2.989552e-04  6.063152e-04
# 407    1.688979e-05  4.315808e-05
# 408    6.569460e-07  1.998023e-06
# 409    1.426230e-08  5.008757e-08
# ...             ...           ...
# 39604  0.000000e+00  0.000000e+00
# 39605  0.000000e+00  0.000000e+00
# 39606  0.000000e+00  0.000000e+00
# 39607  0.000000e+00  0.000000e+00
# 39608  0.000000e+00  0.000000e+00
#
# [10935 rows x 9 columns]

# %%
df_result_metrics_all_params[df_result_metrics_all_params['RMSE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %%
df_result_metrics_all_params[df_result_metrics_all_params['MAE'].isin([np.inf, -np.inf, np.nan])]
# Out:
# Empty DataFrame
# Columns: [Product, Alpha, Beta, MASE, WMAPE, SMAPE, MAPE, MAE, RMSE]
# Index: []

# %% [markdown]
# # Metrics Statistics

# %%
list_metrics = ['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE']

# %%
for mts in list_metrics:
    print('Percentage of unexpected values of', mts, 'is: {}'.format(df_result_metrics_all_params[df_result_metrics_all_params[mts].isin([np.nan, np.inf, -np.inf])].Product.nunique() / df_result_metrics_all_params.Product.nunique() * 100), "%")
# Out:
# Percentage of unexpected values of MASE is: 27.55102040816326 %
# Percentage of unexpected values of WMAPE is: 27.55102040816326 %
# Percentage of unexpected values of SMAPE is: 20.0 %
# Percentage of unexpected values of MAPE is: 27.55102040816326 %
# Percentage of unexpected values of MAE is: 0.0 %
# Percentage of unexpected values of RMSE is: 0.0 %

# %% [markdown]
# ### Filter all rows that have unexpected metrics values

# %%
df_result_metrics_all_params = df_result_metrics_all_params[~df_result_metrics_all_params.isin([np.nan, np.inf, -np.inf]).any(1)]

# %% [markdown]
# ### Get MEAN metrics value of each Alpha

# %%
df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].mean()
# Out:
#                 MASE       WMAPE       SMAPE       MAPE       MAE      RMSE
# Alpha Beta
# 0.1   0.1   1.022506  172.434140  184.542284  80.776270  0.347211  0.489886
#       0.2   1.008843  170.142937  185.062615  81.292397  0.345398  0.500558
#       0.3   1.001627  169.095871  185.509664  81.461807  0.344563  0.512319
#       0.4   0.996580  168.475864  185.985674  81.621160  0.344168  0.525187
#       0.5   0.993236  168.165651  186.535526  81.894511  0.344390  0.539412
# ...              ...         ...         ...        ...       ...       ...
# 0.9   0.5   0.996567  168.483770  187.184400  83.139424  0.351072  0.552902
#       0.6   0.996474  168.682621  187.851562  83.909027  0.352659  0.570017
#       0.7   0.997591  169.077274  188.588381  84.810465  0.354670  0.589219
#       0.8   0.999570  169.612747  189.415059  85.792310  0.357090  0.610926
#       0.9   1.002008  170.225365  190.366729  86.801593  0.359712  0.635674
#
# [81 rows x 6 columns]

# %%
for mts in list_metrics:
    print('The optimum Alpha and Beta based on Mean', mts, 'is: {}'.format(df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].mean()[mts].idxmin()))
# Out:
# The optimum Alpha and Beta based on Mean MASE is: (0.2, 0.7)
# The optimum Alpha and Beta based on Mean WMAPE is: (0.2, 0.6)
# The optimum Alpha and Beta based on Mean SMAPE is: (0.1, 0.1)
# The optimum Alpha and Beta based on Mean MAPE is: (0.1, 0.1)
# The optimum Alpha and Beta based on Mean MAE is: (0.1, 0.4)
# The optimum Alpha and Beta based on Mean RMSE is: (0.1, 0.1)

# %% [markdown]
# ### Get MEDIAN metrics value of each Alpha

# %%
df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].median()
# Out:
#                 MASE      WMAPE      SMAPE      MAPE       MAE      RMSE
# Alpha Beta
# 0.1   0.1   0.980561  165.88465  191.99620  84.73875  0.314379  0.448267
#       0.2   0.972863  167.14745  192.48740  84.50540  0.306501  0.458820
#       0.3   0.972577  166.43595  192.77895  84.39525  0.302338  0.471646
#       0.4   0.972974  165.89390  193.07355  84.60595  0.304113  0.484948
#       0.5   0.973018  166.44380  193.46640  84.79410  0.301474  0.501492
# ...              ...        ...        ...       ...       ...       ...
# 0.9   0.5   0.972935  168.80340  193.61940  85.01900  0.300987  0.499448
#       0.6   0.972973  169.84050  193.96470  85.22625  0.299566  0.517222
#       0.7   0.972973  171.17660  194.53140  86.02840  0.300400  0.534842
#       0.8   0.974317  170.45475  194.78620  87.36885  0.299671  0.556785
#       0.9   0.977837  171.29815  194.86165  88.83790  0.298601  0.582498
#
# [81 rows x 6 columns]

# %%
for mts in list_metrics:
    print('The optimum Alpha and Beta based on Median of', mts, 'is: {}'.format(df_result_metrics_all_params.groupby(['Alpha', 'Beta'])['MASE', 'WMAPE', 'SMAPE', 'MAPE', 'MAE', 'RMSE'].median()[mts].idxmin()))
# Out:
# The optimum Alpha and Beta based on Median of MASE is: (0.4, 0.2)
# The optimum Alpha and Beta based on Median of WMAPE is: (0.2, 0.1)
# The optimum Alpha and Beta based on Median of SMAPE is: (0.6, 0.1)
# The optimum Alpha and Beta based on Median of MAPE is: (0.3, 0.2)
# The optimum Alpha and Beta based on Median of MAE is: (0.1, 0.8)
# The optimum Alpha and Beta based on Median of RMSE is: (0.3, 0.1)

# %% [markdown]
# # Run CrostonTSB model after decide best paramaters

# %%
best_alpha = 0.1
best_beta = 0.1

# %%
def CrostonTSB_test_data(best_alpha, best_beta, sales_pattern,
                         start_train_date, end_train_date, 
                         n_pred_days, num_train_needed, validation_training_ratio):
    
    sales_pattern_py = sales_pattern.copy()
    list_pattern_py = sales_pattern_py.id.unique().tolist()
    
    sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
    df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
    df_pattern.drop('Date', axis=1, inplace=True)
    df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
    df_pattern.index.names = ['Date']
    df_pattern = df_pattern.astype('float64')
    
    train_data = df_pattern[(df_pattern.index >= start_train_date) & (df_pattern.index <= end_train_date)]
    test_data = df_pattern.iloc[n_pred_days*-1:]
    
    df_result_best_params = pd.DataFrame()
    for product in list_pattern_py:
        train_product = train_data[product]
        test_product = test_data[product]
        predictions = list()
        history = [x for x in train_product[num_train_needed*-1:]]
        for t in range(len(test_product)):
            yhat = Croston_TSB(history, extra_periods=1, alpha=best_alpha, beta = best_beta)['Forecast'].iloc[-1]
            predictions.append(yhat)
            history.append(test_product[t])
        df_result_temp = pd.DataFrame({'Product': [product for count in range(len(test_product))],
                                        'Actual Data': test_product,
                                        'Forecast': predictions})
        df_result_best_params = df_result_best_params.append(df_result_temp, ignore_index=True)
            
    return df_result_best_params

# %%
start = timer()

pattern_df_result_best_params = CrostonTSB_test_data(best_alpha, best_beta, sales_intermittent, start_train_date, end_train_date, n_pred_days, num_train_needed, validation_training_ratio)

end = timer()

print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 0.8097675214166732 minutes

# %%
df_result_final = pattern_df_result_best_params.groupby('Product').apply(get_metrics_result_all_params).reset_index()

# %%
df_result_final
# Out:
#                               Product      MASE     WMAPE     SMAPE     MAPE  \
# 0     HOUSEHOLD_1_001_CA_1_validation  1.061912  152.4797  189.6886  85.9169
# 1     HOUSEHOLD_1_001_CA_2_validation  0.772459  166.3759  199.9586  99.8550
# 2     HOUSEHOLD_1_001_CA_3_validation  0.732277  122.6720  135.5755  35.2764
# 3     HOUSEHOLD_1_001_CA_4_validation       inf       inf  200.0000      NaN
# 4     HOUSEHOLD_1_002_CA_1_validation  1.218606  196.8517  193.0506  86.0428
# ...                               ...       ...       ...       ...      ...
# 3485  HOUSEHOLD_2_515_CA_4_validation       NaN       NaN       NaN      NaN
# 3486  HOUSEHOLD_2_516_CA_1_validation  1.605843  172.9370  195.1632  90.5282
# 3487  HOUSEHOLD_2_516_CA_2_validation       inf       inf  200.0000      NaN
# 3488  HOUSEHOLD_2_516_CA_3_validation  2.542754  273.8350  195.7705  82.6246
# 3489  HOUSEHOLD_2_516_CA_4_validation  0.653125  140.6732  199.9398  99.7888
#
#            MAE      RMSE
# 0     0.326742  0.436061
# 1     0.118840  0.273151
# 2     0.788606  0.964024
# 3     0.063443  0.068741
# 4     0.281217  0.370623
# ...        ...       ...
# 3485  0.000000  0.000000
# 3486  0.247053  0.368767
# 3487  0.151658  0.164321
# 3488  0.195596  0.268099
# 3489  0.100481  0.271457
#
# [3490 rows x 7 columns]

# %%
df_result_final.to_csv('CrostonTSB_Intermittent_Test_Data.csv')
