# %% [markdown]
# # Import necessary packages

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from random import sample

import re

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

from timeit import default_timer as timer

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import original data and preprocessed data

# %%
sales_train_val = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/sales_train_validation.csv')
calendar = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/calendar.csv')

# %% [markdown]
# **Note: This Step is for the extraction of California State and Foods category**

# %%
sales_train_val = sales_train_val[(sales_train_val['state_id'] == 'CA') & (sales_train_val['cat_id'] == 'HOBBIES')]

# %%
sales_train_val
# Out:
#                                  id        item_id    dept_id   cat_id  \
# 0     HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1     HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2     HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3     HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4     HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                             ...            ...        ...      ...
# 9707  HOBBIES_2_145_CA_4_validation  HOBBIES_2_145  HOBBIES_2  HOBBIES
# 9708  HOBBIES_2_146_CA_4_validation  HOBBIES_2_146  HOBBIES_2  HOBBIES
# 9709  HOBBIES_2_147_CA_4_validation  HOBBIES_2_147  HOBBIES_2  HOBBIES
# 9710  HOBBIES_2_148_CA_4_validation  HOBBIES_2_148  HOBBIES_2  HOBBIES
# 9711  HOBBIES_2_149_CA_4_validation  HOBBIES_2_149  HOBBIES_2  HOBBIES
#
#      store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# 0        CA_1       CA    0    0    0    0  ...       1       3       0
# 1        CA_1       CA    0    0    0    0  ...       0       0       0
# 2        CA_1       CA    0    0    0    0  ...       2       1       2
# 3        CA_1       CA    0    0    0    0  ...       1       0       5
# 4        CA_1       CA    0    0    0    0  ...       2       1       1
# ...       ...      ...  ...  ...  ...  ...  ...     ...     ...     ...
# 9707     CA_4       CA    0    0    0    0  ...       0       0       0
# 9708     CA_4       CA    0    0    0    0  ...       0       0       0
# 9709     CA_4       CA    0    0    0    0  ...       0       0       0
# 9710     CA_4       CA    0    0    0    0  ...       0       0       0
# 9711     CA_4       CA    0    0    0    0  ...       0       0       0
#
#       d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 0          1       1       1       3       0       1       1
# 1          0       0       1       0       0       0       0
# 2          1       1       1       0       1       1       1
# 3          4       1       0       1       3       7       2
# 4          0       1       1       2       2       2       4
# ...      ...     ...     ...     ...     ...     ...     ...
# 9707       0       0       0       0       0       0       0
# 9708       0       0       0       0       0       0       0
# 9709       0       0       1       0       0       0       0
# 9710       0       0       0       0       0       0       0
# 9711       0       0       1       0       0       0       0
#
# [2260 rows x 1919 columns]

# %%
INPUT_DIR_2 = r'/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/List of Product ID according to 4 demand patterns/California/Hobbies'

list_intermittent = pd.read_csv(f'{INPUT_DIR_2}/Intermittent_ID.csv')
list_lumpy = pd.read_csv(f'{INPUT_DIR_2}/Lumpy_ID.csv')
list_erratic = pd.read_csv(f'{INPUT_DIR_2}/Erratic_ID.csv')
list_smooth = pd.read_csv(f'{INPUT_DIR_2}/Smooth_ID.csv')

list_intermittent = list_intermittent['0'].values.tolist()
list_lumpy = list_lumpy['0'].values.tolist()
list_erratic = list_erratic['0'].values.tolist()
list_smooth = list_smooth['0'].values.tolist()

sales_intermittent = sales_train_val[sales_train_val.id.isin(list_intermittent)]
sales_lumpy = sales_train_val[sales_train_val.id.isin(list_lumpy)]
sales_erratic = sales_train_val[sales_train_val.id.isin(list_erratic)]
sales_smooth = sales_train_val[sales_train_val.id.isin(list_smooth)]

# %%
len(sales_intermittent)
# Out:
# 1301

# %%
len(sales_lumpy)
# Out:
# 395

# %%
len(sales_erratic)
# Out:
# 99

# %%
len(sales_smooth)
# Out:
# 3594

# %% [markdown]
# **Check by looking at column "id" to verify if we choose the right product (FOODS or HOBBIES or HOUSEHOLD)**

# %%
sales_erratic
# Out:
#                                  id        item_id    dept_id   cat_id  \
# 1     HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2     HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 73    HOBBIES_1_076_CA_1_validation  HOBBIES_1_076  HOBBIES_1  HOBBIES
# 77    HOBBIES_1_080_CA_1_validation  HOBBIES_1_080  HOBBIES_1  HOBBIES
# 88    HOBBIES_1_091_CA_1_validation  HOBBIES_1_091  HOBBIES_1  HOBBIES
# ...                             ...            ...        ...      ...
# 9292  HOBBIES_1_150_CA_4_validation  HOBBIES_1_150  HOBBIES_1  HOBBIES
# 9298  HOBBIES_1_156_CA_4_validation  HOBBIES_1_156  HOBBIES_1  HOBBIES
# 9342  HOBBIES_1_202_CA_4_validation  HOBBIES_1_202  HOBBIES_1  HOBBIES
# 9362  HOBBIES_1_223_CA_4_validation  HOBBIES_1_223  HOBBIES_1  HOBBIES
# 9416  HOBBIES_1_277_CA_4_validation  HOBBIES_1_277  HOBBIES_1  HOBBIES
#
#      store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# 1        CA_1       CA    0    0    0    0  ...       0       0       0
# 2        CA_1       CA    0    0    0    0  ...       2       1       2
# 73       CA_1       CA    0    1    2    3  ...       0       2       1
# 77       CA_1       CA    0    0    0    0  ...       0       0       0
# 88       CA_1       CA    0    0    0    0  ...       0       1       7
# ...       ...      ...  ...  ...  ...  ...  ...     ...     ...     ...
# 9292     CA_4       CA    0    0    0    0  ...       0       0       0
# 9298     CA_4       CA    0    0    0    0  ...       0       2       1
# 9342     CA_4       CA    2    1    5    3  ...       0       0       0
# 9362     CA_4       CA    0    0    0    0  ...       2       0       0
# 9416     CA_4       CA    1    1    4    3  ...       0       0       0
#
#       d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 1          0       0       1       0       0       0       0
# 2          1       1       1       0       1       1       1
# 73         0       0       0       0       1       1       0
# 77         0       0      12       2       0       0       7
# 88         1       3       2       0       0       1       0
# ...      ...     ...     ...     ...     ...     ...     ...
# 9292       0       0       0       0       0       1       1
# 9298       0       0       0       0       0       0       0
# 9342       0       0       0       0       0       0       0
# 9362       0       1       0       0       0       1       0
# 9416       6       0       0       0       0       0       0
#
# [99 rows x 1919 columns]

# %% [markdown]
# # User-defined functions to calculate Metrics

# %%
ROUNDING_DECIMAL = 4

def mase_calculation(ts, prediction):
    divisor = 0
    for i in range(1, ts.shape[0]):
        divisor = divisor + abs(ts.iloc[i] - ts.iloc[i-1])
    divisor = divisor/(ts.shape[0] - 1)
    diff    = abs(ts - prediction[:ts.shape[0]])/divisor
    mase    = diff.mean()
    return mase

def mape_calculation(actual, pred): 
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    mask = (actual != 0)
    return round((np.fabs(actual - pred)/actual)[mask].mean()*100, ROUNDING_DECIMAL)

def wmape_calculation(actual, pred):
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    return round((np.sum(np.absolute(actual-pred))/np.sum(actual))*100, ROUNDING_DECIMAL)

def smape_calculation(actual, predicted):
    if not all([isinstance(actual, np.ndarray), isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, ROUNDING_DECIMAL)

# %% [markdown]
# # Format sales data and then merge with calendar data

# %%
sales_pattern = sales_erratic.copy()

# %%
sales_pattern_py = sales_pattern.copy()

list_pattern_py = sales_pattern_py.id.unique().tolist()
list_pattern_py = [(re.sub(r'_validation', r"", x)) for x in list_pattern_py]

sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
df_pattern.drop('Date', axis=1, inplace=True)
df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
df_pattern.index.names = ['Date']
df_pattern = df_pattern.astype('float64')

df_pattern.iloc[:, 1:].columns = df_pattern.iloc[:, 1:].columns.str.rstrip('_validation')
df_pattern.columns = df_pattern.columns.str.replace(r'_validation', '')
df_pattern.reset_index(inplace=True)

calendar['Date'] = pd.to_datetime(calendar['date'])

dataframe = pd.merge(df_pattern,
                     calendar[['wm_yr_wk', 'Date']],
                     on = 'Date')

not_enough_seven_days = dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})[dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})['Date'] < 7].index.tolist()
dataframe = dataframe[~dataframe['wm_yr_wk'].isin(not_enough_seven_days)]

dataframe.set_index('wm_yr_wk', inplace=True)
dataframe.drop('Date', axis=1, inplace=True)

dataframe_weekly = dataframe.groupby('wm_yr_wk').sum().reset_index()

# %%
dataframe_weekly
# Out:
#      wm_yr_wk  HOBBIES_1_002_CA_1  HOBBIES_1_003_CA_1  HOBBIES_1_008_CA_3  \
# 0       11101                 1.0                 0.0                82.0
# 1       11102                 1.0                 0.0                40.0
# 2       11103                 0.0                 0.0                23.0
# 3       11104                 1.0                 0.0                92.0
# 4       11105                 1.0                 0.0                35.0
# ..        ...                 ...                 ...                 ...
# 268     11608                 0.0                 0.0                74.0
# 269     11609                 3.0                 0.0                48.0
# 270     11610                 2.0                 0.0                53.0
# 271     11611                 1.0                 0.0                71.0
# 272     11612                 0.0                 0.0                28.0
#
#      HOBBIES_1_009_CA_2  HOBBIES_1_032_CA_3  HOBBIES_1_047_CA_2  \
# 0                   7.0                68.0                 7.0
# 1                  13.0                30.0                 5.0
# 2                   6.0                24.0                 5.0
# 3                   3.0                38.0                 2.0
# 4                   3.0                50.0                 6.0
# ..                  ...                 ...                 ...
# 268                 5.0                23.0                 2.0
# 269                 9.0                37.0                11.0
# 270                 4.0                34.0                 2.0
# 271                 8.0                36.0                 6.0
# 272                 9.0                25.0                 1.0
#
#      HOBBIES_1_066_CA_4  HOBBIES_1_067_CA_2  HOBBIES_1_076_CA_1  ...  \
# 0                   1.0                55.0                 1.0  ...
# 1                   4.0                 5.0                 0.0  ...
# 2                   2.0                 0.0                 2.0  ...
# 3                   2.0                 0.0                 2.0  ...
# 4                   4.0                 2.0                 5.0  ...
# ..                  ...                 ...                 ...  ...
# 268                 2.0                11.0                 6.0  ...
# 269                 1.0                34.0                 2.0  ...
# 270                 8.0                 3.0                 3.0  ...
# 271                 2.0                32.0                 0.0  ...
# 272                 1.0                20.0                 1.0  ...
#
#      HOBBIES_2_116_CA_2  HOBBIES_2_121_CA_2  HOBBIES_2_124_CA_2  \
# 0                   3.0                 0.0                13.0
# 1                   1.0                 0.0                17.0
# 2                   3.0                 0.0                 2.0
# 3                   2.0                 0.0                 2.0
# 4                   1.0                 0.0                 1.0
# ..                  ...                 ...                 ...
# 268                 0.0                 0.0                10.0
# 269                 0.0                 0.0                 8.0
# 270                 3.0                 0.0                22.0
# 271                 3.0                 0.0                11.0
# 272                 1.0                 0.0                19.0
#
#      HOBBIES_2_126_CA_3  HOBBIES_2_129_CA_1  HOBBIES_2_129_CA_2  \
# 0                   0.0                 2.0                 8.0
# 1                   0.0                14.0                21.0
# 2                   0.0                18.0                 8.0
# 3                   0.0                12.0                 5.0
# 4                   0.0                 4.0                 6.0
# ..                  ...                 ...                 ...
# 268                 0.0                 3.0                 0.0
# 269                 0.0                 1.0                 5.0
# 270                 0.0                 6.0                 2.0
# 271                 0.0                11.0                11.0
# 272                 0.0                11.0                 9.0
#
#      HOBBIES_2_132_CA_2  HOBBIES_2_142_CA_2  HOBBIES_2_142_CA_3  \
# 0                   0.0                32.0                 7.0
# 1                   0.0                 0.0                22.0
# 2                   0.0                 2.0                 0.0
# 3                   0.0                 2.0                 4.0
# 4                   0.0                 7.0                27.0
# ..                  ...                 ...                 ...
# 268                 0.0                 2.0                34.0
# 269                 0.0                15.0                24.0
# 270                 0.0                14.0                21.0
# 271                 0.0                16.0                 4.0
# 272                 0.0                23.0                35.0
#
#      HOBBIES_2_147_CA_2
# 0                   0.0
# 1                   1.0
# 2                   2.0
# 3                   2.0
# 4                   7.0
# ..                  ...
# 268                 4.0
# 269                10.0
# 270                 4.0
# 271                 2.0
# 272                 2.0
#
# [273 rows x 100 columns]

# %%
lags = list(range(1, 25))
moving_averages = list(range(1, 25)) 
stds = list(range(2, 25))
maximums = list(range(1, 25))
minimums = list(range(1, 25))
totals = list(range(1, 25))
num_days_zeros = list(range(1, 25))

correlation_threshold = 0.8

end_train_week = 11610

num_id_sample_for_tuning = 50

# %%
sample_list = sample(list_pattern_py, num_id_sample_for_tuning)

# %%
dataframe_check = dataframe_weekly[sample_list].iloc[-2:].T

dataframe_check['Check'] = np.where((dataframe_check[271] == 0) &
                                    (dataframe_check[272] == 0), 1, 0)

sample_removed = dataframe_check[dataframe_check['Check'] == 1].index.tolist()

# %%
sample_list_filtered = [x for x in sample_list if (x not in sample_removed)]

# %%
len(sample_list_filtered)
# Out:
# 37

# %%
start = timer()

df_output_hyper_params = pd.DataFrame()
    
for product in sample_list_filtered:
    print('Currently Running: %s' % product)
    print('Progressing: {0} %'.format(round(sample_list_filtered.index(product) / len(sample_list_filtered) * 100, 2)))

    dataframe_product = dataframe_weekly[['wm_yr_wk', product]]

    # Create Lag variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (t-{lag})': dataframe_product[product].shift(lag)
        for lag in lags
    })

    # Create Rolling Moving Average variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
        for moving_average in moving_averages
    })

    # Create Rolling Standard Deviation variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
        for std in stds
    })

    # Create Rolling Maximum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
        for maximum in maximums
    })

    # Create Rolling Minimum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
        for minimum in minimums
    })

    # Create Rolling Total variables 
    dataframe_product = dataframe_product.assign(**{
        f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
        for total in totals
    })


    dataframe_product.dropna(inplace=True)
    dataframe_product.set_index('wm_yr_wk', inplace=True)

    train_data = dataframe_product[dataframe_product.index <= end_train_week]

    corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
    high_corr_var=np.where(corr_matrix > correlation_threshold)
    high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

    train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

    X_train = train_data.drop(product, axis=1)
    y_train = train_data[product]  

    tscv = TimeSeriesSplit(n_splits=3)

    params = {'n_estimators': [30, 50],
              'max_depth': list(range(3,11)),
              'min_samples_leaf': range(4,11),
              'max_features': ['sqrt', 'log2', None],
              'bootstrap': [True], #We force bootstrap
              'max_samples': [0.6, 0.7, 0.8, 0.9]}

    forest = RandomForestRegressor(n_jobs=1)

    regressor = RandomizedSearchCV(estimator=forest,
                                  param_distributions=params,
                                  cv = tscv, 
                                  scoring='neg_mean_absolute_percentage_error',
                                  n_iter=150,
                                  verbose=1)
    regressor.fit(X_train, y_train)
    best_params_temp = regressor.best_params_

    df_output_temp = pd.DataFrame.from_dict(best_params_temp, orient='index').T
    df_output_temp['Product'] = product

    df_output_hyper_params = df_output_hyper_params.append(df_output_temp, ignore_index=True)

    
end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: FOODS_3_514_CA_3
# Progressing: 0.0 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_582_CA_4
# Progressing: 0.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_069_CA_3
# Progressing: 1.27 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_116_CA_3
# Progressing: 1.91 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_629_CA_4
# Progressing: 2.55 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_042_CA_3
# Progressing: 3.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_607_CA_3
# Progressing: 3.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_150_CA_3
# Progressing: 4.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_656_CA_3
# Progressing: 5.1 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_028_CA_2
# Progressing: 5.73 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_446_CA_2
# Progressing: 6.37 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_004_CA_2
# Progressing: 7.01 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_427_CA_4
# Progressing: 7.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_218_CA_3
# Progressing: 8.28 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_757_CA_3
# Progressing: 8.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_605_CA_3
# Progressing: 9.55 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_464_CA_2
# Progressing: 10.19 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_432_CA_3
# Progressing: 10.83 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_787_CA_3
# Progressing: 11.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_008_CA_2
# Progressing: 12.1 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_014_CA_1
# Progressing: 12.74 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_082_CA_2
# Progressing: 13.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_629_CA_1
# Progressing: 14.01 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_180_CA_3
# Progressing: 14.65 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_054_CA_3
# Progressing: 15.29 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_224_CA_3
# Progressing: 15.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_514_CA_2
# Progressing: 16.56 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_772_CA_1
# Progressing: 17.2 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_190_CA_4
# Progressing: 17.83 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_128_CA_3
# Progressing: 18.47 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_070_CA_2
# Progressing: 19.11 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_388_CA_3
# Progressing: 19.75 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_479_CA_4
# Progressing: 20.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_003_CA_4
# Progressing: 21.02 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_130_CA_3
# Progressing: 21.66 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_579_CA_4
# Progressing: 22.29 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_027_CA_3
# Progressing: 22.93 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_343_CA_3
# Progressing: 23.57 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_341_CA_3
# Progressing: 24.2 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_027_CA_1
# Progressing: 24.84 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_162_CA_3
# Progressing: 25.48 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_066_CA_3
# Progressing: 26.11 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_285_CA_3
# Progressing: 26.75 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_059_CA_2
# Progressing: 27.39 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_052_CA_3
# Progressing: 28.03 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_055_CA_4
# Progressing: 28.66 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_454_CA_2
# Progressing: 29.3 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_455_CA_3
# Progressing: 29.94 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_311_CA_3
# Progressing: 30.57 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_211_CA_3
# Progressing: 31.21 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_787_CA_2
# Progressing: 31.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_118_CA_2
# Progressing: 32.48 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_022_CA_3
# Progressing: 33.12 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_332_CA_1
# Progressing: 33.76 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_352_CA_3
# Progressing: 34.39 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_672_CA_4
# Progressing: 35.03 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_331_CA_3
# Progressing: 35.67 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_313_CA_1
# Progressing: 36.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_313_CA_3
# Progressing: 36.94 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_113_CA_4
# Progressing: 37.58 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_811_CA_2
# Progressing: 38.22 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_376_CA_1
# Progressing: 38.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_513_CA_2
# Progressing: 39.49 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_432_CA_1
# Progressing: 40.13 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_267_CA_3
# Progressing: 40.76 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_809_CA_2
# Progressing: 41.4 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_306_CA_4
# Progressing: 42.04 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_306_CA_2
# Progressing: 42.68 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_135_CA_2
# Progressing: 43.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_454_CA_4
# Progressing: 43.95 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_672_CA_3
# Progressing: 44.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_100_CA_3
# Progressing: 45.22 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_629_CA_2
# Progressing: 45.86 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_399_CA_3
# Progressing: 46.5 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_274_CA_3
# Progressing: 47.13 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_816_CA_3
# Progressing: 47.77 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_030_CA_3
# Progressing: 48.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_281_CA_3
# Progressing: 49.04 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_328_CA_4
# Progressing: 49.68 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_154_CA_4
# Progressing: 50.32 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_611_CA_3
# Progressing: 50.96 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_055_CA_1
# Progressing: 51.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_206_CA_2
# Progressing: 52.23 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_589_CA_1
# Progressing: 52.87 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_058_CA_1
# Progressing: 53.5 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_546_CA_4
# Progressing: 54.14 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_425_CA_3
# Progressing: 54.78 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_021_CA_3
# Progressing: 55.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_705_CA_4
# Progressing: 56.05 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_652_CA_2
# Progressing: 56.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_368_CA_4
# Progressing: 57.32 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_314_CA_3
# Progressing: 57.96 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_021_CA_3
# Progressing: 58.6 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_008_CA_4
# Progressing: 59.24 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_088_CA_4
# Progressing: 59.87 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_185_CA_3
# Progressing: 60.51 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_283_CA_4
# Progressing: 61.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_427_CA_3
# Progressing: 61.78 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_203_CA_2
# Progressing: 62.42 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_752_CA_2
# Progressing: 63.06 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_461_CA_3
# Progressing: 63.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_132_CA_2
# Progressing: 64.33 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_068_CA_1
# Progressing: 64.97 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_656_CA_2
# Progressing: 65.61 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_032_CA_3
# Progressing: 66.24 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_770_CA_1
# Progressing: 66.88 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_579_CA_3
# Progressing: 67.52 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_536_CA_2
# Progressing: 68.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_376_CA_2
# Progressing: 68.79 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_124_CA_3
# Progressing: 69.43 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_022_CA_3
# Progressing: 70.06 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_115_CA_3
# Progressing: 70.7 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_437_CA_2
# Progressing: 71.34 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_688_CA_2
# Progressing: 71.97 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_255_CA_3
# Progressing: 72.61 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_313_CA_4
# Progressing: 73.25 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_778_CA_3
# Progressing: 73.89 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_788_CA_1
# Progressing: 74.52 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_128_CA_2
# Progressing: 75.16 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_086_CA_3
# Progressing: 75.8 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_672_CA_1
# Progressing: 76.43 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_565_CA_2
# Progressing: 77.07 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_085_CA_3
# Progressing: 77.71 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_132_CA_1
# Progressing: 78.34 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_334_CA_3
# Progressing: 78.98 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_672_CA_2
# Progressing: 79.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_783_CA_3
# Progressing: 80.25 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_463_CA_1
# Progressing: 80.89 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_128_CA_2
# Progressing: 81.53 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_376_CA_4
# Progressing: 82.17 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_702_CA_3
# Progressing: 82.8 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_809_CA_3
# Progressing: 83.44 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_007_CA_4
# Progressing: 84.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_245_CA_2
# Progressing: 84.71 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_276_CA_3
# Progressing: 85.35 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_114_CA_3
# Progressing: 85.99 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_143_CA_4
# Progressing: 86.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_118_CA_3
# Progressing: 87.26 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_624_CA_3
# Progressing: 87.9 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_095_CA_2
# Progressing: 88.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_660_CA_1
# Progressing: 89.17 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_454_CA_3
# Progressing: 89.81 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_078_CA_3
# Progressing: 90.45 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_616_CA_1
# Progressing: 91.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_594_CA_2
# Progressing: 91.72 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_332_CA_3
# Progressing: 92.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_787_CA_1
# Progressing: 92.99 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_241_CA_4
# Progressing: 93.63 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_169_CA_3
# Progressing: 94.27 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_1_132_CA_4
# Progressing: 94.9 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_700_CA_3
# Progressing: 95.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_816_CA_4
# Progressing: 96.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_116_CA_4
# Progressing: 96.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_811_CA_4
# Progressing: 97.45 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_2_165_CA_3
# Progressing: 98.09 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_154_CA_3
# Progressing: 98.73 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: FOODS_3_566_CA_4
# Progressing: 99.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# This line of code took 74.57009853856668 minutes

# %%
df_output_hyper_params.to_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/Random Forest (Completed Pipeline)/Foods/Erratic_Params_Tuning_Random Forest.csv')

# %% [markdown]
# # Decide optimum set of parameters for Random Forest algorithm

# %%
# See if any values larger than 1 in column "Product"
# If yes, the corresponding set of parameters occur more than once and those sets should be considered first
df_output_hyper_params.groupby(['n_estimators', 'max_depth', 'min_samples_leaf', 'max_features', 'max_samples'])[['Product']].count().sort_values(by = 'Product', ascending=False)
# Out:
#                                                                   Product
# n_estimators max_depth min_samples_leaf max_features max_samples
# 30           3         4                sqrt         0.7                1
#              4         4                sqrt         0.6                1
# 50           8         6                sqrt         0.6                1
#              6         4                sqrt         0.6                1
#              3         4                sqrt         0.6                1
#                                         log2         0.6                1
# 30           10        7                sqrt         0.9                1
#                                                      0.8                1
#                        4                sqrt         0.7                1
#                                         log2         0.7                1
#              9         7                log2         0.9                1
#                        5                sqrt         0.9                1
#                                                      0.8                1
#              8         10               sqrt         0.7                1
#                        6                sqrt         0.6                1
#                        5                log2         0.6                1
#                        4                log2         0.7                1
#              6         10               sqrt         0.6                1
#                        8                log2         0.6                1
#                        7                log2         0.9                1
#                                                      0.6                1
#              5         9                sqrt         0.7                1
#                                                      0.6                1
#                        8                sqrt         0.6                1
#                        5                sqrt         0.9                1
#                                         log2         0.9                1
#              4         8                sqrt         0.8                1
# 50           10        8                sqrt         0.9                1

# %%
df_output_hyper_params.groupby(['n_estimators'])[['Product']].count()
# Out:
#               Product
# n_estimators
# 30                108
# 50                 49

# %%
df_output_hyper_params.groupby(['max_depth'])[['Product']].count()
# Out:
#            Product
# max_depth
# 3               14
# 4               19
# 5               24
# 6               23
# 7               14
# 8               24
# 9               18
# 10              21

# %%
# See what value of parameter "max_depth" occurs the most frequently
df_output_hyper_params.groupby(['min_samples_leaf'])[['Product']].count()
# Out:
#                   Product
# min_samples_leaf
# 4                      39
# 5                      25
# 6                      16
# 7                      17
# 8                      22
# 9                      16
# 10                     22

# %%
# See what value of parameter "learning_rate" occurs the most frequently
df_output_hyper_params.groupby(['max_features'])[['Product']].count()
# Out:
#               Product
# max_features
# log2                9
# sqrt               19

# %%
# See what value of parameter "colsample_bytree" occurs the most frequently
df_output_hyper_params.groupby(['max_samples'])[['Product']].count()
# Out:
#              Product
# max_samples
# 0.6               38
# 0.7               32
# 0.8               37
# 0.9               50

# %% [markdown]
# # Implement Random Forest on Test Set with optimum set of parameters

# %% [markdown]
# ### Specify optimum set of parameters

# %%
n_estimators_chosen = 30
max_depth_chosen = 6
min_samples_leaf_chosen = 4
max_features_chosen = 'sqrt'
max_samples_chosen = 0.9

# %%
len(list_pattern_py)
# Out:
# 99

# %%
list_pattern_temp = list_pattern_py.copy()

# %%
start = timer()

df_output_rf_pattern = pd.DataFrame()
for product in list_pattern_temp:
  print('Currently Running: %s' % product)
  print('Progressing: {0} %'.format(round(list_pattern_temp.index(product) / len(list_pattern_temp) * 100, 2)))
  dataframe_product = dataframe_weekly[['wm_yr_wk', product]]
  # Create Lag variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (t-{lag})': dataframe_product[product].shift(lag)
      for lag in lags
  })

  # Create Rolling Moving Average variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
      for moving_average in moving_averages
  })

  # Create Rolling Standard Deviation variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
      for std in stds
  })

  # Create Rolling Maximum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
      for maximum in maximums
  })

  # Create Rolling Minimum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
      for minimum in minimums
  })

  # Create Rolling Total variables 
  dataframe_product = dataframe_product.assign(**{
      f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
      for total in totals
  })

  dataframe_product.dropna(inplace=True)
  dataframe_product.set_index('wm_yr_wk', inplace=True)

  train_data = dataframe_product[dataframe_product.index <= end_train_week]
  test_data = dataframe_product[dataframe_product.index > end_train_week]

  corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
  high_corr_var=np.where(corr_matrix > correlation_threshold)
  high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

  train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)
  test_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

  X_train = train_data.drop(product, axis=1)
  y_train = train_data[product]

  X_test = test_data.drop(product, axis=1)
  y_test = test_data[product]

  forest = RandomForestRegressor(n_jobs=1,
                                n_estimators = n_estimators_chosen,
                                min_samples_leaf = min_samples_leaf_chosen,
                                max_samples = max_samples_chosen,
                                max_features = max_features_chosen,
                                max_depth = max_depth_chosen,
                                bootstrap = [True],
                                random_state = 0)
  

  forest.fit(X_train,y_train)
  y_pred = forest.predict(X_test)
  df_output_temp = pd.DataFrame({'Actual Data': y_test, 
                                  'Forecast': y_pred, 
                                  'Product': [product for num_rows in range(len(y_pred))]
                                  })
  
  df_output_rf_pattern = df_output_rf_pattern.append(df_output_temp, ignore_index=False)  

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: HOBBIES_1_002_CA_1
# Progressing: 0.0 %
# Currently Running: HOBBIES_1_003_CA_1
# Progressing: 1.01 %
# Currently Running: HOBBIES_1_076_CA_1
# Progressing: 2.02 %
# Currently Running: HOBBIES_1_080_CA_1
# Progressing: 3.03 %
# Currently Running: HOBBIES_1_091_CA_1
# Progressing: 4.04 %
# Currently Running: HOBBIES_1_111_CA_1
# Progressing: 5.05 %
# Currently Running: HOBBIES_1_115_CA_1
# Progressing: 6.06 %
# Currently Running: HOBBIES_1_121_CA_1
# Progressing: 7.07 %
# Currently Running: HOBBIES_1_142_CA_1
# Progressing: 8.08 %
# Currently Running: HOBBIES_1_161_CA_1
# Progressing: 9.09 %
# Currently Running: HOBBIES_1_193_CA_1
# Progressing: 10.1 %
# Currently Running: HOBBIES_1_220_CA_1
# Progressing: 11.11 %
# Currently Running: HOBBIES_1_232_CA_1
# Progressing: 12.12 %
# Currently Running: HOBBIES_1_248_CA_1
# Progressing: 13.13 %
# Currently Running: HOBBIES_1_255_CA_1
# Progressing: 14.14 %
# Currently Running: HOBBIES_1_316_CA_1
# Progressing: 15.15 %
# Currently Running: HOBBIES_1_408_CA_1
# Progressing: 16.16 %
# Currently Running: HOBBIES_1_418_CA_1
# Progressing: 17.17 %
# Currently Running: HOBBIES_2_009_CA_1
# Progressing: 18.18 %
# Currently Running: HOBBIES_2_026_CA_1
# Progressing: 19.19 %
# Currently Running: HOBBIES_2_041_CA_1
# Progressing: 20.2 %
# Currently Running: HOBBIES_2_053_CA_1
# Progressing: 21.21 %
# Currently Running: HOBBIES_2_059_CA_1
# Progressing: 22.22 %
# Currently Running: HOBBIES_2_070_CA_1
# Progressing: 23.23 %
# Currently Running: HOBBIES_2_091_CA_1
# Progressing: 24.24 %
# Currently Running: HOBBIES_2_129_CA_1
# Progressing: 25.25 %
# Currently Running: HOBBIES_1_009_CA_2
# Progressing: 26.26 %
# Currently Running: HOBBIES_1_047_CA_2
# Progressing: 27.27 %
# Currently Running: HOBBIES_1_067_CA_2
# Progressing: 28.28 %
# Currently Running: HOBBIES_1_103_CA_2
# Progressing: 29.29 %
# Currently Running: HOBBIES_1_202_CA_2
# Progressing: 30.3 %
# Currently Running: HOBBIES_1_211_CA_2
# Progressing: 31.31 %
# Currently Running: HOBBIES_1_216_CA_2
# Progressing: 32.32 %
# Currently Running: HOBBIES_1_227_CA_2
# Progressing: 33.33 %
# Currently Running: HOBBIES_1_246_CA_2
# Progressing: 34.34 %
# Currently Running: HOBBIES_1_248_CA_2
# Progressing: 35.35 %
# Currently Running: HOBBIES_1_277_CA_2
# Progressing: 36.36 %
# Currently Running: HOBBIES_1_288_CA_2
# Progressing: 37.37 %
# Currently Running: HOBBIES_1_312_CA_2
# Progressing: 38.38 %
# Currently Running: HOBBIES_1_316_CA_2
# Progressing: 39.39 %
# Currently Running: HOBBIES_1_379_CA_2
# Progressing: 40.4 %
# Currently Running: HOBBIES_1_398_CA_2
# Progressing: 41.41 %
# Currently Running: HOBBIES_1_400_CA_2
# Progressing: 42.42 %
# Currently Running: HOBBIES_1_408_CA_2
# Progressing: 43.43 %
# Currently Running: HOBBIES_1_417_CA_2
# Progressing: 44.44 %
# Currently Running: HOBBIES_2_007_CA_2
# Progressing: 45.45 %
# Currently Running: HOBBIES_2_026_CA_2
# Progressing: 46.46 %
# Currently Running: HOBBIES_2_038_CA_2
# Progressing: 47.47 %
# Currently Running: HOBBIES_2_053_CA_2
# Progressing: 48.48 %
# Currently Running: HOBBIES_2_059_CA_2
# Progressing: 49.49 %
# Currently Running: HOBBIES_2_068_CA_2
# Progressing: 50.51 %
# Currently Running: HOBBIES_2_070_CA_2
# Progressing: 51.52 %
# Currently Running: HOBBIES_2_091_CA_2
# Progressing: 52.53 %
# Currently Running: HOBBIES_2_116_CA_2
# Progressing: 53.54 %
# Currently Running: HOBBIES_2_121_CA_2
# Progressing: 54.55 %
# Currently Running: HOBBIES_2_124_CA_2
# Progressing: 55.56 %
# Currently Running: HOBBIES_2_129_CA_2
# Progressing: 56.57 %
# Currently Running: HOBBIES_2_132_CA_2
# Progressing: 57.58 %
# Currently Running: HOBBIES_2_142_CA_2
# Progressing: 58.59 %
# Currently Running: HOBBIES_2_147_CA_2
# Progressing: 59.6 %
# Currently Running: HOBBIES_1_008_CA_3
# Progressing: 60.61 %
# Currently Running: HOBBIES_1_032_CA_3
# Progressing: 61.62 %
# Currently Running: HOBBIES_1_080_CA_3
# Progressing: 62.63 %
# Currently Running: HOBBIES_1_091_CA_3
# Progressing: 63.64 %
# Currently Running: HOBBIES_1_121_CA_3
# Progressing: 64.65 %
# Currently Running: HOBBIES_1_140_CA_3
# Progressing: 65.66 %
# Currently Running: HOBBIES_1_169_CA_3
# Progressing: 66.67 %
# Currently Running: HOBBIES_1_198_CA_3
# Progressing: 67.68 %
# Currently Running: HOBBIES_1_223_CA_3
# Progressing: 68.69 %
# Currently Running: HOBBIES_1_234_CA_3
# Progressing: 69.7 %
# Currently Running: HOBBIES_1_248_CA_3
# Progressing: 70.71 %
# Currently Running: HOBBIES_1_255_CA_3
# Progressing: 71.72 %
# Currently Running: HOBBIES_1_288_CA_3
# Progressing: 72.73 %
# Currently Running: HOBBIES_1_312_CA_3
# Progressing: 73.74 %
# Currently Running: HOBBIES_1_318_CA_3
# Progressing: 74.75 %
# Currently Running: HOBBIES_1_331_CA_3
# Progressing: 75.76 %
# Currently Running: HOBBIES_1_380_CA_3
# Progressing: 76.77 %
# Currently Running: HOBBIES_1_400_CA_3
# Progressing: 77.78 %
# Currently Running: HOBBIES_1_408_CA_3
# Progressing: 78.79 %
# Currently Running: HOBBIES_1_414_CA_3
# Progressing: 79.8 %
# Currently Running: HOBBIES_1_417_CA_3
# Progressing: 80.81 %
# Currently Running: HOBBIES_2_028_CA_3
# Progressing: 81.82 %
# Currently Running: HOBBIES_2_059_CA_3
# Progressing: 82.83 %
# Currently Running: HOBBIES_2_070_CA_3
# Progressing: 83.84 %
# Currently Running: HOBBIES_2_071_CA_3
# Progressing: 84.85 %
# Currently Running: HOBBIES_2_090_CA_3
# Progressing: 85.86 %
# Currently Running: HOBBIES_2_100_CA_3
# Progressing: 86.87 %
# Currently Running: HOBBIES_2_103_CA_3
# Progressing: 87.88 %
# Currently Running: HOBBIES_2_126_CA_3
# Progressing: 88.89 %
# Currently Running: HOBBIES_2_142_CA_3
# Progressing: 89.9 %
# Currently Running: HOBBIES_1_066_CA_4
# Progressing: 90.91 %
# Currently Running: HOBBIES_1_119_CA_4
# Progressing: 91.92 %
# Currently Running: HOBBIES_1_140_CA_4
# Progressing: 92.93 %
# Currently Running: HOBBIES_1_145_CA_4
# Progressing: 93.94 %
# Currently Running: HOBBIES_1_150_CA_4
# Progressing: 94.95 %
# Currently Running: HOBBIES_1_156_CA_4
# Progressing: 95.96 %
# Currently Running: HOBBIES_1_202_CA_4
# Progressing: 96.97 %
# Currently Running: HOBBIES_1_223_CA_4
# Progressing: 97.98 %
# Currently Running: HOBBIES_1_277_CA_4
# Progressing: 98.99 %
# This line of code took 0.36533609233333286 minutes

# %%
df_output_rf_pattern
# Out:
#           Actual Data   Forecast             Product
# wm_yr_wk
# 11611             1.0   1.967203  HOBBIES_1_002_CA_1
# 11612             0.0   1.638180  HOBBIES_1_002_CA_1
# 11611             0.0   0.002659  HOBBIES_1_003_CA_1
# 11612             0.0   0.002659  HOBBIES_1_003_CA_1
# 11611             0.0   4.371975  HOBBIES_1_076_CA_1
# ...               ...        ...                 ...
# 11612             5.0   8.197826  HOBBIES_1_202_CA_4
# 11611             0.0   2.087208  HOBBIES_1_223_CA_4
# 11612             0.0   2.815652  HOBBIES_1_223_CA_4
# 11611             2.0  11.367482  HOBBIES_1_277_CA_4
# 11612             7.0  12.872821  HOBBIES_1_277_CA_4
#
# [198 rows x 3 columns]

# %%
df_output_rf_pattern.to_csv('Erratic_Random_Forest_Forecast_Values.csv')

# %%
# User-defined funcion to calculate metrics

def get_metrics_result_all_params(data):
    metrics_df = {}
    metrics_df['MASE'] = mase_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['WMAPE'] = wmape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['SMAPE'] = smape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAPE'] = mape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAE'] = mean_absolute_error(data['Actual Data'], data['Forecast'])
    metrics_df['RMSE'] = np.sqrt(mean_squared_error(data['Actual Data'], data['Forecast']))
    return pd.Series(metrics_df)

# %%
# Start calculating metrics 
start = timer()

df_forecast_metrics = df_output_rf_pattern.groupby('Product').apply(get_metrics_result_all_params).reset_index()

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 0.0031633714500003407 minutes

# %%
df_forecast_metrics
# Out:
#                Product      MASE     WMAPE     SMAPE      MAPE        MAE  \
# 0   HOBBIES_1_002_CA_1  1.302692  260.5383  132.5965   96.7203   1.302692
# 1   HOBBIES_1_003_CA_1       inf       inf  200.0000       NaN   0.002659
# 2   HOBBIES_1_008_CA_3  0.550489   47.8202   48.6375   66.8646  23.671010
# 3   HOBBIES_1_009_CA_2  1.840683   21.6551   24.2654   21.0514   1.840683
# 4   HOBBIES_1_032_CA_3  0.374199   13.4957   13.0217   11.6978   4.116193
# ..                 ...       ...       ...       ...       ...        ...
# 94  HOBBIES_2_129_CA_2  1.747393   34.9479   43.8036   35.6411   3.494786
# 95  HOBBIES_2_132_CA_2       inf       inf  200.0000       NaN   0.044657
# 96  HOBBIES_2_142_CA_2  1.326352   47.6126   60.7021   46.1169   9.284462
# 97  HOBBIES_2_142_CA_3  0.507874   80.7390   95.6651  215.3492  15.744100
# 98  HOBBIES_2_147_CA_2       inf    0.4620    0.4613    0.4620   0.009239
#
#          RMSE
# 0    1.345198
# 1    0.002659
# 2   24.779361
# 3    2.084146
# 4    5.524192
# ..        ...
# 94   3.510980
# 95   0.044657
# 96   9.833266
# 97  15.748129
# 98   0.009738
#
# [99 rows x 7 columns]

# %%
df_forecast_metrics.to_csv('Random_Forest_Erratic_Forecast_Metrics.csv')
