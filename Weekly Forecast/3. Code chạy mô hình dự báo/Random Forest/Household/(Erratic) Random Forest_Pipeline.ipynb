# %% [markdown]
# # Import necessary packages

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from random import sample

import re

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

from timeit import default_timer as timer

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import original data and preprocessed data

# %%
sales_train_val = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/sales_train_validation.csv')
calendar = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/calendar.csv')

# %% [markdown]
# **Note: This Step is for the extraction of California State and Foods category**

# %%
sales_train_val = sales_train_val[(sales_train_val['state_id'] == 'CA') & (sales_train_val['cat_id'] == 'HOUSEHOLD')]

# %%
sales_train_val
# Out:
#                                     id          item_id      dept_id  \
# 565    HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 566    HOUSEHOLD_1_002_CA_1_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 568    HOUSEHOLD_1_004_CA_1_validation  HOUSEHOLD_1_004  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
# 10756  HOUSEHOLD_2_514_CA_4_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
# 10757  HOUSEHOLD_2_515_CA_4_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 10758  HOUSEHOLD_2_516_CA_4_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565    HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 566    HOUSEHOLD     CA_1       CA    1    1    2    4  ...       0       0
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 568    HOUSEHOLD     CA_1       CA    4    0    8   11  ...       0       5
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
# 10756  HOUSEHOLD     CA_4       CA    0    2    0    1  ...       0       0
# 10757  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10758  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565         1       1       1       0       0       0       0       1
# 566         0       0       0       1       0       0       0       1
# 567         1       2       1       0       0       0       1       0
# 568         0       0       0       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10754       0       0       2       1       0       0       0       0
# 10755       0       0       0       0       0       0       0       0
# 10756       1       0       0       0       0       0       0       0
# 10757       0       0       0       0       0       0       2       0
# 10758       0       0       0       0       0       0       0       1
#
# [4188 rows x 1919 columns]

# %%
INPUT_DIR_2 = r'/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/List of Product ID according to 4 demand patterns/California/Household'

list_intermittent = pd.read_csv(f'{INPUT_DIR_2}/Intermittent_ID.csv')
list_lumpy = pd.read_csv(f'{INPUT_DIR_2}/Lumpy_ID.csv')
list_erratic = pd.read_csv(f'{INPUT_DIR_2}/Erratic_ID.csv')
list_smooth = pd.read_csv(f'{INPUT_DIR_2}/Smooth_ID.csv')

list_intermittent = list_intermittent['0'].values.tolist()
list_lumpy = list_lumpy['0'].values.tolist()
list_erratic = list_erratic['0'].values.tolist()
list_smooth = list_smooth['0'].values.tolist()

sales_intermittent = sales_train_val[sales_train_val.id.isin(list_intermittent)]
sales_lumpy = sales_train_val[sales_train_val.id.isin(list_lumpy)]
sales_erratic = sales_train_val[sales_train_val.id.isin(list_erratic)]
sales_smooth = sales_train_val[sales_train_val.id.isin(list_smooth)]

# %%
len(sales_intermittent)
# Out:
# 1493

# %%
len(sales_lumpy)
# Out:
# 178

# %%
len(sales_erratic)
# Out:
# 126

# %%
len(sales_smooth)
# Out:
# 2391

# %% [markdown]
# **Check by looking at column "id" to verify if we choose the right product (FOODS or HOBBIES or HOUSEHOLD)**

# %%
sales_erratic
# Out:
#                                     id          item_id      dept_id  \
# 565    HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 593    HOUSEHOLD_1_029_CA_1_validation  HOUSEHOLD_1_029  HOUSEHOLD_1
# 627    HOUSEHOLD_1_065_CA_1_validation  HOUSEHOLD_1_065  HOUSEHOLD_1
# 673    HOUSEHOLD_1_113_CA_1_validation  HOUSEHOLD_1_113  HOUSEHOLD_1
# 692    HOUSEHOLD_1_132_CA_1_validation  HOUSEHOLD_1_132  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10208  HOUSEHOLD_1_506_CA_4_validation  HOUSEHOLD_1_506  HOUSEHOLD_1
# 10481  HOUSEHOLD_2_239_CA_4_validation  HOUSEHOLD_2_239  HOUSEHOLD_2
# 10543  HOUSEHOLD_2_301_CA_4_validation  HOUSEHOLD_2_301  HOUSEHOLD_2
# 10689  HOUSEHOLD_2_447_CA_4_validation  HOUSEHOLD_2_447  HOUSEHOLD_2
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565    HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 593    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 627    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 673    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       1       2
# 692    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10208  HOUSEHOLD     CA_4       CA    1    0    0    0  ...       3       0
# 10481  HOUSEHOLD     CA_4       CA    0    1    1    1  ...       2       1
# 10543  HOUSEHOLD     CA_4       CA    1    2    1    1  ...       0       0
# 10689  HOUSEHOLD     CA_4       CA    0    0    0   11  ...       0       6
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565         1       1       1       0       0       0       0       1
# 593         4       2       0       2       0       0       1       0
# 627         0       3       2       0       0       0       1       1
# 673         3       7       1       1       2       2       2       2
# 692         0       0       2       0       3       2       1       3
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10208       0       2       1       1       0       1       0       2
# 10481       0       3       0       0       1       2       2       1
# 10543       0       3       0       0       0       0       0       3
# 10689       0       0       0       0       4       0       1       1
# 10754       0       0       2       1       0       0       0       0
#
# [126 rows x 1919 columns]

# %% [markdown]
# # User-defined functions to calculate Metrics

# %%
ROUNDING_DECIMAL = 4

def mase_calculation(ts, prediction):
    divisor = 0
    for i in range(1, ts.shape[0]):
        divisor = divisor + abs(ts.iloc[i] - ts.iloc[i-1])
    divisor = divisor/(ts.shape[0] - 1)
    diff    = abs(ts - prediction[:ts.shape[0]])/divisor
    mase    = diff.mean()
    return mase

def mape_calculation(actual, pred): 
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    mask = (actual != 0)
    return round((np.fabs(actual - pred)/actual)[mask].mean()*100, ROUNDING_DECIMAL)

def wmape_calculation(actual, pred):
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    return round((np.sum(np.absolute(actual-pred))/np.sum(actual))*100, ROUNDING_DECIMAL)

def smape_calculation(actual, predicted):
    if not all([isinstance(actual, np.ndarray), isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, ROUNDING_DECIMAL)

# %% [markdown]
# # Format sales data and then merge with calendar data

# %%
sales_pattern = sales_erratic.copy()

# %%
sales_pattern_py = sales_pattern.copy()

list_pattern_py = sales_pattern_py.id.unique().tolist()
list_pattern_py = [(re.sub(r'_validation', r"", x)) for x in list_pattern_py]

sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
df_pattern.drop('Date', axis=1, inplace=True)
df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
df_pattern.index.names = ['Date']
df_pattern = df_pattern.astype('float64')

df_pattern.iloc[:, 1:].columns = df_pattern.iloc[:, 1:].columns.str.rstrip('_validation')
df_pattern.columns = df_pattern.columns.str.replace(r'_validation', '')
df_pattern.reset_index(inplace=True)

calendar['Date'] = pd.to_datetime(calendar['date'])

dataframe = pd.merge(df_pattern,
                     calendar[['wm_yr_wk', 'Date']],
                     on = 'Date')

not_enough_seven_days = dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})[dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})['Date'] < 7].index.tolist()
dataframe = dataframe[~dataframe['wm_yr_wk'].isin(not_enough_seven_days)]

dataframe.set_index('wm_yr_wk', inplace=True)
dataframe.drop('Date', axis=1, inplace=True)

dataframe_weekly = dataframe.groupby('wm_yr_wk').sum().reset_index()

# %%
dataframe_weekly
# Out:
#      wm_yr_wk  HOUSEHOLD_1_001_CA_1  HOUSEHOLD_1_002_CA_2  \
# 0       11101                   4.0                   7.0
# 1       11102                   0.0                   5.0
# 2       11103                   2.0                   2.0
# 3       11104                   0.0                   1.0
# 4       11105                   2.0                   7.0
# ..        ...                   ...                   ...
# 268     11608                   1.0                   1.0
# 269     11609                   0.0                   1.0
# 270     11610                   1.0                   9.0
# 271     11611                   2.0                   4.0
# 272     11612                   1.0                   4.0
#
#      HOUSEHOLD_1_004_CA_2  HOUSEHOLD_1_008_CA_2  HOUSEHOLD_1_028_CA_2  \
# 0                     2.0                   0.0                   7.0
# 1                     0.0                   5.0                   6.0
# 2                     0.0                   5.0                   0.0
# 3                     0.0                   4.0                   1.0
# 4                     0.0                  11.0                   5.0
# ..                    ...                   ...                   ...
# 268                   9.0                   6.0                   5.0
# 269                   5.0                   6.0                  13.0
# 270                  11.0                   5.0                   3.0
# 271                   0.0                   3.0                   7.0
# 272                   0.0                   3.0                   5.0
#
#      HOUSEHOLD_1_029_CA_1  HOUSEHOLD_1_033_CA_3  HOUSEHOLD_1_043_CA_3  \
# 0                     4.0                  16.0                   0.0
# 1                     9.0                  15.0                   0.0
# 2                     5.0                   7.0                   0.0
# 3                     6.0                  12.0                   0.0
# 4                     1.0                   7.0                   0.0
# ..                    ...                   ...                   ...
# 268                  12.0                   2.0                   0.0
# 269                  12.0                   2.0                   0.0
# 270                   9.0                   3.0                   0.0
# 271                   5.0                  13.0                   0.0
# 272                   9.0                   3.0                   0.0
#
#      HOUSEHOLD_1_065_CA_1  ...  HOUSEHOLD_2_447_CA_4  HOUSEHOLD_2_448_CA_3  \
# 0                    16.0  ...                   1.0                   0.0
# 1                    26.0  ...                   0.0                   0.0
# 2                    16.0  ...                   3.0                   0.0
# 3                    14.0  ...                   3.0                   0.0
# 4                    20.0  ...                   4.0                   0.0
# ..                    ...  ...                   ...                   ...
# 268                  21.0  ...                   5.0                   0.0
# 269                  28.0  ...                   2.0                   0.0
# 270                  28.0  ...                   1.0                   0.0
# 271                  24.0  ...                   5.0                   0.0
# 272                  25.0  ...                   2.0                   0.0
#
#      HOUSEHOLD_2_452_CA_3  HOUSEHOLD_2_460_CA_3  HOUSEHOLD_2_498_CA_1  \
# 0                     6.0                   1.0                   0.0
# 1                     8.0                   4.0                   0.0
# 2                     1.0                   1.0                   0.0
# 3                     9.0                   2.0                   0.0
# 4                     3.0                   1.0                   0.0
# ..                    ...                   ...                   ...
# 268                   1.0                   1.0                   0.0
# 269                   4.0                   2.0                   0.0
# 270                   6.0                   1.0                   0.0
# 271                   6.0                   1.0                   0.0
# 272                   4.0                   2.0                   0.0
#
#      HOUSEHOLD_2_498_CA_3  HOUSEHOLD_2_499_CA_2  HOUSEHOLD_2_511_CA_3  \
# 0                     0.0                   0.0                  31.0
# 1                     0.0                   0.0                  16.0
# 2                     0.0                   0.0                  25.0
# 3                     0.0                   0.0                  17.0
# 4                     0.0                   0.0                  14.0
# ..                    ...                   ...                   ...
# 268                   0.0                   0.0                  19.0
# 269                   0.0                   0.0                   9.0
# 270                   0.0                   0.0                  20.0
# 271                   0.0                   0.0                   4.0
# 272                   0.0                   0.0                   9.0
#
#      HOUSEHOLD_2_512_CA_4  HOUSEHOLD_2_513_CA_1
# 0                     8.0                   5.0
# 1                     1.0                   0.0
# 2                     0.0                   7.0
# 3                     0.0                   0.0
# 4                     1.0                   3.0
# ..                    ...                   ...
# 268                   6.0                   0.0
# 269                   0.0                   4.0
# 270                   1.0                   2.0
# 271                   1.0                   0.0
# 272                   5.0                   0.0
#
# [273 rows x 127 columns]

# %%
lags = list(range(1, 25))
moving_averages = list(range(1, 25)) 
stds = list(range(2, 25))
maximums = list(range(1, 25))
minimums = list(range(1, 25))
totals = list(range(1, 25))
num_days_zeros = list(range(1, 25))

correlation_threshold = 0.8

end_train_week = 11610

num_id_sample_for_tuning = 100

# %%
sample_list = sample(list_pattern_py, num_id_sample_for_tuning)

# %%
dataframe_check = dataframe_weekly[sample_list].iloc[-2:].T

dataframe_check['Check'] = np.where((dataframe_check[271] == 0) &
                                    (dataframe_check[272] == 0), 1, 0)

sample_removed = dataframe_check[dataframe_check['Check'] == 1].index.tolist()

# %%
sample_list_filtered = [x for x in sample_list if (x not in sample_removed)]

# %%
len(sample_list_filtered)
# Out:
# 78

# %%
start = timer()

df_output_hyper_params = pd.DataFrame()
    
for product in sample_list_filtered:
    print('Currently Running: %s' % product)
    print('Progressing: {0} %'.format(round(sample_list_filtered.index(product) / len(sample_list_filtered) * 100, 2)))

    dataframe_product = dataframe_weekly[['wm_yr_wk', product]]

    # Create Lag variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (t-{lag})': dataframe_product[product].shift(lag)
        for lag in lags
    })

    # Create Rolling Moving Average variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
        for moving_average in moving_averages
    })

    # Create Rolling Standard Deviation variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
        for std in stds
    })

    # Create Rolling Maximum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
        for maximum in maximums
    })

    # Create Rolling Minimum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
        for minimum in minimums
    })

    # Create Rolling Total variables 
    dataframe_product = dataframe_product.assign(**{
        f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
        for total in totals
    })


    dataframe_product.dropna(inplace=True)
    dataframe_product.set_index('wm_yr_wk', inplace=True)

    train_data = dataframe_product[dataframe_product.index <= end_train_week]

    corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
    high_corr_var=np.where(corr_matrix > correlation_threshold)
    high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

    train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

    X_train = train_data.drop(product, axis=1)
    y_train = train_data[product]  

    tscv = TimeSeriesSplit(n_splits=3)

    params = {'n_estimators': [30, 50],
              'max_depth': list(range(3,11)),
              'min_samples_leaf': range(4,11),
              'max_features': ['sqrt', 'log2', None],
              'bootstrap': [True], #We force bootstrap
              'max_samples': [0.6, 0.7, 0.8, 0.9]}

    forest = RandomForestRegressor(n_jobs=1)

    regressor = RandomizedSearchCV(estimator=forest,
                                  param_distributions=params,
                                  cv = tscv, 
                                  scoring='neg_mean_absolute_percentage_error',
                                  n_iter=150,
                                  verbose=1)
    regressor.fit(X_train, y_train)
    best_params_temp = regressor.best_params_

    df_output_temp = pd.DataFrame.from_dict(best_params_temp, orient='index').T
    df_output_temp['Product'] = product

    df_output_hyper_params = df_output_hyper_params.append(df_output_temp, ignore_index=True)

    
end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: HOUSEHOLD_2_142_CA_2
# Progressing: 0.0 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_065_CA_4
# Progressing: 1.28 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_212_CA_1
# Progressing: 2.56 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_460_CA_3
# Progressing: 3.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_414_CA_2
# Progressing: 5.13 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_321_CA_4
# Progressing: 6.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_029_CA_1
# Progressing: 7.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_331_CA_2
# Progressing: 8.97 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_206_CA_2
# Progressing: 10.26 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_240_CA_3
# Progressing: 11.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_240_CA_2
# Progressing: 12.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_447_CA_4
# Progressing: 14.1 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_277_CA_2
# Progressing: 15.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_237_CA_2
# Progressing: 16.67 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_239_CA_4
# Progressing: 17.95 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_230_CA_1
# Progressing: 19.23 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_290_CA_1
# Progressing: 20.51 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_269_CA_3
# Progressing: 21.79 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_493_CA_2
# Progressing: 23.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_386_CA_2
# Progressing: 24.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_440_CA_2
# Progressing: 25.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_512_CA_4
# Progressing: 26.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_385_CA_3
# Progressing: 28.21 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_193_CA_3
# Progressing: 29.49 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_301_CA_4
# Progressing: 30.77 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_033_CA_3
# Progressing: 32.05 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_169_CA_3
# Progressing: 33.33 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_230_CA_2
# Progressing: 34.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_439_CA_2
# Progressing: 35.9 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_090_CA_2
# Progressing: 37.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_416_CA_4
# Progressing: 38.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_113_CA_1
# Progressing: 39.74 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_452_CA_1
# Progressing: 41.03 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_357_CA_2
# Progressing: 42.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_117_CA_1
# Progressing: 43.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_165_CA_1
# Progressing: 44.87 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_224_CA_2
# Progressing: 46.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_169_CA_4
# Progressing: 47.44 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_475_CA_2
# Progressing: 48.72 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_436_CA_3
# Progressing: 50.0 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_148_CA_2
# Progressing: 51.28 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_090_CA_3
# Progressing: 52.56 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_008_CA_2
# Progressing: 53.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_203_CA_2
# Progressing: 55.13 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_184_CA_3
# Progressing: 56.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_105_CA_2
# Progressing: 57.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_079_CA_3
# Progressing: 58.97 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_235_CA_4
# Progressing: 60.26 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_132_CA_1
# Progressing: 61.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_279_CA_2
# Progressing: 62.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_460_CA_4
# Progressing: 64.1 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_172_CA_4
# Progressing: 65.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_371_CA_3
# Progressing: 66.67 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_190_CA_2
# Progressing: 67.95 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_341_CA_1
# Progressing: 69.23 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_325_CA_3
# Progressing: 70.51 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_172_CA_3
# Progressing: 71.79 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_504_CA_2
# Progressing: 73.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_373_CA_3
# Progressing: 74.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_028_CA_2
# Progressing: 75.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_133_CA_3
# Progressing: 76.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_219_CA_2
# Progressing: 78.21 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_229_CA_3
# Progressing: 79.49 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_065_CA_1
# Progressing: 80.77 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_511_CA_3
# Progressing: 82.05 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_416_CA_1
# Progressing: 83.33 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_002_CA_2
# Progressing: 84.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_395_CA_2
# Progressing: 85.9 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_506_CA_4
# Progressing: 87.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_410_CA_3
# Progressing: 88.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_154_CA_3
# Progressing: 89.74 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_203_CA_2
# Progressing: 91.03 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_312_CA_2
# Progressing: 92.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_305_CA_3
# Progressing: 93.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_379_CA_4
# Progressing: 94.87 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_103_CA_3
# Progressing: 96.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_325_CA_1
# Progressing: 97.44 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_477_CA_2
# Progressing: 98.72 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# This line of code took 36.499178973166664 minutes

# %%
df_output_hyper_params.to_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/Random Forest (Completed Pipeline)/Foods/Erratic_Params_Tuning_Random Forest.csv')

# %% [markdown]
# # Decide optimum set of parameters for Random Forest algorithm

# %%
# See if any values larger than 1 in column "Product"
# If yes, the corresponding set of parameters occur more than once and those sets should be considered first
df_output_hyper_params.groupby(['n_estimators', 'max_depth', 'min_samples_leaf', 'max_features', 'max_samples'])[['Product']].count().sort_values(by = 'Product', ascending=False)
# Out:
#                                                                   Product
# n_estimators max_depth min_samples_leaf max_features max_samples
# 30           3         4                sqrt         0.7                1
#              8         4                sqrt         0.7                1
# 50           8         10               sqrt         0.6                1
#              5         4                sqrt         0.7                1
#              4         4                sqrt         0.8                1
# 30           10        10               sqrt         0.7                1
#              9         7                log2         0.8                1
#                        4                log2         0.7                1
#              8         5                sqrt         0.8                1
#                                         log2         0.7                1
#                                                      0.6                1
#                        4                log2         0.9                1
#              4         8                sqrt         0.9                1
#              6         10               log2         0.8                1
#                                                      0.6                1
#                        5                log2         0.8                1
#                        4                sqrt         0.8                1
#              5         9                sqrt         0.7                1
#                        8                sqrt         0.6                1
#                        5                log2         0.9                1
#                        4                sqrt         0.9                1
#              4         10               log2         0.6                1
# 50           10        5                log2         0.6                1

# %%
df_output_hyper_params.groupby(['n_estimators'])[['Product']].count()
# Out:
#               Product
# n_estimators
# 30                 63
# 50                 15

# %%
df_output_hyper_params.groupby(['max_depth'])[['Product']].count()
# Out:
#            Product
# max_depth
# 3                6
# 4                6
# 5               11
# 6               12
# 7                9
# 8               16
# 9                9
# 10               9

# %%
# See what value of parameter "max_depth" occurs the most frequently
df_output_hyper_params.groupby(['min_samples_leaf'])[['Product']].count()
# Out:
#                   Product
# min_samples_leaf
# 4                      22
# 5                      18
# 6                       4
# 7                      12
# 8                       7
# 9                       8
# 10                      7

# %%
# See what value of parameter "learning_rate" occurs the most frequently
df_output_hyper_params.groupby(['max_features'])[['Product']].count()
# Out:
#               Product
# max_features
# log2               11
# sqrt               12

# %%
# See what value of parameter "colsample_bytree" occurs the most frequently
df_output_hyper_params.groupby(['max_samples'])[['Product']].count()
# Out:
#              Product
# max_samples
# 0.6               14
# 0.7               21
# 0.8               22
# 0.9               21

# %% [markdown]
# # Implement Random Forest on Test Set with optimum set of parameters

# %% [markdown]
# ### Specify optimum set of parameters

# %%
n_estimators_chosen = 30
max_depth_chosen = 6
min_samples_leaf_chosen = 4
max_features_chosen = 'sqrt'
max_samples_chosen = 0.9

# %%
len(list_pattern_py)
# Out:
# 126

# %%
list_pattern_temp = list_pattern_py.copy()

# %%
start = timer()

df_output_rf_pattern = pd.DataFrame()
for product in list_pattern_temp:
  print('Currently Running: %s' % product)
  print('Progressing: {0} %'.format(round(list_pattern_temp.index(product) / len(list_pattern_temp) * 100, 2)))
  dataframe_product = dataframe_weekly[['wm_yr_wk', product]]
  # Create Lag variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (t-{lag})': dataframe_product[product].shift(lag)
      for lag in lags
  })

  # Create Rolling Moving Average variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
      for moving_average in moving_averages
  })

  # Create Rolling Standard Deviation variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
      for std in stds
  })

  # Create Rolling Maximum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
      for maximum in maximums
  })

  # Create Rolling Minimum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
      for minimum in minimums
  })

  # Create Rolling Total variables 
  dataframe_product = dataframe_product.assign(**{
      f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
      for total in totals
  })

  dataframe_product.dropna(inplace=True)
  dataframe_product.set_index('wm_yr_wk', inplace=True)

  train_data = dataframe_product[dataframe_product.index <= end_train_week]
  test_data = dataframe_product[dataframe_product.index > end_train_week]

  corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
  high_corr_var=np.where(corr_matrix > correlation_threshold)
  high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

  train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)
  test_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

  X_train = train_data.drop(product, axis=1)
  y_train = train_data[product]

  X_test = test_data.drop(product, axis=1)
  y_test = test_data[product]

  forest = RandomForestRegressor(n_jobs=1,
                                n_estimators = n_estimators_chosen,
                                min_samples_leaf = min_samples_leaf_chosen,
                                max_samples = max_samples_chosen,
                                max_features = max_features_chosen,
                                max_depth = max_depth_chosen,
                                bootstrap = [True],
                                random_state = 0)
  

  forest.fit(X_train,y_train)
  y_pred = forest.predict(X_test)
  df_output_temp = pd.DataFrame({'Actual Data': y_test, 
                                  'Forecast': y_pred, 
                                  'Product': [product for num_rows in range(len(y_pred))]
                                  })
  
  df_output_rf_pattern = df_output_rf_pattern.append(df_output_temp, ignore_index=False)  

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: HOUSEHOLD_1_001_CA_1
# Progressing: 0.0 %
# Currently Running: HOUSEHOLD_1_029_CA_1
# Progressing: 0.79 %
# Currently Running: HOUSEHOLD_1_065_CA_1
# Progressing: 1.59 %
# Currently Running: HOUSEHOLD_1_113_CA_1
# Progressing: 2.38 %
# Currently Running: HOUSEHOLD_1_132_CA_1
# Progressing: 3.17 %
# Currently Running: HOUSEHOLD_1_133_CA_1
# Progressing: 3.97 %
# Currently Running: HOUSEHOLD_1_165_CA_1
# Progressing: 4.76 %
# Currently Running: HOUSEHOLD_1_172_CA_1
# Progressing: 5.56 %
# Currently Running: HOUSEHOLD_1_212_CA_1
# Progressing: 6.35 %
# Currently Running: HOUSEHOLD_1_230_CA_1
# Progressing: 7.14 %
# Currently Running: HOUSEHOLD_1_274_CA_1
# Progressing: 7.94 %
# Currently Running: HOUSEHOLD_1_290_CA_1
# Progressing: 8.73 %
# Currently Running: HOUSEHOLD_1_325_CA_1
# Progressing: 9.52 %
# Currently Running: HOUSEHOLD_1_341_CA_1
# Progressing: 10.32 %
# Currently Running: HOUSEHOLD_1_416_CA_1
# Progressing: 11.11 %
# Currently Running: HOUSEHOLD_1_423_CA_1
# Progressing: 11.9 %
# Currently Running: HOUSEHOLD_1_452_CA_1
# Progressing: 12.7 %
# Currently Running: HOUSEHOLD_1_456_CA_1
# Progressing: 13.49 %
# Currently Running: HOUSEHOLD_1_480_CA_1
# Progressing: 14.29 %
# Currently Running: HOUSEHOLD_1_518_CA_1
# Progressing: 15.08 %
# Currently Running: HOUSEHOLD_2_117_CA_1
# Progressing: 15.87 %
# Currently Running: HOUSEHOLD_2_177_CA_1
# Progressing: 16.67 %
# Currently Running: HOUSEHOLD_2_498_CA_1
# Progressing: 17.46 %
# Currently Running: HOUSEHOLD_2_513_CA_1
# Progressing: 18.25 %
# Currently Running: HOUSEHOLD_1_002_CA_2
# Progressing: 19.05 %
# Currently Running: HOUSEHOLD_1_004_CA_2
# Progressing: 19.84 %
# Currently Running: HOUSEHOLD_1_008_CA_2
# Progressing: 20.63 %
# Currently Running: HOUSEHOLD_1_028_CA_2
# Progressing: 21.43 %
# Currently Running: HOUSEHOLD_1_065_CA_2
# Progressing: 22.22 %
# Currently Running: HOUSEHOLD_1_090_CA_2
# Progressing: 23.02 %
# Currently Running: HOUSEHOLD_1_105_CA_2
# Progressing: 23.81 %
# Currently Running: HOUSEHOLD_1_193_CA_2
# Progressing: 24.6 %
# Currently Running: HOUSEHOLD_1_203_CA_2
# Progressing: 25.4 %
# Currently Running: HOUSEHOLD_1_206_CA_2
# Progressing: 26.19 %
# Currently Running: HOUSEHOLD_1_219_CA_2
# Progressing: 26.98 %
# Currently Running: HOUSEHOLD_1_224_CA_2
# Progressing: 27.78 %
# Currently Running: HOUSEHOLD_1_230_CA_2
# Progressing: 28.57 %
# Currently Running: HOUSEHOLD_1_250_CA_2
# Progressing: 29.37 %
# Currently Running: HOUSEHOLD_1_277_CA_2
# Progressing: 30.16 %
# Currently Running: HOUSEHOLD_1_279_CA_2
# Progressing: 30.95 %
# Currently Running: HOUSEHOLD_1_295_CA_2
# Progressing: 31.75 %
# Currently Running: HOUSEHOLD_1_312_CA_2
# Progressing: 32.54 %
# Currently Running: HOUSEHOLD_1_325_CA_2
# Progressing: 33.33 %
# Currently Running: HOUSEHOLD_1_331_CA_2
# Progressing: 34.13 %
# Currently Running: HOUSEHOLD_1_374_CA_2
# Progressing: 34.92 %
# Currently Running: HOUSEHOLD_1_395_CA_2
# Progressing: 35.71 %
# Currently Running: HOUSEHOLD_1_414_CA_2
# Progressing: 36.51 %
# Currently Running: HOUSEHOLD_1_424_CA_2
# Progressing: 37.3 %
# Currently Running: HOUSEHOLD_1_439_CA_2
# Progressing: 38.1 %
# Currently Running: HOUSEHOLD_1_456_CA_2
# Progressing: 38.89 %
# Currently Running: HOUSEHOLD_1_475_CA_2
# Progressing: 39.68 %
# Currently Running: HOUSEHOLD_1_477_CA_2
# Progressing: 40.48 %
# Currently Running: HOUSEHOLD_1_480_CA_2
# Progressing: 41.27 %
# Currently Running: HOUSEHOLD_1_493_CA_2
# Progressing: 42.06 %
# Currently Running: HOUSEHOLD_1_504_CA_2
# Progressing: 42.86 %
# Currently Running: HOUSEHOLD_1_526_CA_2
# Progressing: 43.65 %
# Currently Running: HOUSEHOLD_2_017_CA_2
# Progressing: 44.44 %
# Currently Running: HOUSEHOLD_2_051_CA_2
# Progressing: 45.24 %
# Currently Running: HOUSEHOLD_2_053_CA_2
# Progressing: 46.03 %
# Currently Running: HOUSEHOLD_2_081_CA_2
# Progressing: 46.83 %
# Currently Running: HOUSEHOLD_2_142_CA_2
# Progressing: 47.62 %
# Currently Running: HOUSEHOLD_2_148_CA_2
# Progressing: 48.41 %
# Currently Running: HOUSEHOLD_2_180_CA_2
# Progressing: 49.21 %
# Currently Running: HOUSEHOLD_2_190_CA_2
# Progressing: 50.0 %
# Currently Running: HOUSEHOLD_2_203_CA_2
# Progressing: 50.79 %
# Currently Running: HOUSEHOLD_2_237_CA_2
# Progressing: 51.59 %
# Currently Running: HOUSEHOLD_2_240_CA_2
# Progressing: 52.38 %
# Currently Running: HOUSEHOLD_2_264_CA_2
# Progressing: 53.17 %
# Currently Running: HOUSEHOLD_2_313_CA_2
# Progressing: 53.97 %
# Currently Running: HOUSEHOLD_2_357_CA_2
# Progressing: 54.76 %
# Currently Running: HOUSEHOLD_2_386_CA_2
# Progressing: 55.56 %
# Currently Running: HOUSEHOLD_2_389_CA_2
# Progressing: 56.35 %
# Currently Running: HOUSEHOLD_2_399_CA_2
# Progressing: 57.14 %
# Currently Running: HOUSEHOLD_2_402_CA_2
# Progressing: 57.94 %
# Currently Running: HOUSEHOLD_2_440_CA_2
# Progressing: 58.73 %
# Currently Running: HOUSEHOLD_2_499_CA_2
# Progressing: 59.52 %
# Currently Running: HOUSEHOLD_1_033_CA_3
# Progressing: 60.32 %
# Currently Running: HOUSEHOLD_1_043_CA_3
# Progressing: 61.11 %
# Currently Running: HOUSEHOLD_1_090_CA_3
# Progressing: 61.9 %
# Currently Running: HOUSEHOLD_1_101_CA_3
# Progressing: 62.7 %
# Currently Running: HOUSEHOLD_1_103_CA_3
# Progressing: 63.49 %
# Currently Running: HOUSEHOLD_1_133_CA_3
# Progressing: 64.29 %
# Currently Running: HOUSEHOLD_1_148_CA_3
# Progressing: 65.08 %
# Currently Running: HOUSEHOLD_1_169_CA_3
# Progressing: 65.87 %
# Currently Running: HOUSEHOLD_1_172_CA_3
# Progressing: 66.67 %
# Currently Running: HOUSEHOLD_1_184_CA_3
# Progressing: 67.46 %
# Currently Running: HOUSEHOLD_1_191_CA_3
# Progressing: 68.25 %
# Currently Running: HOUSEHOLD_1_199_CA_3
# Progressing: 69.05 %
# Currently Running: HOUSEHOLD_1_229_CA_3
# Progressing: 69.84 %
# Currently Running: HOUSEHOLD_1_269_CA_3
# Progressing: 70.63 %
# Currently Running: HOUSEHOLD_1_274_CA_3
# Progressing: 71.43 %
# Currently Running: HOUSEHOLD_1_305_CA_3
# Progressing: 72.22 %
# Currently Running: HOUSEHOLD_1_325_CA_3
# Progressing: 73.02 %
# Currently Running: HOUSEHOLD_1_331_CA_3
# Progressing: 73.81 %
# Currently Running: HOUSEHOLD_1_357_CA_3
# Progressing: 74.6 %
# Currently Running: HOUSEHOLD_1_385_CA_3
# Progressing: 75.4 %
# Currently Running: HOUSEHOLD_1_410_CA_3
# Progressing: 76.19 %
# Currently Running: HOUSEHOLD_1_436_CA_3
# Progressing: 76.98 %
# Currently Running: HOUSEHOLD_1_504_CA_3
# Progressing: 77.78 %
# Currently Running: HOUSEHOLD_2_004_CA_3
# Progressing: 78.57 %
# Currently Running: HOUSEHOLD_2_079_CA_3
# Progressing: 79.37 %
# Currently Running: HOUSEHOLD_2_154_CA_3
# Progressing: 80.16 %
# Currently Running: HOUSEHOLD_2_193_CA_3
# Progressing: 80.95 %
# Currently Running: HOUSEHOLD_2_240_CA_3
# Progressing: 81.75 %
# Currently Running: HOUSEHOLD_2_371_CA_3
# Progressing: 82.54 %
# Currently Running: HOUSEHOLD_2_373_CA_3
# Progressing: 83.33 %
# Currently Running: HOUSEHOLD_2_430_CA_3
# Progressing: 84.13 %
# Currently Running: HOUSEHOLD_2_436_CA_3
# Progressing: 84.92 %
# Currently Running: HOUSEHOLD_2_448_CA_3
# Progressing: 85.71 %
# Currently Running: HOUSEHOLD_2_452_CA_3
# Progressing: 86.51 %
# Currently Running: HOUSEHOLD_2_460_CA_3
# Progressing: 87.3 %
# Currently Running: HOUSEHOLD_2_498_CA_3
# Progressing: 88.1 %
# Currently Running: HOUSEHOLD_2_511_CA_3
# Progressing: 88.89 %
# Currently Running: HOUSEHOLD_1_065_CA_4
# Progressing: 89.68 %
# Currently Running: HOUSEHOLD_1_169_CA_4
# Progressing: 90.48 %
# Currently Running: HOUSEHOLD_1_172_CA_4
# Progressing: 91.27 %
# Currently Running: HOUSEHOLD_1_235_CA_4
# Progressing: 92.06 %
# Currently Running: HOUSEHOLD_1_321_CA_4
# Progressing: 92.86 %
# Currently Running: HOUSEHOLD_1_379_CA_4
# Progressing: 93.65 %
# Currently Running: HOUSEHOLD_1_416_CA_4
# Progressing: 94.44 %
# Currently Running: HOUSEHOLD_1_460_CA_4
# Progressing: 95.24 %
# Currently Running: HOUSEHOLD_1_506_CA_4
# Progressing: 96.03 %
# Currently Running: HOUSEHOLD_2_239_CA_4
# Progressing: 96.83 %
# Currently Running: HOUSEHOLD_2_301_CA_4
# Progressing: 97.62 %
# Currently Running: HOUSEHOLD_2_447_CA_4
# Progressing: 98.41 %
# Currently Running: HOUSEHOLD_2_512_CA_4
# Progressing: 99.21 %
# This line of code took 0.40750888906666966 minutes

# %%
df_output_rf_pattern
# Out:
#           Actual Data   Forecast               Product
# wm_yr_wk
# 11611             2.0   1.337989  HOUSEHOLD_1_001_CA_1
# 11612             1.0   1.374392  HOUSEHOLD_1_001_CA_1
# 11611             5.0   9.656373  HOUSEHOLD_1_029_CA_1
# 11612             9.0   8.850814  HOUSEHOLD_1_029_CA_1
# 11611            24.0  24.838465  HOUSEHOLD_1_065_CA_1
# ...               ...        ...                   ...
# 11612             1.0   2.812018  HOUSEHOLD_2_301_CA_4
# 11611             5.0   3.875049  HOUSEHOLD_2_447_CA_4
# 11612             2.0   3.311545  HOUSEHOLD_2_447_CA_4
# 11611             1.0   2.495051  HOUSEHOLD_2_512_CA_4
# 11612             5.0   2.556606  HOUSEHOLD_2_512_CA_4
#
# [252 rows x 3 columns]

# %%
df_output_rf_pattern.to_csv('Erratic_Random_Forest_Forecast_Values.csv')

# %%
# User-defined funcion to calculate metrics

def get_metrics_result_all_params(data):
    metrics_df = {}
    metrics_df['MASE'] = mase_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['WMAPE'] = wmape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['SMAPE'] = smape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAPE'] = mape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAE'] = mean_absolute_error(data['Actual Data'], data['Forecast'])
    metrics_df['RMSE'] = np.sqrt(mean_squared_error(data['Actual Data'], data['Forecast']))
    return pd.Series(metrics_df)

# %%
# Start calculating metrics 
start = timer()

df_forecast_metrics = df_output_rf_pattern.groupby('Product').apply(get_metrics_result_all_params).reset_index()

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 0.004124109149999337 minutes

# %%
df_forecast_metrics
# Out:
#                   Product      MASE     WMAPE     SMAPE      MAPE       MAE  \
# 0    HOUSEHOLD_1_001_CA_1  0.518202   34.5468   35.6005   35.2699  0.518202
# 1    HOUSEHOLD_1_002_CA_2       inf   24.1147   21.1912   24.1147  0.964588
# 2    HOUSEHOLD_1_004_CA_2       inf       inf  200.0000       NaN  8.815840
# 3    HOUSEHOLD_1_008_CA_2       inf   40.2161   33.0614   40.2161  1.206483
# 4    HOUSEHOLD_1_028_CA_2  1.293861   43.1287   35.9602   43.9405  2.587722
# ..                    ...       ...       ...       ...       ...       ...
# 121  HOUSEHOLD_2_498_CA_3       inf       inf  200.0000       NaN  0.062050
# 122  HOUSEHOLD_2_499_CA_2       inf       inf  200.0000       NaN  0.493510
# 123  HOUSEHOLD_2_511_CA_3  1.960292  150.7917   85.2937  214.0509  9.801459
# 124  HOUSEHOLD_2_512_CA_4  0.492306   65.6408   75.1108   99.1865  1.969223
# 125  HOUSEHOLD_2_513_CA_1       inf       inf  200.0000       NaN  3.328630
#
#           RMSE
# 0     0.537786
# 1     1.038368
# 2     8.843520
# 3     1.259699
# 4     2.591902
# ..         ...
# 121   0.062050
# 122   0.493510
# 123  11.161505
# 124   2.025506
# 125   3.331890
#
# [126 rows x 7 columns]

# %%
df_forecast_metrics.to_csv('Random_Forest_Erratic_Forecast_Metrics.csv')
