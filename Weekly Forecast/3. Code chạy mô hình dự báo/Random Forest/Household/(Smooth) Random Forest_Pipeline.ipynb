# %% [markdown]
# # Import necessary packages

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from random import sample

import re

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

from timeit import default_timer as timer

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import original data and preprocessed data

# %%
sales_train_val = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/sales_train_validation.csv')
calendar = pd.read_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/calendar.csv')

# %% [markdown]
# **Note: This Step is for the extraction of California State and Foods category**

# %%
sales_train_val = sales_train_val[(sales_train_val['state_id'] == 'CA') & (sales_train_val['cat_id'] == 'HOUSEHOLD')]

# %%
sales_train_val
# Out:
#                                     id          item_id      dept_id  \
# 565    HOUSEHOLD_1_001_CA_1_validation  HOUSEHOLD_1_001  HOUSEHOLD_1
# 566    HOUSEHOLD_1_002_CA_1_validation  HOUSEHOLD_1_002  HOUSEHOLD_1
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 568    HOUSEHOLD_1_004_CA_1_validation  HOUSEHOLD_1_004  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10754  HOUSEHOLD_2_512_CA_4_validation  HOUSEHOLD_2_512  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
# 10756  HOUSEHOLD_2_514_CA_4_validation  HOUSEHOLD_2_514  HOUSEHOLD_2
# 10757  HOUSEHOLD_2_515_CA_4_validation  HOUSEHOLD_2_515  HOUSEHOLD_2
# 10758  HOUSEHOLD_2_516_CA_4_validation  HOUSEHOLD_2_516  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 565    HOUSEHOLD     CA_1       CA    3    0    0    0  ...       1       0
# 566    HOUSEHOLD     CA_1       CA    1    1    2    4  ...       0       0
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 568    HOUSEHOLD     CA_1       CA    4    0    8   11  ...       0       5
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10754  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
# 10756  HOUSEHOLD     CA_4       CA    0    2    0    1  ...       0       0
# 10757  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10758  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 565         1       1       1       0       0       0       0       1
# 566         0       0       0       1       0       0       0       1
# 567         1       2       1       0       0       0       1       0
# 568         0       0       0       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10754       0       0       2       1       0       0       0       0
# 10755       0       0       0       0       0       0       0       0
# 10756       1       0       0       0       0       0       0       0
# 10757       0       0       0       0       0       0       2       0
# 10758       0       0       0       0       0       0       0       1
#
# [4188 rows x 1919 columns]

# %%
INPUT_DIR_2 = r'/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/List of Product ID according to 4 demand patterns/California/Household'

list_intermittent = pd.read_csv(f'{INPUT_DIR_2}/Intermittent_ID.csv')
list_lumpy = pd.read_csv(f'{INPUT_DIR_2}/Lumpy_ID.csv')
list_erratic = pd.read_csv(f'{INPUT_DIR_2}/Erratic_ID.csv')
list_smooth = pd.read_csv(f'{INPUT_DIR_2}/Smooth_ID.csv')

list_intermittent = list_intermittent['0'].values.tolist()
list_lumpy = list_lumpy['0'].values.tolist()
list_erratic = list_erratic['0'].values.tolist()
list_smooth = list_smooth['0'].values.tolist()

sales_intermittent = sales_train_val[sales_train_val.id.isin(list_intermittent)]
sales_lumpy = sales_train_val[sales_train_val.id.isin(list_lumpy)]
sales_erratic = sales_train_val[sales_train_val.id.isin(list_erratic)]
sales_smooth = sales_train_val[sales_train_val.id.isin(list_smooth)]

# %%
len(sales_intermittent)
# Out:
# 1493

# %%
len(sales_lumpy)
# Out:
# 178

# %%
len(sales_erratic)
# Out:
# 126

# %%
len(sales_smooth)
# Out:
# 2391

# %% [markdown]
# **Check by looking at column "id" to verify if we choose the right product (FOODS or HOBBIES or HOUSEHOLD)**

# %%
sales_smooth
# Out:
#                                     id          item_id      dept_id  \
# 567    HOUSEHOLD_1_003_CA_1_validation  HOUSEHOLD_1_003  HOUSEHOLD_1
# 568    HOUSEHOLD_1_004_CA_1_validation  HOUSEHOLD_1_004  HOUSEHOLD_1
# 569    HOUSEHOLD_1_005_CA_1_validation  HOUSEHOLD_1_005  HOUSEHOLD_1
# 570    HOUSEHOLD_1_006_CA_1_validation  HOUSEHOLD_1_006  HOUSEHOLD_1
# 571    HOUSEHOLD_1_007_CA_1_validation  HOUSEHOLD_1_007  HOUSEHOLD_1
# ...                                ...              ...          ...
# 10742  HOUSEHOLD_2_500_CA_4_validation  HOUSEHOLD_2_500  HOUSEHOLD_2
# 10747  HOUSEHOLD_2_505_CA_4_validation  HOUSEHOLD_2_505  HOUSEHOLD_2
# 10752  HOUSEHOLD_2_510_CA_4_validation  HOUSEHOLD_2_510  HOUSEHOLD_2
# 10753  HOUSEHOLD_2_511_CA_4_validation  HOUSEHOLD_2_511  HOUSEHOLD_2
# 10755  HOUSEHOLD_2_513_CA_4_validation  HOUSEHOLD_2_513  HOUSEHOLD_2
#
#           cat_id store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  \
# 567    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       0
# 568    HOUSEHOLD     CA_1       CA    4    0    8   11  ...       0       5
# 569    HOUSEHOLD     CA_1       CA    0    3    2    2  ...       1       0
# 570    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       3       4
# 571    HOUSEHOLD     CA_1       CA    0    0    0    0  ...       0       3
# ...          ...      ...      ...  ...  ...  ...  ...  ...     ...     ...
# 10742  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       1
# 10747  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10752  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       0       0
# 10753  HOUSEHOLD     CA_4       CA    0    0    2    1  ...       1       1
# 10755  HOUSEHOLD     CA_4       CA    0    0    0    0  ...       2       0
#
#        d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  d_1913
# 567         1       2       1       0       0       0       1       0
# 568         0       0       0       0       0       0       1       0
# 569         3       1       2       0       0       1       0       1
# 570         2       6       3       2       2       1       3       4
# 571         1       1       1       3       0       5       3       2
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 10742       0       1       0       0       1       0       0       1
# 10747       0       0       0       2       0       0       0       0
# 10752       0       2       1       1       0       1       0       0
# 10753       1       0       0       3       1       0       0       1
# 10755       0       0       0       0       0       0       0       0
#
# [2391 rows x 1919 columns]

# %% [markdown]
# # User-defined functions to calculate Metrics

# %%
ROUNDING_DECIMAL = 4

def mase_calculation(ts, prediction):
    divisor = 0
    for i in range(1, ts.shape[0]):
        divisor = divisor + abs(ts.iloc[i] - ts.iloc[i-1])
    divisor = divisor/(ts.shape[0] - 1)
    diff    = abs(ts - prediction[:ts.shape[0]])/divisor
    mase    = diff.mean()
    return mase

def mape_calculation(actual, pred): 
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    mask = (actual != 0)
    return round((np.fabs(actual - pred)/actual)[mask].mean()*100, ROUNDING_DECIMAL)

def wmape_calculation(actual, pred):
    if not all([isinstance(actual, np.ndarray), isinstance(pred, np.ndarray)]):
        actual, pred = np.array(actual), np.array(pred)
    return round((np.sum(np.absolute(actual-pred))/np.sum(actual))*100, ROUNDING_DECIMAL)

def smape_calculation(actual, predicted):
    if not all([isinstance(actual, np.ndarray), isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, ROUNDING_DECIMAL)

# %% [markdown]
# # Format sales data and then merge with calendar data

# %%
sales_pattern = sales_smooth.copy()

# %%
sales_pattern_py = sales_pattern.copy()

list_pattern_py = sales_pattern_py.id.unique().tolist()
list_pattern_py = [(re.sub(r'_validation', r"", x)) for x in list_pattern_py]

sales_pattern_py = sales_pattern_py.drop(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], axis=1)
df_pattern = sales_pattern_py.melt(['id'], var_name='Date').pivot(index = ['Date'], columns = 'id', values = 'value').reset_index()
df_pattern.drop('Date', axis=1, inplace=True)
df_pattern.index = pd.date_range('2011-01-29', periods=df_pattern.shape[0], freq="D")
df_pattern.index.names = ['Date']
df_pattern = df_pattern.astype('float64')

df_pattern.iloc[:, 1:].columns = df_pattern.iloc[:, 1:].columns.str.rstrip('_validation')
df_pattern.columns = df_pattern.columns.str.replace(r'_validation', '')
df_pattern.reset_index(inplace=True)

calendar['Date'] = pd.to_datetime(calendar['date'])

dataframe = pd.merge(df_pattern,
                     calendar[['wm_yr_wk', 'Date']],
                     on = 'Date')

not_enough_seven_days = dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})[dataframe.groupby('wm_yr_wk').agg({'Date': 'count'})['Date'] < 7].index.tolist()
dataframe = dataframe[~dataframe['wm_yr_wk'].isin(not_enough_seven_days)]

dataframe.set_index('wm_yr_wk', inplace=True)
dataframe.drop('Date', axis=1, inplace=True)

dataframe_weekly = dataframe.groupby('wm_yr_wk').sum().reset_index()

# %%
dataframe_weekly
# Out:
#      wm_yr_wk  HOUSEHOLD_1_001_CA_3  HOUSEHOLD_1_002_CA_3  \
# 0       11101                   3.0                   3.0
# 1       11102                   2.0                   6.0
# 2       11103                   1.0                   5.0
# 3       11104                   4.0                   7.0
# 4       11105                   3.0                   8.0
# ..        ...                   ...                   ...
# 268     11608                   4.0                   9.0
# 269     11609                   2.0                   5.0
# 270     11610                  12.0                   4.0
# 271     11611                   6.0                   5.0
# 272     11612                   4.0                   2.0
#
#      HOUSEHOLD_1_002_CA_4  HOUSEHOLD_1_003_CA_1  HOUSEHOLD_1_003_CA_2  \
# 0                     4.0                   0.0                   3.0
# 1                     3.0                   0.0                   6.0
# 2                     1.0                   0.0                   9.0
# 3                     0.0                   0.0                   2.0
# 4                     0.0                   1.0                   9.0
# ..                    ...                   ...                   ...
# 268                   2.0                   8.0                   5.0
# 269                   1.0                   4.0                   6.0
# 270                   3.0                   4.0                  10.0
# 271                   4.0                   4.0                   3.0
# 272                   0.0                   2.0                   3.0
#
#      HOUSEHOLD_1_003_CA_3  HOUSEHOLD_1_003_CA_4  HOUSEHOLD_1_004_CA_1  \
# 0                     1.0                   0.0                  13.0
# 1                     6.0                   7.0                   3.0
# 2                     7.0                  12.0                   8.0
# 3                     8.0                   4.0                  11.0
# 4                     5.0                   6.0                   6.0
# ..                    ...                   ...                   ...
# 268                   7.0                   3.0                   8.0
# 269                  11.0                   3.0                  11.0
# 270                   8.0                   9.0                  11.0
# 271                  10.0                   7.0                   7.0
# 272                   4.0                   2.0                   9.0
#
#      HOUSEHOLD_1_004_CA_3  ...  HOUSEHOLD_2_510_CA_3  HOUSEHOLD_2_510_CA_4  \
# 0                    42.0  ...                  12.0                   1.0
# 1                    17.0  ...                  13.0                   2.0
# 2                    35.0  ...                  16.0                   3.0
# 3                    23.0  ...                   0.0                   0.0
# 4                    32.0  ...                  17.0                   0.0
# ..                    ...  ...                   ...                   ...
# 268                  25.0  ...                  19.0                   2.0
# 269                  16.0  ...                  15.0                   3.0
# 270                  21.0  ...                  17.0                   4.0
# 271                  25.0  ...                  18.0                   3.0
# 272                  35.0  ...                  16.0                   1.0
#
#      HOUSEHOLD_2_511_CA_1  HOUSEHOLD_2_511_CA_4  HOUSEHOLD_2_512_CA_1  \
# 0                    14.0                   3.0                   3.0
# 1                     5.0                   2.0                   4.0
# 2                     6.0                   2.0                   5.0
# 3                     5.0                   3.0                   4.0
# 4                     2.0                   2.0                   1.0
# ..                    ...                   ...                   ...
# 268                   4.0                   7.0                   3.0
# 269                   1.0                   1.0                   9.0
# 270                  10.0                   6.0                   1.0
# 271                  13.0                   6.0                   0.0
# 272                  13.0                   3.0                   0.0
#
#      HOUSEHOLD_2_512_CA_2  HOUSEHOLD_2_512_CA_3  HOUSEHOLD_2_513_CA_3  \
# 0                     8.0                   5.0                  22.0
# 1                     6.0                  15.0                  38.0
# 2                     8.0                  16.0                  29.0
# 3                    19.0                   5.0                  14.0
# 4                    15.0                  16.0                  23.0
# ..                    ...                   ...                   ...
# 268                   4.0                   3.0                  23.0
# 269                   7.0                   9.0                  12.0
# 270                  11.0                   8.0                  17.0
# 271                  11.0                   5.0                   7.0
# 272                  13.0                  17.0                  30.0
#
#      HOUSEHOLD_2_513_CA_4  HOUSEHOLD_2_514_CA_1
# 0                     0.0                   4.0
# 1                     2.0                   0.0
# 2                     2.0                   0.0
# 3                     2.0                   1.0
# 4                     3.0                   1.0
# ..                    ...                   ...
# 268                   0.0                   0.0
# 269                   0.0                   2.0
# 270                   4.0                   1.0
# 271                   0.0                   0.0
# 272                   0.0                   1.0
#
# [273 rows x 2392 columns]

# %%
lags = list(range(1, 25))
moving_averages = list(range(1, 25)) 
stds = list(range(2, 25))
maximums = list(range(1, 25))
minimums = list(range(1, 25))
totals = list(range(1, 25))
num_days_zeros = list(range(1, 25))

correlation_threshold = 0.8

end_train_week = 11610

num_id_sample_for_tuning = 200

# %%
sample_list = sample(list_pattern_py, num_id_sample_for_tuning)

# %%
dataframe_check = dataframe_weekly[sample_list].iloc[-2:].T

dataframe_check['Check'] = np.where((dataframe_check[271] == 0) &
                                    (dataframe_check[272] == 0), 1, 0)

sample_removed = dataframe_check[dataframe_check['Check'] == 1].index.tolist()

# %%
sample_list_filtered = [x for x in sample_list if (x not in sample_removed)]

# %%
len(sample_list_filtered)
# Out:
# 169

# %%
start = timer()

df_output_hyper_params = pd.DataFrame()
    
for product in sample_list_filtered:
    print('Currently Running: %s' % product)
    print('Progressing: {0} %'.format(round(sample_list_filtered.index(product) / len(sample_list_filtered) * 100, 2)))

    dataframe_product = dataframe_weekly[['wm_yr_wk', product]]

    # Create Lag variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (t-{lag})': dataframe_product[product].shift(lag)
        for lag in lags
    })

    # Create Rolling Moving Average variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
        for moving_average in moving_averages
    })

    # Create Rolling Standard Deviation variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
        for std in stds
    })

    # Create Rolling Maximum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
        for maximum in maximums
    })

    # Create Rolling Minimum variables
    dataframe_product = dataframe_product.assign(**{
        f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
        for minimum in minimums
    })

    # Create Rolling Total variables 
    dataframe_product = dataframe_product.assign(**{
        f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
        for total in totals
    })


    dataframe_product.dropna(inplace=True)
    dataframe_product.set_index('wm_yr_wk', inplace=True)

    train_data = dataframe_product[dataframe_product.index <= end_train_week]

    corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
    high_corr_var=np.where(corr_matrix > correlation_threshold)
    high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

    train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

    X_train = train_data.drop(product, axis=1)
    y_train = train_data[product]  

    tscv = TimeSeriesSplit(n_splits=3)

    params = {'n_estimators': [30, 50],
              'max_depth': list(range(3,11)),
              'min_samples_leaf': range(4,11),
              'max_features': ['sqrt', 'log2', None],
              'bootstrap': [True], #We force bootstrap
              'max_samples': [0.6, 0.7, 0.8, 0.9]}

    forest = RandomForestRegressor(n_jobs=1)

    regressor = RandomizedSearchCV(estimator=forest,
                                  param_distributions=params,
                                  cv = tscv, 
                                  scoring='neg_mean_absolute_percentage_error',
                                  n_iter=150,
                                  verbose=1)
    regressor.fit(X_train, y_train)
    best_params_temp = regressor.best_params_

    df_output_temp = pd.DataFrame.from_dict(best_params_temp, orient='index').T
    df_output_temp['Product'] = product

    df_output_hyper_params = df_output_hyper_params.append(df_output_temp, ignore_index=True)

    
end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: HOUSEHOLD_1_363_CA_4
# Progressing: 0.0 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_268_CA_3
# Progressing: 0.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_138_CA_4
# Progressing: 1.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_019_CA_2
# Progressing: 1.78 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_041_CA_3
# Progressing: 2.37 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_176_CA_4
# Progressing: 2.96 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_451_CA_1
# Progressing: 3.55 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_046_CA_2
# Progressing: 4.14 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_035_CA_1
# Progressing: 4.73 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_292_CA_4
# Progressing: 5.33 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_089_CA_4
# Progressing: 5.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_110_CA_1
# Progressing: 6.51 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_425_CA_1
# Progressing: 7.1 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_319_CA_3
# Progressing: 7.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_475_CA_3
# Progressing: 8.28 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_168_CA_4
# Progressing: 8.88 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_048_CA_3
# Progressing: 9.47 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_275_CA_2
# Progressing: 10.06 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_500_CA_1
# Progressing: 10.65 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_203_CA_3
# Progressing: 11.24 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_344_CA_3
# Progressing: 11.83 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_345_CA_3
# Progressing: 12.43 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_434_CA_3
# Progressing: 13.02 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_056_CA_3
# Progressing: 13.61 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_141_CA_4
# Progressing: 14.2 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_160_CA_3
# Progressing: 14.79 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_500_CA_4
# Progressing: 15.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_363_CA_2
# Progressing: 15.98 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_501_CA_3
# Progressing: 16.57 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_155_CA_2
# Progressing: 17.16 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_482_CA_3
# Progressing: 17.75 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_394_CA_2
# Progressing: 18.34 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_145_CA_2
# Progressing: 18.93 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_181_CA_4
# Progressing: 19.53 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_435_CA_2
# Progressing: 20.12 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_321_CA_3
# Progressing: 20.71 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_086_CA_3
# Progressing: 21.3 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_405_CA_4
# Progressing: 21.89 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_176_CA_2
# Progressing: 22.49 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_171_CA_4
# Progressing: 23.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_005_CA_2
# Progressing: 23.67 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_485_CA_3
# Progressing: 24.26 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_182_CA_3
# Progressing: 24.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_048_CA_4
# Progressing: 25.44 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_051_CA_4
# Progressing: 26.04 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_453_CA_1
# Progressing: 26.63 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_196_CA_4
# Progressing: 27.22 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_236_CA_1
# Progressing: 27.81 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_275_CA_1
# Progressing: 28.4 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_417_CA_2
# Progressing: 28.99 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_184_CA_3
# Progressing: 29.59 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_134_CA_2
# Progressing: 30.18 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_262_CA_2
# Progressing: 30.77 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_354_CA_2
# Progressing: 31.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_218_CA_1
# Progressing: 31.95 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_506_CA_3
# Progressing: 32.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_370_CA_1
# Progressing: 33.14 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_380_CA_4
# Progressing: 33.73 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_136_CA_4
# Progressing: 34.32 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_235_CA_2
# Progressing: 34.91 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_126_CA_4
# Progressing: 35.5 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_492_CA_3
# Progressing: 36.09 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_011_CA_2
# Progressing: 36.69 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_212_CA_3
# Progressing: 37.28 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_145_CA_3
# Progressing: 37.87 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_394_CA_4
# Progressing: 38.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_165_CA_2
# Progressing: 39.05 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_219_CA_4
# Progressing: 39.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_167_CA_1
# Progressing: 40.24 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_541_CA_1
# Progressing: 40.83 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_503_CA_3
# Progressing: 41.42 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_219_CA_3
# Progressing: 42.01 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_401_CA_2
# Progressing: 42.6 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_465_CA_2
# Progressing: 43.2 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_450_CA_2
# Progressing: 43.79 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_236_CA_1
# Progressing: 44.38 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_380_CA_3
# Progressing: 44.97 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_017_CA_3
# Progressing: 45.56 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_155_CA_3
# Progressing: 46.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_303_CA_3
# Progressing: 46.75 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_387_CA_4
# Progressing: 47.34 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_517_CA_3
# Progressing: 47.93 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_327_CA_2
# Progressing: 48.52 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_225_CA_4
# Progressing: 49.11 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_006_CA_1
# Progressing: 49.7 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_440_CA_4
# Progressing: 50.3 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_438_CA_1
# Progressing: 50.89 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_400_CA_2
# Progressing: 51.48 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_287_CA_2
# Progressing: 52.07 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_047_CA_2
# Progressing: 52.66 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_162_CA_1
# Progressing: 53.25 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_053_CA_1
# Progressing: 53.85 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_467_CA_4
# Progressing: 54.44 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_375_CA_3
# Progressing: 55.03 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_025_CA_2
# Progressing: 55.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_427_CA_1
# Progressing: 56.21 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_045_CA_3
# Progressing: 56.8 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_064_CA_4
# Progressing: 57.4 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_538_CA_4
# Progressing: 57.99 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_397_CA_4
# Progressing: 58.58 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_336_CA_3
# Progressing: 59.17 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_493_CA_1
# Progressing: 59.76 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_369_CA_3
# Progressing: 60.36 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_143_CA_4
# Progressing: 60.95 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_383_CA_4
# Progressing: 61.54 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_437_CA_4
# Progressing: 62.13 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_105_CA_2
# Progressing: 62.72 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_369_CA_4
# Progressing: 63.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_074_CA_2
# Progressing: 63.91 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_437_CA_3
# Progressing: 64.5 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_099_CA_4
# Progressing: 65.09 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_352_CA_1
# Progressing: 65.68 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_277_CA_1
# Progressing: 66.27 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_403_CA_4
# Progressing: 66.86 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_461_CA_3
# Progressing: 67.46 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_198_CA_3
# Progressing: 68.05 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_334_CA_1
# Progressing: 68.64 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_259_CA_3
# Progressing: 69.23 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_479_CA_2
# Progressing: 69.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_515_CA_1
# Progressing: 70.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_343_CA_4
# Progressing: 71.01 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_014_CA_1
# Progressing: 71.6 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_047_CA_4
# Progressing: 72.19 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_485_CA_1
# Progressing: 72.78 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_427_CA_3
# Progressing: 73.37 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_322_CA_4
# Progressing: 73.96 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_483_CA_2
# Progressing: 74.56 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_074_CA_4
# Progressing: 75.15 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_252_CA_1
# Progressing: 75.74 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_284_CA_1
# Progressing: 76.33 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_361_CA_2
# Progressing: 76.92 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_295_CA_3
# Progressing: 77.51 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_003_CA_3
# Progressing: 78.11 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_181_CA_3
# Progressing: 78.7 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_447_CA_1
# Progressing: 79.29 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_256_CA_2
# Progressing: 79.88 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_191_CA_4
# Progressing: 80.47 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_294_CA_2
# Progressing: 81.07 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_337_CA_4
# Progressing: 81.66 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_407_CA_3
# Progressing: 82.25 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_480_CA_3
# Progressing: 82.84 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_110_CA_3
# Progressing: 83.43 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_388_CA_1
# Progressing: 84.02 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_343_CA_1
# Progressing: 84.62 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_336_CA_2
# Progressing: 85.21 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_070_CA_1
# Progressing: 85.8 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_507_CA_3
# Progressing: 86.39 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_238_CA_2
# Progressing: 86.98 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_007_CA_1
# Progressing: 87.57 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_315_CA_3
# Progressing: 88.17 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_176_CA_1
# Progressing: 88.76 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_232_CA_2
# Progressing: 89.35 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_079_CA_1
# Progressing: 89.94 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_124_CA_4
# Progressing: 90.53 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_070_CA_2
# Progressing: 91.12 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_048_CA_1
# Progressing: 91.72 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_188_CA_4
# Progressing: 92.31 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_088_CA_3
# Progressing: 92.9 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_458_CA_1
# Progressing: 93.49 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_478_CA_1
# Progressing: 94.08 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_282_CA_1
# Progressing: 94.67 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_220_CA_1
# Progressing: 95.27 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_243_CA_3
# Progressing: 95.86 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_379_CA_3
# Progressing: 96.45 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_059_CA_4
# Progressing: 97.04 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_348_CA_4
# Progressing: 97.63 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_2_478_CA_2
# Progressing: 98.22 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_522_CA_4
# Progressing: 98.82 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# Currently Running: HOUSEHOLD_1_080_CA_3
# Progressing: 99.41 %
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# This line of code took 88.05286421670002 minutes

# %%
df_output_hyper_params.to_csv('/content/drive/MyDrive/Colab Notebooks_Weekly Prediction/Random Forest (Completed Pipeline)/Foods/Smooth_Params_Tuning_Random Forest.csv')

# %% [markdown]
# # Decide optimum set of parameters for Random Forest algorithm

# %%
# See if any values larger than 1 in column "Product"
# If yes, the corresponding set of parameters occur more than once and those sets should be considered first
df_output_hyper_params.groupby(['n_estimators', 'max_depth', 'min_samples_leaf', 'max_features', 'max_samples'])[['Product']].count().sort_values(by = 'Product', ascending=False)
# Out:
#                                                                   Product
# n_estimators max_depth min_samples_leaf max_features max_samples
# 30           8         7                log2         0.9                2
#              9         6                sqrt         0.8                2
#              10        5                sqrt         0.6                2
#              3         10               log2         0.8                1
#              10        5                sqrt         0.9                1
#              8         4                log2         0.9                1
#                                         sqrt         0.6                1
#                        8                sqrt         0.8                1
#              9         5                log2         0.9                1
#                        6                sqrt         0.9                1
#                        7                log2         0.6                1
#              10        6                log2         0.6                1
#              7         9                log2         0.6                1
#              10        8                sqrt         0.6                1
#                                                      0.8                1
#                        9                sqrt         0.8                1
# 50           3         9                sqrt         0.6                1
#              4         4                log2         0.6                1
#                                         sqrt         0.8                1
#              5         4                sqrt         0.8                1
#                        9                log2         0.7                1
#              8         4                sqrt         0.6                1
# 30           8         4                log2         0.8                1
#              7         6                log2         0.6                1
#              3         10               sqrt         0.6                1
#              5         7                log2         0.6                1
#              4         4                log2         0.6                1
#                                         sqrt         0.6                1
#                        6                log2         0.7                1
#                        8                log2         0.6                1
#                                                      0.7                1
#                                                      0.8                1
#              5         4                log2         0.8                1
#                                         sqrt         0.6                1
#                                                      0.7                1
#                        10               log2         0.9                1
#              7         5                sqrt         0.9                1
#              6         4                sqrt         0.6                1
#                        6                log2         0.6                1
#                        8                sqrt         0.6                1
#                        10               log2         0.9                1
#              7         4                sqrt         0.6                1
#                                                      0.7                1
#                                                      0.9                1
#                        5                log2         0.6                1
#                                         sqrt         0.8                1
# 50           9         6                sqrt         0.6                1

# %%
df_output_hyper_params.groupby(['n_estimators'])[['Product']].count()
# Out:
#               Product
# n_estimators
# 30                131
# 50                 38

# %%
df_output_hyper_params.groupby(['max_depth'])[['Product']].count()
# Out:
#            Product
# max_depth
# 3               11
# 4               25
# 5               20
# 6               21
# 7               24
# 8               23
# 9               20
# 10              25

# %%
# See what value of parameter "max_depth" occurs the most frequently
df_output_hyper_params.groupby(['min_samples_leaf'])[['Product']].count()
# Out:
#                   Product
# min_samples_leaf
# 4                      57
# 5                      22
# 6                      32
# 7                      13
# 8                      16
# 9                      12
# 10                     17

# %%
# See what value of parameter "learning_rate" occurs the most frequently
df_output_hyper_params.groupby(['max_features'])[['Product']].count()
# Out:
#               Product
# max_features
# log2               23
# sqrt               27

# %%
# See what value of parameter "colsample_bytree" occurs the most frequently
df_output_hyper_params.groupby(['max_samples'])[['Product']].count()
# Out:
#              Product
# max_samples
# 0.6               41
# 0.7               33
# 0.8               47
# 0.9               48

# %% [markdown]
# # Implement Random Forest on Test Set with optimum set of parameters

# %% [markdown]
# ### Specify optimum set of parameters

# %%
n_estimators_chosen = 30
max_depth_chosen = 4
min_samples_leaf_chosen = 6
max_features_chosen = 'log2'
max_samples_chosen = 0.7

# %%
len(list_pattern_py)
# Out:
# 2391

# %%
list_pattern_temp = list_pattern_py.copy()

# %%
start = timer()

df_output_rf_pattern = pd.DataFrame()
for product in list_pattern_temp:
  print('Currently Running: %s' % product)
  print('Progressing: {0} %'.format(round(list_pattern_temp.index(product) / len(list_pattern_temp) * 100, 2)))
  dataframe_product = dataframe_weekly[['wm_yr_wk', product]]
  # Create Lag variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (t-{lag})': dataframe_product[product].shift(lag)
      for lag in lags
  })

  # Create Rolling Moving Average variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (mva_{moving_average})': dataframe_product[product].shift(1).rolling(moving_average).mean()
      for moving_average in moving_averages
  })

  # Create Rolling Standard Deviation variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (std_{std})': dataframe_product[product].shift(1).rolling(std).std()
      for std in stds
  })

  # Create Rolling Maximum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (max_{maximum})': dataframe_product[product].shift(1).rolling(maximum).max()
      for maximum in maximums
  })

  # Create Rolling Minimum variables
  dataframe_product = dataframe_product.assign(**{
      f'{product} (min_{minimum})': dataframe_product[product].shift(1).rolling(minimum).min()
      for minimum in minimums
  })

  # Create Rolling Total variables 
  dataframe_product = dataframe_product.assign(**{
      f'{product} (total_{total})': dataframe_product[product].shift(1).rolling(total).sum()
      for total in totals
  })

  dataframe_product.dropna(inplace=True)
  dataframe_product.set_index('wm_yr_wk', inplace=True)

  train_data = dataframe_product[dataframe_product.index <= end_train_week]
  test_data = dataframe_product[dataframe_product.index > end_train_week]

  corr_matrix = train_data.loc[:, train_data.columns != product].corr().abs()
  high_corr_var=np.where(corr_matrix > correlation_threshold)
  high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

  train_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)
  test_data.drop([i[1] for i in high_corr_var], axis=1, inplace=True)

  X_train = train_data.drop(product, axis=1)
  y_train = train_data[product]

  X_test = test_data.drop(product, axis=1)
  y_test = test_data[product]

  forest = RandomForestRegressor(n_jobs=1,
                                n_estimators = n_estimators_chosen,
                                min_samples_leaf = min_samples_leaf_chosen,
                                max_samples = max_samples_chosen,
                                max_features = max_features_chosen,
                                max_depth = max_depth_chosen,
                                bootstrap = [True],
                                random_state = 0)
  

  forest.fit(X_train,y_train)
  y_pred = forest.predict(X_test)
  df_output_temp = pd.DataFrame({'Actual Data': y_test, 
                                  'Forecast': y_pred, 
                                  'Product': [product for num_rows in range(len(y_pred))]
                                  })
  
  df_output_rf_pattern = df_output_rf_pattern.append(df_output_temp, ignore_index=False)  

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# Currently Running: HOUSEHOLD_1_003_CA_1
# Progressing: 0.0 %
# Currently Running: HOUSEHOLD_1_004_CA_1
# Progressing: 0.04 %
# Currently Running: HOUSEHOLD_1_005_CA_1
# Progressing: 0.08 %
# Currently Running: HOUSEHOLD_1_006_CA_1
# Progressing: 0.13 %
# Currently Running: HOUSEHOLD_1_007_CA_1
# Progressing: 0.17 %
# Currently Running: HOUSEHOLD_1_008_CA_1
# Progressing: 0.21 %
# Currently Running: HOUSEHOLD_1_009_CA_1
# Progressing: 0.25 %
# Currently Running: HOUSEHOLD_1_010_CA_1
# Progressing: 0.29 %
# Currently Running: HOUSEHOLD_1_011_CA_1
# Progressing: 0.33 %
# Currently Running: HOUSEHOLD_1_014_CA_1
# Progressing: 0.38 %
# Currently Running: HOUSEHOLD_1_016_CA_1
# Progressing: 0.42 %
# Currently Running: HOUSEHOLD_1_019_CA_1
# Progressing: 0.46 %
# Currently Running: HOUSEHOLD_1_020_CA_1
# Progressing: 0.5 %
# Currently Running: HOUSEHOLD_1_021_CA_1
# Progressing: 0.54 %
# Currently Running: HOUSEHOLD_1_022_CA_1
# Progressing: 0.59 %
# Currently Running: HOUSEHOLD_1_023_CA_1
# Progressing: 0.63 %
# Currently Running: HOUSEHOLD_1_024_CA_1
# Progressing: 0.67 %
# Currently Running: HOUSEHOLD_1_025_CA_1
# Progressing: 0.71 %
# Currently Running: HOUSEHOLD_1_026_CA_1
# Progressing: 0.75 %
# Currently Running: HOUSEHOLD_1_027_CA_1
# Progressing: 0.79 %
# Currently Running: HOUSEHOLD_1_028_CA_1
# Progressing: 0.84 %
# Currently Running: HOUSEHOLD_1_030_CA_1
# Progressing: 0.88 %
# Currently Running: HOUSEHOLD_1_032_CA_1
# Progressing: 0.92 %
# Currently Running: HOUSEHOLD_1_034_CA_1
# Progressing: 0.96 %
# Currently Running: HOUSEHOLD_1_035_CA_1
# Progressing: 1.0 %
# Currently Running: HOUSEHOLD_1_038_CA_1
# Progressing: 1.05 %
# Currently Running: HOUSEHOLD_1_040_CA_1
# Progressing: 1.09 %
# Currently Running: HOUSEHOLD_1_043_CA_1
# Progressing: 1.13 %
# Currently Running: HOUSEHOLD_1_044_CA_1
# Progressing: 1.17 %
# Currently Running: HOUSEHOLD_1_045_CA_1
# Progressing: 1.21 %
# Currently Running: HOUSEHOLD_1_046_CA_1
# Progressing: 1.25 %
# Currently Running: HOUSEHOLD_1_047_CA_1
# Progressing: 1.3 %
# Currently Running: HOUSEHOLD_1_048_CA_1
# Progressing: 1.34 %
# Currently Running: HOUSEHOLD_1_050_CA_1
# Progressing: 1.38 %
# Currently Running: HOUSEHOLD_1_051_CA_1
# Progressing: 1.42 %
# Currently Running: HOUSEHOLD_1_053_CA_1
# Progressing: 1.46 %
# Currently Running: HOUSEHOLD_1_054_CA_1
# Progressing: 1.51 %
# Currently Running: HOUSEHOLD_1_055_CA_1
# Progressing: 1.55 %
# Currently Running: HOUSEHOLD_1_058_CA_1
# Progressing: 1.59 %
# Currently Running: HOUSEHOLD_1_061_CA_1
# Progressing: 1.63 %
# Currently Running: HOUSEHOLD_1_062_CA_1
# Progressing: 1.67 %
# Currently Running: HOUSEHOLD_1_066_CA_1
# Progressing: 1.71 %
# Currently Running: HOUSEHOLD_1_068_CA_1
# Progressing: 1.76 %
# Currently Running: HOUSEHOLD_1_069_CA_1
# Progressing: 1.8 %
# Currently Running: HOUSEHOLD_1_070_CA_1
# Progressing: 1.84 %
# Currently Running: HOUSEHOLD_1_071_CA_1
# Progressing: 1.88 %
# Currently Running: HOUSEHOLD_1_072_CA_1
# Progressing: 1.92 %
# Currently Running: HOUSEHOLD_1_073_CA_1
# Progressing: 1.97 %
# Currently Running: HOUSEHOLD_1_074_CA_1
# Progressing: 2.01 %
# Currently Running: HOUSEHOLD_1_075_CA_1
# Progressing: 2.05 %
# Currently Running: HOUSEHOLD_1_076_CA_1
# Progressing: 2.09 %
# Currently Running: HOUSEHOLD_1_077_CA_1
# Progressing: 2.13 %
# Currently Running: HOUSEHOLD_1_078_CA_1
# Progressing: 2.17 %
# Currently Running: HOUSEHOLD_1_079_CA_1
# Progressing: 2.22 %
# Currently Running: HOUSEHOLD_1_080_CA_1
# Progressing: 2.26 %
# Currently Running: HOUSEHOLD_1_081_CA_1
# Progressing: 2.3 %
# Currently Running: HOUSEHOLD_1_082_CA_1
# Progressing: 2.34 %
# Currently Running: HOUSEHOLD_1_083_CA_1
# Progressing: 2.38 %
# Currently Running: HOUSEHOLD_1_086_CA_1
# Progressing: 2.43 %
# Currently Running: HOUSEHOLD_1_087_CA_1
# Progressing: 2.47 %
# Currently Running: HOUSEHOLD_1_088_CA_1
# Progressing: 2.51 %
# Currently Running: HOUSEHOLD_1_089_CA_1
# Progressing: 2.55 %
# Currently Running: HOUSEHOLD_1_090_CA_1
# Progressing: 2.59 %
# Currently Running: HOUSEHOLD_1_091_CA_1
# Progressing: 2.63 %
# Currently Running: HOUSEHOLD_1_093_CA_1
# Progressing: 2.68 %
# Currently Running: HOUSEHOLD_1_096_CA_1
# Progressing: 2.72 %
# Currently Running: HOUSEHOLD_1_097_CA_1
# Progressing: 2.76 %
# Currently Running: HOUSEHOLD_1_099_CA_1
# Progressing: 2.8 %
# Currently Running: HOUSEHOLD_1_100_CA_1
# Progressing: 2.84 %
# Currently Running: HOUSEHOLD_1_101_CA_1
# Progressing: 2.89 %
# Currently Running: HOUSEHOLD_1_102_CA_1
# Progressing: 2.93 %
# Currently Running: HOUSEHOLD_1_103_CA_1
# Progressing: 2.97 %
# Currently Running: HOUSEHOLD_1_105_CA_1
# Progressing: 3.01 %
# Currently Running: HOUSEHOLD_1_106_CA_1
# Progressing: 3.05 %
# Currently Running: HOUSEHOLD_1_107_CA_1
# Progressing: 3.09 %
# Currently Running: HOUSEHOLD_1_109_CA_1
# Progressing: 3.14 %
# Currently Running: HOUSEHOLD_1_110_CA_1
# Progressing: 3.18 %
# Currently Running: HOUSEHOLD_1_112_CA_1
# Progressing: 3.22 %
# Currently Running: HOUSEHOLD_1_114_CA_1
# Progressing: 3.26 %
# Currently Running: HOUSEHOLD_1_118_CA_1
# Progressing: 3.3 %
# Currently Running: HOUSEHOLD_1_120_CA_1
# Progressing: 3.35 %
# Currently Running: HOUSEHOLD_1_121_CA_1
# Progressing: 3.39 %
# Currently Running: HOUSEHOLD_1_122_CA_1
# Progressing: 3.43 %
# Currently Running: HOUSEHOLD_1_123_CA_1
# Progressing: 3.47 %
# Currently Running: HOUSEHOLD_1_124_CA_1
# Progressing: 3.51 %
# Currently Running: HOUSEHOLD_1_125_CA_1
# Progressing: 3.55 %
# Currently Running: HOUSEHOLD_1_126_CA_1
# Progressing: 3.6 %
# Currently Running: HOUSEHOLD_1_127_CA_1
# Progressing: 3.64 %
# Currently Running: HOUSEHOLD_1_128_CA_1
# Progressing: 3.68 %
# Currently Running: HOUSEHOLD_1_129_CA_1
# Progressing: 3.72 %
# Currently Running: HOUSEHOLD_1_130_CA_1
# Progressing: 3.76 %
# Currently Running: HOUSEHOLD_1_131_CA_1
# Progressing: 3.81 %
# Currently Running: HOUSEHOLD_1_134_CA_1
# Progressing: 3.85 %
# Currently Running: HOUSEHOLD_1_137_CA_1
# Progressing: 3.89 %
# Currently Running: HOUSEHOLD_1_138_CA_1
# Progressing: 3.93 %
# Currently Running: HOUSEHOLD_1_139_CA_1
# Progressing: 3.97 %
# Currently Running: HOUSEHOLD_1_140_CA_1
# Progressing: 4.02 %
# Currently Running: HOUSEHOLD_1_141_CA_1
# Progressing: 4.06 %
# Currently Running: HOUSEHOLD_1_142_CA_1
# Progressing: 4.1 %
# Currently Running: HOUSEHOLD_1_143_CA_1
# Progressing: 4.14 %
# Currently Running: HOUSEHOLD_1_146_CA_1
# Progressing: 4.18 %
# Currently Running: HOUSEHOLD_1_147_CA_1
# Progressing: 4.22 %
# Currently Running: HOUSEHOLD_1_149_CA_1
# Progressing: 4.27 %
# Currently Running: HOUSEHOLD_1_151_CA_1
# Progressing: 4.31 %
# Currently Running: HOUSEHOLD_1_153_CA_1
# Progressing: 4.35 %
# Currently Running: HOUSEHOLD_1_155_CA_1
# Progressing: 4.39 %
# Currently Running: HOUSEHOLD_1_156_CA_1
# Progressing: 4.43 %
# Currently Running: HOUSEHOLD_1_158_CA_1
# Progressing: 4.48 %
# Currently Running: HOUSEHOLD_1_159_CA_1
# Progressing: 4.52 %
# Currently Running: HOUSEHOLD_1_161_CA_1
# Progressing: 4.56 %
# Currently Running: HOUSEHOLD_1_162_CA_1
# Progressing: 4.6 %
# Currently Running: HOUSEHOLD_1_163_CA_1
# Progressing: 4.64 %
# Currently Running: HOUSEHOLD_1_164_CA_1
# Progressing: 4.68 %
# Currently Running: HOUSEHOLD_1_167_CA_1
# Progressing: 4.73 %
# Currently Running: HOUSEHOLD_1_168_CA_1
# Progressing: 4.77 %
# Currently Running: HOUSEHOLD_1_169_CA_1
# Progressing: 4.81 %
# Currently Running: HOUSEHOLD_1_171_CA_1
# Progressing: 4.85 %
# Currently Running: HOUSEHOLD_1_173_CA_1
# Progressing: 4.89 %
# Currently Running: HOUSEHOLD_1_176_CA_1
# Progressing: 4.94 %
# Currently Running: HOUSEHOLD_1_177_CA_1
# Progressing: 4.98 %
# Currently Running: HOUSEHOLD_1_178_CA_1
# Progressing: 5.02 %
# Currently Running: HOUSEHOLD_1_179_CA_1
# Progressing: 5.06 %
# Currently Running: HOUSEHOLD_1_180_CA_1
# Progressing: 5.1 %
# Currently Running: HOUSEHOLD_1_181_CA_1
# Progressing: 5.14 %
# Currently Running: HOUSEHOLD_1_185_CA_1
# Progressing: 5.19 %
# Currently Running: HOUSEHOLD_1_187_CA_1
# Progressing: 5.23 %
# Currently Running: HOUSEHOLD_1_188_CA_1
# Progressing: 5.27 %
# Currently Running: HOUSEHOLD_1_190_CA_1
# Progressing: 5.31 %
# Currently Running: HOUSEHOLD_1_192_CA_1
# Progressing: 5.35 %
# Currently Running: HOUSEHOLD_1_193_CA_1
# Progressing: 5.4 %
# Currently Running: HOUSEHOLD_1_194_CA_1
# Progressing: 5.44 %
# Currently Running: HOUSEHOLD_1_195_CA_1
# Progressing: 5.48 %
# Currently Running: HOUSEHOLD_1_196_CA_1
# Progressing: 5.52 %
# Currently Running: HOUSEHOLD_1_197_CA_1
# Progressing: 5.56 %
# Currently Running: HOUSEHOLD_1_198_CA_1
# Progressing: 5.6 %
# Currently Running: HOUSEHOLD_1_200_CA_1
# Progressing: 5.65 %
# Currently Running: HOUSEHOLD_1_201_CA_1
# Progressing: 5.69 %
# Currently Running: HOUSEHOLD_1_202_CA_1
# Progressing: 5.73 %
# Currently Running: HOUSEHOLD_1_203_CA_1
# Progressing: 5.77 %
# Currently Running: HOUSEHOLD_1_204_CA_1
# Progressing: 5.81 %
# Currently Running: HOUSEHOLD_1_205_CA_1
# Progressing: 5.86 %
# Currently Running: HOUSEHOLD_1_207_CA_1
# Progressing: 5.9 %
# Currently Running: HOUSEHOLD_1_208_CA_1
# Progressing: 5.94 %
# Currently Running: HOUSEHOLD_1_211_CA_1
# Progressing: 5.98 %
# Currently Running: HOUSEHOLD_1_213_CA_1
# Progressing: 6.02 %
# Currently Running: HOUSEHOLD_1_214_CA_1
# Progressing: 6.06 %
# Currently Running: HOUSEHOLD_1_215_CA_1
# Progressing: 6.11 %
# Currently Running: HOUSEHOLD_1_217_CA_1
# Progressing: 6.15 %
# Currently Running: HOUSEHOLD_1_218_CA_1
# Progressing: 6.19 %
# Currently Running: HOUSEHOLD_1_219_CA_1
# Progressing: 6.23 %
# Currently Running: HOUSEHOLD_1_220_CA_1
# Progressing: 6.27 %
# Currently Running: HOUSEHOLD_1_221_CA_1
# Progressing: 6.32 %
# Currently Running: HOUSEHOLD_1_225_CA_1
# Progressing: 6.36 %
# Currently Running: HOUSEHOLD_1_226_CA_1
# Progressing: 6.4 %
# Currently Running: HOUSEHOLD_1_227_CA_1
# Progressing: 6.44 %
# Currently Running: HOUSEHOLD_1_228_CA_1
# Progressing: 6.48 %
# Currently Running: HOUSEHOLD_1_229_CA_1
# Progressing: 6.52 %
# Currently Running: HOUSEHOLD_1_231_CA_1
# Progressing: 6.57 %
# Currently Running: HOUSEHOLD_1_232_CA_1
# Progressing: 6.61 %
# Currently Running: HOUSEHOLD_1_234_CA_1
# Progressing: 6.65 %
# Currently Running: HOUSEHOLD_1_235_CA_1
# Progressing: 6.69 %
# Currently Running: HOUSEHOLD_1_236_CA_1
# Progressing: 6.73 %
# Currently Running: HOUSEHOLD_1_238_CA_1
# Progressing: 6.78 %
# Currently Running: HOUSEHOLD_1_239_CA_1
# Progressing: 6.82 %
# Currently Running: HOUSEHOLD_1_241_CA_1
# Progressing: 6.86 %
# Currently Running: HOUSEHOLD_1_242_CA_1
# Progressing: 6.9 %
# Currently Running: HOUSEHOLD_1_243_CA_1
# Progressing: 6.94 %
# Currently Running: HOUSEHOLD_1_244_CA_1
# Progressing: 6.98 %
# Currently Running: HOUSEHOLD_1_246_CA_1
# Progressing: 7.03 %
# Currently Running: HOUSEHOLD_1_247_CA_1
# Progressing: 7.07 %
# Currently Running: HOUSEHOLD_1_248_CA_1
# Progressing: 7.11 %
# Currently Running: HOUSEHOLD_1_249_CA_1
# Progressing: 7.15 %
# Currently Running: HOUSEHOLD_1_250_CA_1
# Progressing: 7.19 %
# Currently Running: HOUSEHOLD_1_251_CA_1
# Progressing: 7.24 %
# Currently Running: HOUSEHOLD_1_252_CA_1
# Progressing: 7.28 %
# Currently Running: HOUSEHOLD_1_253_CA_1
# Progressing: 7.32 %
# Currently Running: HOUSEHOLD_1_254_CA_1
# Progressing: 7.36 %
# Currently Running: HOUSEHOLD_1_255_CA_1
# Progressing: 7.4 %
# Currently Running: HOUSEHOLD_1_256_CA_1
# Progressing: 7.44 %
# Currently Running: HOUSEHOLD_1_257_CA_1
# Progressing: 7.49 %
# Currently Running: HOUSEHOLD_1_259_CA_1
# Progressing: 7.53 %
# Currently Running: HOUSEHOLD_1_261_CA_1
# Progressing: 7.57 %
# Currently Running: HOUSEHOLD_1_262_CA_1
# Progressing: 7.61 %
# Currently Running: HOUSEHOLD_1_265_CA_1
# Progressing: 7.65 %
# Currently Running: HOUSEHOLD_1_266_CA_1
# Progressing: 7.7 %
# Currently Running: HOUSEHOLD_1_268_CA_1
# Progressing: 7.74 %
# Currently Running: HOUSEHOLD_1_269_CA_1
# Progressing: 7.78 %
# Currently Running: HOUSEHOLD_1_270_CA_1
# Progressing: 7.82 %
# Currently Running: HOUSEHOLD_1_271_CA_1
# Progressing: 7.86 %
# Currently Running: HOUSEHOLD_1_272_CA_1
# Progressing: 7.9 %
# Currently Running: HOUSEHOLD_1_275_CA_1
# Progressing: 7.95 %
# Currently Running: HOUSEHOLD_1_276_CA_1
# Progressing: 7.99 %
# Currently Running: HOUSEHOLD_1_277_CA_1
# Progressing: 8.03 %
# Currently Running: HOUSEHOLD_1_278_CA_1
# Progressing: 8.07 %
# Currently Running: HOUSEHOLD_1_279_CA_1
# Progressing: 8.11 %
# Currently Running: HOUSEHOLD_1_280_CA_1
# Progressing: 8.16 %
# Currently Running: HOUSEHOLD_1_281_CA_1
# Progressing: 8.2 %
# Currently Running: HOUSEHOLD_1_282_CA_1
# Progressing: 8.24 %
# Currently Running: HOUSEHOLD_1_283_CA_1
# Progressing: 8.28 %
# Currently Running: HOUSEHOLD_1_284_CA_1
# Progressing: 8.32 %
# Currently Running: HOUSEHOLD_1_285_CA_1
# Progressing: 8.36 %
# Currently Running: HOUSEHOLD_1_286_CA_1
# Progressing: 8.41 %
# Currently Running: HOUSEHOLD_1_287_CA_1
# Progressing: 8.45 %
# Currently Running: HOUSEHOLD_1_288_CA_1
# Progressing: 8.49 %
# Currently Running: HOUSEHOLD_1_289_CA_1
# Progressing: 8.53 %
# Currently Running: HOUSEHOLD_1_291_CA_1
# Progressing: 8.57 %
# Currently Running: HOUSEHOLD_1_292_CA_1
# Progressing: 8.62 %
# Currently Running: HOUSEHOLD_1_293_CA_1
# Progressing: 8.66 %
# Currently Running: HOUSEHOLD_1_294_CA_1
# Progressing: 8.7 %
# Currently Running: HOUSEHOLD_1_295_CA_1
# Progressing: 8.74 %
# Currently Running: HOUSEHOLD_1_296_CA_1
# Progressing: 8.78 %
# Currently Running: HOUSEHOLD_1_298_CA_1
# Progressing: 8.82 %
# Currently Running: HOUSEHOLD_1_299_CA_1
# Progressing: 8.87 %
# Currently Running: HOUSEHOLD_1_301_CA_1
# Progressing: 8.91 %
# Currently Running: HOUSEHOLD_1_303_CA_1
# Progressing: 8.95 %
# Currently Running: HOUSEHOLD_1_304_CA_1
# Progressing: 8.99 %
# Currently Running: HOUSEHOLD_1_305_CA_1
# Progressing: 9.03 %
# Currently Running: HOUSEHOLD_1_306_CA_1
# Progressing: 9.08 %
# Currently Running: HOUSEHOLD_1_307_CA_1
# Progressing: 9.12 %
# Currently Running: HOUSEHOLD_1_308_CA_1
# Progressing: 9.16 %
# Currently Running: HOUSEHOLD_1_309_CA_1
# Progressing: 9.2 %
# Currently Running: HOUSEHOLD_1_311_CA_1
# Progressing: 9.24 %
# Currently Running: HOUSEHOLD_1_312_CA_1
# Progressing: 9.28 %
# Currently Running: HOUSEHOLD_1_315_CA_1
# Progressing: 9.33 %
# Currently Running: HOUSEHOLD_1_316_CA_1
# Progressing: 9.37 %
# Currently Running: HOUSEHOLD_1_317_CA_1
# Progressing: 9.41 %
# Currently Running: HOUSEHOLD_1_318_CA_1
# Progressing: 9.45 %
# Currently Running: HOUSEHOLD_1_319_CA_1
# Progressing: 9.49 %
# Currently Running: HOUSEHOLD_1_320_CA_1
# Progressing: 9.54 %
# Currently Running: HOUSEHOLD_1_321_CA_1
# Progressing: 9.58 %
# Currently Running: HOUSEHOLD_1_322_CA_1
# Progressing: 9.62 %
# Currently Running: HOUSEHOLD_1_324_CA_1
# Progressing: 9.66 %
# Currently Running: HOUSEHOLD_1_327_CA_1
# Progressing: 9.7 %
# Currently Running: HOUSEHOLD_1_328_CA_1
# Progressing: 9.74 %
# Currently Running: HOUSEHOLD_1_329_CA_1
# Progressing: 9.79 %
# Currently Running: HOUSEHOLD_1_330_CA_1
# Progressing: 9.83 %
# Currently Running: HOUSEHOLD_1_331_CA_1
# Progressing: 9.87 %
# Currently Running: HOUSEHOLD_1_333_CA_1
# Progressing: 9.91 %
# Currently Running: HOUSEHOLD_1_334_CA_1
# Progressing: 9.95 %
# Currently Running: HOUSEHOLD_1_336_CA_1
# Progressing: 10.0 %
# Currently Running: HOUSEHOLD_1_337_CA_1
# Progressing: 10.04 %
# Currently Running: HOUSEHOLD_1_338_CA_1
# Progressing: 10.08 %
# Currently Running: HOUSEHOLD_1_339_CA_1
# Progressing: 10.12 %
# Currently Running: HOUSEHOLD_1_340_CA_1
# Progressing: 10.16 %
# Currently Running: HOUSEHOLD_1_342_CA_1
# Progressing: 10.2 %
# Currently Running: HOUSEHOLD_1_343_CA_1
# Progressing: 10.25 %
# Currently Running: HOUSEHOLD_1_344_CA_1
# Progressing: 10.29 %
# Currently Running: HOUSEHOLD_1_345_CA_1
# Progressing: 10.33 %
# Currently Running: HOUSEHOLD_1_346_CA_1
# Progressing: 10.37 %
# Currently Running: HOUSEHOLD_1_347_CA_1
# Progressing: 10.41 %
# Currently Running: HOUSEHOLD_1_348_CA_1
# Progressing: 10.46 %
# Currently Running: HOUSEHOLD_1_349_CA_1
# Progressing: 10.5 %
# Currently Running: HOUSEHOLD_1_350_CA_1
# Progressing: 10.54 %
# Currently Running: HOUSEHOLD_1_351_CA_1
# Progressing: 10.58 %
# Currently Running: HOUSEHOLD_1_353_CA_1
# Progressing: 10.62 %
# Currently Running: HOUSEHOLD_1_354_CA_1
# Progressing: 10.66 %
# Currently Running: HOUSEHOLD_1_355_CA_1
# Progressing: 10.71 %
# Currently Running: HOUSEHOLD_1_358_CA_1
# Progressing: 10.75 %
# Currently Running: HOUSEHOLD_1_360_CA_1
# Progressing: 10.79 %
# Currently Running: HOUSEHOLD_1_361_CA_1
# Progressing: 10.83 %
# Currently Running: HOUSEHOLD_1_362_CA_1
# Progressing: 10.87 %
# Currently Running: HOUSEHOLD_1_363_CA_1
# Progressing: 10.92 %
# Currently Running: HOUSEHOLD_1_364_CA_1
# Progressing: 10.96 %
# Currently Running: HOUSEHOLD_1_365_CA_1
# Progressing: 11.0 %
# Currently Running: HOUSEHOLD_1_367_CA_1
# Progressing: 11.04 %
# Currently Running: HOUSEHOLD_1_368_CA_1
# Progressing: 11.08 %
# Currently Running: HOUSEHOLD_1_369_CA_1
# Progressing: 11.13 %
# Currently Running: HOUSEHOLD_1_370_CA_1
# Progressing: 11.17 %
# Currently Running: HOUSEHOLD_1_371_CA_1
# Progressing: 11.21 %
# Currently Running: HOUSEHOLD_1_372_CA_1
# Progressing: 11.25 %
# Currently Running: HOUSEHOLD_1_373_CA_1
# Progressing: 11.29 %
# Currently Running: HOUSEHOLD_1_374_CA_1
# Progressing: 11.33 %
# Currently Running: HOUSEHOLD_1_375_CA_1
# Progressing: 11.38 %
# Currently Running: HOUSEHOLD_1_376_CA_1
# Progressing: 11.42 %
# Currently Running: HOUSEHOLD_1_377_CA_1
# Progressing: 11.46 %
# Currently Running: HOUSEHOLD_1_379_CA_1
# Progressing: 11.5 %
# Currently Running: HOUSEHOLD_1_380_CA_1
# Progressing: 11.54 %
# Currently Running: HOUSEHOLD_1_381_CA_1
# Progressing: 11.59 %
# Currently Running: HOUSEHOLD_1_382_CA_1
# Progressing: 11.63 %
# Currently Running: HOUSEHOLD_1_383_CA_1
# Progressing: 11.67 %
# Currently Running: HOUSEHOLD_1_384_CA_1
# Progressing: 11.71 %
# Currently Running: HOUSEHOLD_1_385_CA_1
# Progressing: 11.75 %
# Currently Running: HOUSEHOLD_1_386_CA_1
# Progressing: 11.79 %
# Currently Running: HOUSEHOLD_1_387_CA_1
# Progressing: 11.84 %
# Currently Running: HOUSEHOLD_1_388_CA_1
# Progressing: 11.88 %
# Currently Running: HOUSEHOLD_1_389_CA_1
# Progressing: 11.92 %
# Currently Running: HOUSEHOLD_1_390_CA_1
# Progressing: 11.96 %
# Currently Running: HOUSEHOLD_1_393_CA_1
# Progressing: 12.0 %
# Currently Running: HOUSEHOLD_1_394_CA_1
# Progressing: 12.05 %
# Currently Running: HOUSEHOLD_1_396_CA_1
# Progressing: 12.09 %
# Currently Running: HOUSEHOLD_1_397_CA_1
# Progressing: 12.13 %
# Currently Running: HOUSEHOLD_1_398_CA_1
# Progressing: 12.17 %
# Currently Running: HOUSEHOLD_1_399_CA_1
# Progressing: 12.21 %
# Currently Running: HOUSEHOLD_1_400_CA_1
# Progressing: 12.25 %
# Currently Running: HOUSEHOLD_1_403_CA_1
# Progressing: 12.3 %
# Currently Running: HOUSEHOLD_1_404_CA_1
# Progressing: 12.34 %
# Currently Running: HOUSEHOLD_1_405_CA_1
# Progressing: 12.38 %
# Currently Running: HOUSEHOLD_1_407_CA_1
# Progressing: 12.42 %
# Currently Running: HOUSEHOLD_1_408_CA_1
# Progressing: 12.46 %
# Currently Running: HOUSEHOLD_1_409_CA_1
# Progressing: 12.51 %
# Currently Running: HOUSEHOLD_1_411_CA_1
# Progressing: 12.55 %
# Currently Running: HOUSEHOLD_1_412_CA_1
# Progressing: 12.59 %
# Currently Running: HOUSEHOLD_1_413_CA_1
# Progressing: 12.63 %
# Currently Running: HOUSEHOLD_1_415_CA_1
# Progressing: 12.67 %
# Currently Running: HOUSEHOLD_1_417_CA_1
# Progressing: 12.71 %
# Currently Running: HOUSEHOLD_1_418_CA_1
# Progressing: 12.76 %
# Currently Running: HOUSEHOLD_1_419_CA_1
# Progressing: 12.8 %
# Currently Running: HOUSEHOLD_1_420_CA_1
# Progressing: 12.84 %
# Currently Running: HOUSEHOLD_1_422_CA_1
# Progressing: 12.88 %
# Currently Running: HOUSEHOLD_1_424_CA_1
# Progressing: 12.92 %
# Currently Running: HOUSEHOLD_1_425_CA_1
# Progressing: 12.97 %
# Currently Running: HOUSEHOLD_1_426_CA_1
# Progressing: 13.01 %
# Currently Running: HOUSEHOLD_1_427_CA_1
# Progressing: 13.05 %
# Currently Running: HOUSEHOLD_1_428_CA_1
# Progressing: 13.09 %
# Currently Running: HOUSEHOLD_1_429_CA_1
# Progressing: 13.13 %
# Currently Running: HOUSEHOLD_1_433_CA_1
# Progressing: 13.17 %
# Currently Running: HOUSEHOLD_1_434_CA_1
# Progressing: 13.22 %
# Currently Running: HOUSEHOLD_1_438_CA_1
# Progressing: 13.26 %
# Currently Running: HOUSEHOLD_1_439_CA_1
# Progressing: 13.3 %
# Currently Running: HOUSEHOLD_1_440_CA_1
# Progressing: 13.34 %
# Currently Running: HOUSEHOLD_1_441_CA_1
# Progressing: 13.38 %
# Currently Running: HOUSEHOLD_1_442_CA_1
# Progressing: 13.43 %
# Currently Running: HOUSEHOLD_1_443_CA_1
# Progressing: 13.47 %
# Currently Running: HOUSEHOLD_1_444_CA_1
# Progressing: 13.51 %
# Currently Running: HOUSEHOLD_1_445_CA_1
# Progressing: 13.55 %
# Currently Running: HOUSEHOLD_1_446_CA_1
# Progressing: 13.59 %
# Currently Running: HOUSEHOLD_1_447_CA_1
# Progressing: 13.63 %
# Currently Running: HOUSEHOLD_1_448_CA_1
# Progressing: 13.68 %
# Currently Running: HOUSEHOLD_1_449_CA_1
# Progressing: 13.72 %
# Currently Running: HOUSEHOLD_1_450_CA_1
# Progressing: 13.76 %
# Currently Running: HOUSEHOLD_1_451_CA_1
# Progressing: 13.8 %
# Currently Running: HOUSEHOLD_1_453_CA_1
# Progressing: 13.84 %
# Currently Running: HOUSEHOLD_1_454_CA_1
# Progressing: 13.89 %
# Currently Running: HOUSEHOLD_1_455_CA_1
# Progressing: 13.93 %
# Currently Running: HOUSEHOLD_1_457_CA_1
# Progressing: 13.97 %
# Currently Running: HOUSEHOLD_1_458_CA_1
# Progressing: 14.01 %
# Currently Running: HOUSEHOLD_1_459_CA_1
# Progressing: 14.05 %
# Currently Running: HOUSEHOLD_1_460_CA_1
# Progressing: 14.09 %
# Currently Running: HOUSEHOLD_1_461_CA_1
# Progressing: 14.14 %
# Currently Running: HOUSEHOLD_1_462_CA_1
# Progressing: 14.18 %
# Currently Running: HOUSEHOLD_1_464_CA_1
# Progressing: 14.22 %
# Currently Running: HOUSEHOLD_1_465_CA_1
# Progressing: 14.26 %
# Currently Running: HOUSEHOLD_1_466_CA_1
# Progressing: 14.3 %
# Currently Running: HOUSEHOLD_1_467_CA_1
# Progressing: 14.35 %
# Currently Running: HOUSEHOLD_1_468_CA_1
# Progressing: 14.39 %
# Currently Running: HOUSEHOLD_1_469_CA_1
# Progressing: 14.43 %
# Currently Running: HOUSEHOLD_1_471_CA_1
# Progressing: 14.47 %
# Currently Running: HOUSEHOLD_1_472_CA_1
# Progressing: 14.51 %
# Currently Running: HOUSEHOLD_1_473_CA_1
# Progressing: 14.55 %
# Currently Running: HOUSEHOLD_1_474_CA_1
# Progressing: 14.6 %
# Currently Running: HOUSEHOLD_1_475_CA_1
# Progressing: 14.64 %
# Currently Running: HOUSEHOLD_1_476_CA_1
# Progressing: 14.68 %
# Currently Running: HOUSEHOLD_1_477_CA_1
# Progressing: 14.72 %
# Currently Running: HOUSEHOLD_1_478_CA_1
# Progressing: 14.76 %
# Currently Running: HOUSEHOLD_1_479_CA_1
# Progressing: 14.81 %
# Currently Running: HOUSEHOLD_1_481_CA_1
# Progressing: 14.85 %
# Currently Running: HOUSEHOLD_1_482_CA_1
# Progressing: 14.89 %
# Currently Running: HOUSEHOLD_1_483_CA_1
# Progressing: 14.93 %
# Currently Running: HOUSEHOLD_1_484_CA_1
# Progressing: 14.97 %
# Currently Running: HOUSEHOLD_1_485_CA_1
# Progressing: 15.01 %
# Currently Running: HOUSEHOLD_1_486_CA_1
# Progressing: 15.06 %
# Currently Running: HOUSEHOLD_1_488_CA_1
# Progressing: 15.1 %
# Currently Running: HOUSEHOLD_1_489_CA_1
# Progressing: 15.14 %
# Currently Running: HOUSEHOLD_1_490_CA_1
# Progressing: 15.18 %
# Currently Running: HOUSEHOLD_1_491_CA_1
# Progressing: 15.22 %
# Currently Running: HOUSEHOLD_1_492_CA_1
# Progressing: 15.27 %
# Currently Running: HOUSEHOLD_1_493_CA_1
# Progressing: 15.31 %
# Currently Running: HOUSEHOLD_1_494_CA_1
# Progressing: 15.35 %
# Currently Running: HOUSEHOLD_1_495_CA_1
# Progressing: 15.39 %
# Currently Running: HOUSEHOLD_1_497_CA_1
# Progressing: 15.43 %
# Currently Running: HOUSEHOLD_1_498_CA_1
# Progressing: 15.47 %
# Currently Running: HOUSEHOLD_1_499_CA_1
# Progressing: 15.52 %
# Currently Running: HOUSEHOLD_1_500_CA_1
# Progressing: 15.56 %
# Currently Running: HOUSEHOLD_1_501_CA_1
# Progressing: 15.6 %
# Currently Running: HOUSEHOLD_1_503_CA_1
# Progressing: 15.64 %
# Currently Running: HOUSEHOLD_1_504_CA_1
# Progressing: 15.68 %
# Currently Running: HOUSEHOLD_1_505_CA_1
# Progressing: 15.73 %
# Currently Running: HOUSEHOLD_1_506_CA_1
# Progressing: 15.77 %
# Currently Running: HOUSEHOLD_1_507_CA_1
# Progressing: 15.81 %
# Currently Running: HOUSEHOLD_1_508_CA_1
# Progressing: 15.85 %
# Currently Running: HOUSEHOLD_1_509_CA_1
# Progressing: 15.89 %
# Currently Running: HOUSEHOLD_1_510_CA_1
# Progressing: 15.93 %
# Currently Running: HOUSEHOLD_1_511_CA_1
# Progressing: 15.98 %
# Currently Running: HOUSEHOLD_1_512_CA_1
# Progressing: 16.02 %
# Currently Running: HOUSEHOLD_1_514_CA_1
# Progressing: 16.06 %
# Currently Running: HOUSEHOLD_1_515_CA_1
# Progressing: 16.1 %
# Currently Running: HOUSEHOLD_1_516_CA_1
# Progressing: 16.14 %
# Currently Running: HOUSEHOLD_1_517_CA_1
# Progressing: 16.19 %
# Currently Running: HOUSEHOLD_1_519_CA_1
# Progressing: 16.23 %
# Currently Running: HOUSEHOLD_1_521_CA_1
# Progressing: 16.27 %
# Currently Running: HOUSEHOLD_1_522_CA_1
# Progressing: 16.31 %
# Currently Running: HOUSEHOLD_1_524_CA_1
# Progressing: 16.35 %
# Currently Running: HOUSEHOLD_1_525_CA_1
# Progressing: 16.39 %
# Currently Running: HOUSEHOLD_1_526_CA_1
# Progressing: 16.44 %
# Currently Running: HOUSEHOLD_1_527_CA_1
# Progressing: 16.48 %
# Currently Running: HOUSEHOLD_1_528_CA_1
# Progressing: 16.52 %
# Currently Running: HOUSEHOLD_1_529_CA_1
# Progressing: 16.56 %
# Currently Running: HOUSEHOLD_1_530_CA_1
# Progressing: 16.6 %
# Currently Running: HOUSEHOLD_1_531_CA_1
# Progressing: 16.65 %
# Currently Running: HOUSEHOLD_1_532_CA_1
# Progressing: 16.69 %
# Currently Running: HOUSEHOLD_1_534_CA_1
# Progressing: 16.73 %
# Currently Running: HOUSEHOLD_1_535_CA_1
# Progressing: 16.77 %
# Currently Running: HOUSEHOLD_1_536_CA_1
# Progressing: 16.81 %
# Currently Running: HOUSEHOLD_1_537_CA_1
# Progressing: 16.85 %
# Currently Running: HOUSEHOLD_1_538_CA_1
# Progressing: 16.9 %
# Currently Running: HOUSEHOLD_1_539_CA_1
# Progressing: 16.94 %
# Currently Running: HOUSEHOLD_1_540_CA_1
# Progressing: 16.98 %
# Currently Running: HOUSEHOLD_1_541_CA_1
# Progressing: 17.02 %
# Currently Running: HOUSEHOLD_2_001_CA_1
# Progressing: 17.06 %
# Currently Running: HOUSEHOLD_2_002_CA_1
# Progressing: 17.11 %
# Currently Running: HOUSEHOLD_2_007_CA_1
# Progressing: 17.15 %
# Currently Running: HOUSEHOLD_2_011_CA_1
# Progressing: 17.19 %
# Currently Running: HOUSEHOLD_2_014_CA_1
# Progressing: 17.23 %
# Currently Running: HOUSEHOLD_2_017_CA_1
# Progressing: 17.27 %
# Currently Running: HOUSEHOLD_2_020_CA_1
# Progressing: 17.31 %
# Currently Running: HOUSEHOLD_2_021_CA_1
# Progressing: 17.36 %
# Currently Running: HOUSEHOLD_2_025_CA_1
# Progressing: 17.4 %
# Currently Running: HOUSEHOLD_2_028_CA_1
# Progressing: 17.44 %
# Currently Running: HOUSEHOLD_2_030_CA_1
# Progressing: 17.48 %
# Currently Running: HOUSEHOLD_2_031_CA_1
# Progressing: 17.52 %
# Currently Running: HOUSEHOLD_2_032_CA_1
# Progressing: 17.57 %
# Currently Running: HOUSEHOLD_2_033_CA_1
# Progressing: 17.61 %
# Currently Running: HOUSEHOLD_2_035_CA_1
# Progressing: 17.65 %
# Currently Running: HOUSEHOLD_2_036_CA_1
# Progressing: 17.69 %
# Currently Running: HOUSEHOLD_2_037_CA_1
# Progressing: 17.73 %
# Currently Running: HOUSEHOLD_2_041_CA_1
# Progressing: 17.77 %
# Currently Running: HOUSEHOLD_2_043_CA_1
# Progressing: 17.82 %
# Currently Running: HOUSEHOLD_2_044_CA_1
# Progressing: 17.86 %
# Currently Running: HOUSEHOLD_2_047_CA_1
# Progressing: 17.9 %
# Currently Running: HOUSEHOLD_2_049_CA_1
# Progressing: 17.94 %
# Currently Running: HOUSEHOLD_2_050_CA_1
# Progressing: 17.98 %
# Currently Running: HOUSEHOLD_2_054_CA_1
# Progressing: 18.03 %
# Currently Running: HOUSEHOLD_2_055_CA_1
# Progressing: 18.07 %
# Currently Running: HOUSEHOLD_2_059_CA_1
# Progressing: 18.11 %
# Currently Running: HOUSEHOLD_2_061_CA_1
# Progressing: 18.15 %
# Currently Running: HOUSEHOLD_2_064_CA_1
# Progressing: 18.19 %
# Currently Running: HOUSEHOLD_2_066_CA_1
# Progressing: 18.24 %
# Currently Running: HOUSEHOLD_2_069_CA_1
# Progressing: 18.28 %
# Currently Running: HOUSEHOLD_2_070_CA_1
# Progressing: 18.32 %
# Currently Running: HOUSEHOLD_2_071_CA_1
# Progressing: 18.36 %
# Currently Running: HOUSEHOLD_2_072_CA_1
# Progressing: 18.4 %
# Currently Running: HOUSEHOLD_2_074_CA_1
# Progressing: 18.44 %
# Currently Running: HOUSEHOLD_2_075_CA_1
# Progressing: 18.49 %
# Currently Running: HOUSEHOLD_2_076_CA_1
# Progressing: 18.53 %
# Currently Running: HOUSEHOLD_2_077_CA_1
# Progressing: 18.57 %
# Currently Running: HOUSEHOLD_2_079_CA_1
# Progressing: 18.61 %
# Currently Running: HOUSEHOLD_2_081_CA_1
# Progressing: 18.65 %
# Currently Running: HOUSEHOLD_2_084_CA_1
# Progressing: 18.7 %
# Currently Running: HOUSEHOLD_2_095_CA_1
# Progressing: 18.74 %
# Currently Running: HOUSEHOLD_2_096_CA_1
# Progressing: 18.78 %
# Currently Running: HOUSEHOLD_2_102_CA_1
# Progressing: 18.82 %
# Currently Running: HOUSEHOLD_2_109_CA_1
# Progressing: 18.86 %
# Currently Running: HOUSEHOLD_2_110_CA_1
# Progressing: 18.9 %
# Currently Running: HOUSEHOLD_2_113_CA_1
# Progressing: 18.95 %
# Currently Running: HOUSEHOLD_2_115_CA_1
# Progressing: 18.99 %
# Currently Running: HOUSEHOLD_2_118_CA_1
# Progressing: 19.03 %
# Currently Running: HOUSEHOLD_2_119_CA_1
# Progressing: 19.07 %
# Currently Running: HOUSEHOLD_2_123_CA_1
# Progressing: 19.11 %
# Currently Running: HOUSEHOLD_2_124_CA_1
# Progressing: 19.16 %
# Currently Running: HOUSEHOLD_2_135_CA_1
# Progressing: 19.2 %
# Currently Running: HOUSEHOLD_2_136_CA_1
# Progressing: 19.24 %
# Currently Running: HOUSEHOLD_2_137_CA_1
# Progressing: 19.28 %
# Currently Running: HOUSEHOLD_2_139_CA_1
# Progressing: 19.32 %
# Currently Running: HOUSEHOLD_2_140_CA_1
# Progressing: 19.36 %
# Currently Running: HOUSEHOLD_2_142_CA_1
# Progressing: 19.41 %
# Currently Running: HOUSEHOLD_2_145_CA_1
# Progressing: 19.45 %
# Currently Running: HOUSEHOLD_2_150_CA_1
# Progressing: 19.49 %
# Currently Running: HOUSEHOLD_2_152_CA_1
# Progressing: 19.53 %
# Currently Running: HOUSEHOLD_2_153_CA_1
# Progressing: 19.57 %
# Currently Running: HOUSEHOLD_2_154_CA_1
# Progressing: 19.62 %
# Currently Running: HOUSEHOLD_2_155_CA_1
# Progressing: 19.66 %
# Currently Running: HOUSEHOLD_2_159_CA_1
# Progressing: 19.7 %
# Currently Running: HOUSEHOLD_2_160_CA_1
# Progressing: 19.74 %
# Currently Running: HOUSEHOLD_2_163_CA_1
# Progressing: 19.78 %
# Currently Running: HOUSEHOLD_2_165_CA_1
# Progressing: 19.82 %
# Currently Running: HOUSEHOLD_2_167_CA_1
# Progressing: 19.87 %
# Currently Running: HOUSEHOLD_2_170_CA_1
# Progressing: 19.91 %
# Currently Running: HOUSEHOLD_2_171_CA_1
# Progressing: 19.95 %
# Currently Running: HOUSEHOLD_2_172_CA_1
# Progressing: 19.99 %
# Currently Running: HOUSEHOLD_2_176_CA_1
# Progressing: 20.03 %
# Currently Running: HOUSEHOLD_2_179_CA_1
# Progressing: 20.08 %
# Currently Running: HOUSEHOLD_2_183_CA_1
# Progressing: 20.12 %
# Currently Running: HOUSEHOLD_2_184_CA_1
# Progressing: 20.16 %
# Currently Running: HOUSEHOLD_2_185_CA_1
# Progressing: 20.2 %
# Currently Running: HOUSEHOLD_2_188_CA_1
# Progressing: 20.24 %
# Currently Running: HOUSEHOLD_2_191_CA_1
# Progressing: 20.28 %
# Currently Running: HOUSEHOLD_2_193_CA_1
# Progressing: 20.33 %
# Currently Running: HOUSEHOLD_2_195_CA_1
# Progressing: 20.37 %
# Currently Running: HOUSEHOLD_2_196_CA_1
# Progressing: 20.41 %
# Currently Running: HOUSEHOLD_2_197_CA_1
# Progressing: 20.45 %
# Currently Running: HOUSEHOLD_2_199_CA_1
# Progressing: 20.49 %
# Currently Running: HOUSEHOLD_2_200_CA_1
# Progressing: 20.54 %
# Currently Running: HOUSEHOLD_2_201_CA_1
# Progressing: 20.58 %
# Currently Running: HOUSEHOLD_2_203_CA_1
# Progressing: 20.62 %
# Currently Running: HOUSEHOLD_2_205_CA_1
# Progressing: 20.66 %
# Currently Running: HOUSEHOLD_2_212_CA_1
# Progressing: 20.7 %
# Currently Running: HOUSEHOLD_2_213_CA_1
# Progressing: 20.74 %
# Currently Running: HOUSEHOLD_2_217_CA_1
# Progressing: 20.79 %
# Currently Running: HOUSEHOLD_2_219_CA_1
# Progressing: 20.83 %
# Currently Running: HOUSEHOLD_2_221_CA_1
# Progressing: 20.87 %
# Currently Running: HOUSEHOLD_2_222_CA_1
# Progressing: 20.91 %
# Currently Running: HOUSEHOLD_2_223_CA_1
# Progressing: 20.95 %
# Currently Running: HOUSEHOLD_2_225_CA_1
# Progressing: 21.0 %
# Currently Running: HOUSEHOLD_2_228_CA_1
# Progressing: 21.04 %
# Currently Running: HOUSEHOLD_2_231_CA_1
# Progressing: 21.08 %
# Currently Running: HOUSEHOLD_2_232_CA_1
# Progressing: 21.12 %
# Currently Running: HOUSEHOLD_2_233_CA_1
# Progressing: 21.16 %
# Currently Running: HOUSEHOLD_2_236_CA_1
# Progressing: 21.2 %
# Currently Running: HOUSEHOLD_2_239_CA_1
# Progressing: 21.25 %
# Currently Running: HOUSEHOLD_2_246_CA_1
# Progressing: 21.29 %
# Currently Running: HOUSEHOLD_2_247_CA_1
# Progressing: 21.33 %
# Currently Running: HOUSEHOLD_2_248_CA_1
# Progressing: 21.37 %
# Currently Running: HOUSEHOLD_2_250_CA_1
# Progressing: 21.41 %
# Currently Running: HOUSEHOLD_2_255_CA_1
# Progressing: 21.46 %
# Currently Running: HOUSEHOLD_2_256_CA_1
# Progressing: 21.5 %
# Currently Running: HOUSEHOLD_2_257_CA_1
# Progressing: 21.54 %
# Currently Running: HOUSEHOLD_2_259_CA_1
# Progressing: 21.58 %
# Currently Running: HOUSEHOLD_2_262_CA_1
# Progressing: 21.62 %
# Currently Running: HOUSEHOLD_2_264_CA_1
# Progressing: 21.66 %
# Currently Running: HOUSEHOLD_2_265_CA_1
# Progressing: 21.71 %
# Currently Running: HOUSEHOLD_2_269_CA_1
# Progressing: 21.75 %
# Currently Running: HOUSEHOLD_2_275_CA_1
# Progressing: 21.79 %
# Currently Running: HOUSEHOLD_2_279_CA_1
# Progressing: 21.83 %
# Currently Running: HOUSEHOLD_2_280_CA_1
# Progressing: 21.87 %
# Currently Running: HOUSEHOLD_2_281_CA_1
# Progressing: 21.92 %
# Currently Running: HOUSEHOLD_2_284_CA_1
# Progressing: 21.96 %
# Currently Running: HOUSEHOLD_2_285_CA_1
# Progressing: 22.0 %
# Currently Running: HOUSEHOLD_2_286_CA_1
# Progressing: 22.04 %
# Currently Running: HOUSEHOLD_2_287_CA_1
# Progressing: 22.08 %
# Currently Running: HOUSEHOLD_2_288_CA_1
# Progressing: 22.12 %
# Currently Running: HOUSEHOLD_2_290_CA_1
# Progressing: 22.17 %
# Currently Running: HOUSEHOLD_2_295_CA_1
# Progressing: 22.21 %
# Currently Running: HOUSEHOLD_2_297_CA_1
# Progressing: 22.25 %
# Currently Running: HOUSEHOLD_2_298_CA_1
# Progressing: 22.29 %
# Currently Running: HOUSEHOLD_2_299_CA_1
# Progressing: 22.33 %
# Currently Running: HOUSEHOLD_2_301_CA_1
# Progressing: 22.38 %
# Currently Running: HOUSEHOLD_2_303_CA_1
# Progressing: 22.42 %
# Currently Running: HOUSEHOLD_2_308_CA_1
# Progressing: 22.46 %
# Currently Running: HOUSEHOLD_2_310_CA_1
# Progressing: 22.5 %
# Currently Running: HOUSEHOLD_2_312_CA_1
# Progressing: 22.54 %
# Currently Running: HOUSEHOLD_2_313_CA_1
# Progressing: 22.58 %
# Currently Running: HOUSEHOLD_2_315_CA_1
# Progressing: 22.63 %
# Currently Running: HOUSEHOLD_2_317_CA_1
# Progressing: 22.67 %
# Currently Running: HOUSEHOLD_2_320_CA_1
# Progressing: 22.71 %
# Currently Running: HOUSEHOLD_2_322_CA_1
# Progressing: 22.75 %
# Currently Running: HOUSEHOLD_2_323_CA_1
# Progressing: 22.79 %
# Currently Running: HOUSEHOLD_2_324_CA_1
# Progressing: 22.84 %
# Currently Running: HOUSEHOLD_2_325_CA_1
# Progressing: 22.88 %
# Currently Running: HOUSEHOLD_2_326_CA_1
# Progressing: 22.92 %
# Currently Running: HOUSEHOLD_2_328_CA_1
# Progressing: 22.96 %
# Currently Running: HOUSEHOLD_2_329_CA_1
# Progressing: 23.0 %
# Currently Running: HOUSEHOLD_2_335_CA_1
# Progressing: 23.04 %
# Currently Running: HOUSEHOLD_2_336_CA_1
# Progressing: 23.09 %
# Currently Running: HOUSEHOLD_2_338_CA_1
# Progressing: 23.13 %
# Currently Running: HOUSEHOLD_2_341_CA_1
# Progressing: 23.17 %
# Currently Running: HOUSEHOLD_2_342_CA_1
# Progressing: 23.21 %
# Currently Running: HOUSEHOLD_2_343_CA_1
# Progressing: 23.25 %
# Currently Running: HOUSEHOLD_2_345_CA_1
# Progressing: 23.3 %
# Currently Running: HOUSEHOLD_2_346_CA_1
# Progressing: 23.34 %
# Currently Running: HOUSEHOLD_2_347_CA_1
# Progressing: 23.38 %
# Currently Running: HOUSEHOLD_2_348_CA_1
# Progressing: 23.42 %
# Currently Running: HOUSEHOLD_2_349_CA_1
# Progressing: 23.46 %
# Currently Running: HOUSEHOLD_2_350_CA_1
# Progressing: 23.5 %
# Currently Running: HOUSEHOLD_2_352_CA_1
# Progressing: 23.55 %
# Currently Running: HOUSEHOLD_2_353_CA_1
# Progressing: 23.59 %
# Currently Running: HOUSEHOLD_2_355_CA_1
# Progressing: 23.63 %
# Currently Running: HOUSEHOLD_2_356_CA_1
# Progressing: 23.67 %
# Currently Running: HOUSEHOLD_2_359_CA_1
# Progressing: 23.71 %
# Currently Running: HOUSEHOLD_2_361_CA_1
# Progressing: 23.76 %
# Currently Running: HOUSEHOLD_2_366_CA_1
# Progressing: 23.8 %
# Currently Running: HOUSEHOLD_2_367_CA_1
# Progressing: 23.84 %
# Currently Running: HOUSEHOLD_2_368_CA_1
# Progressing: 23.88 %
# Currently Running: HOUSEHOLD_2_369_CA_1
# Progressing: 23.92 %
# Currently Running: HOUSEHOLD_2_371_CA_1
# Progressing: 23.96 %
# Currently Running: HOUSEHOLD_2_373_CA_1
# Progressing: 24.01 %
# Currently Running: HOUSEHOLD_2_374_CA_1
# Progressing: 24.05 %
# Currently Running: HOUSEHOLD_2_375_CA_1
# Progressing: 24.09 %
# Currently Running: HOUSEHOLD_2_376_CA_1
# Progressing: 24.13 %
# Currently Running: HOUSEHOLD_2_377_CA_1
# Progressing: 24.17 %
# Currently Running: HOUSEHOLD_2_380_CA_1
# Progressing: 24.22 %
# Currently Running: HOUSEHOLD_2_382_CA_1
# Progressing: 24.26 %
# Currently Running: HOUSEHOLD_2_388_CA_1
# Progressing: 24.3 %
# Currently Running: HOUSEHOLD_2_389_CA_1
# Progressing: 24.34 %
# Currently Running: HOUSEHOLD_2_390_CA_1
# Progressing: 24.38 %
# Currently Running: HOUSEHOLD_2_391_CA_1
# Progressing: 24.42 %
# Currently Running: HOUSEHOLD_2_395_CA_1
# Progressing: 24.47 %
# Currently Running: HOUSEHOLD_2_399_CA_1
# Progressing: 24.51 %
# Currently Running: HOUSEHOLD_2_400_CA_1
# Progressing: 24.55 %
# Currently Running: HOUSEHOLD_2_401_CA_1
# Progressing: 24.59 %
# Currently Running: HOUSEHOLD_2_402_CA_1
# Progressing: 24.63 %
# Currently Running: HOUSEHOLD_2_403_CA_1
# Progressing: 24.68 %
# Currently Running: HOUSEHOLD_2_404_CA_1
# Progressing: 24.72 %
# Currently Running: HOUSEHOLD_2_406_CA_1
# Progressing: 24.76 %
# Currently Running: HOUSEHOLD_2_407_CA_1
# Progressing: 24.8 %
# Currently Running: HOUSEHOLD_2_409_CA_1
# Progressing: 24.84 %
# Currently Running: HOUSEHOLD_2_410_CA_1
# Progressing: 24.88 %
# Currently Running: HOUSEHOLD_2_411_CA_1
# Progressing: 24.93 %
# Currently Running: HOUSEHOLD_2_413_CA_1
# Progressing: 24.97 %
# Currently Running: HOUSEHOLD_2_417_CA_1
# Progressing: 25.01 %
# Currently Running: HOUSEHOLD_2_418_CA_1
# Progressing: 25.05 %
# Currently Running: HOUSEHOLD_2_421_CA_1
# Progressing: 25.09 %
# Currently Running: HOUSEHOLD_2_424_CA_1
# Progressing: 25.14 %
# Currently Running: HOUSEHOLD_2_426_CA_1
# Progressing: 25.18 %
# Currently Running: HOUSEHOLD_2_427_CA_1
# Progressing: 25.22 %
# Currently Running: HOUSEHOLD_2_431_CA_1
# Progressing: 25.26 %
# Currently Running: HOUSEHOLD_2_435_CA_1
# Progressing: 25.3 %
# Currently Running: HOUSEHOLD_2_437_CA_1
# Progressing: 25.35 %
# Currently Running: HOUSEHOLD_2_438_CA_1
# Progressing: 25.39 %
# Currently Running: HOUSEHOLD_2_440_CA_1
# Progressing: 25.43 %
# Currently Running: HOUSEHOLD_2_442_CA_1
# Progressing: 25.47 %
# Currently Running: HOUSEHOLD_2_443_CA_1
# Progressing: 25.51 %
# Currently Running: HOUSEHOLD_2_447_CA_1
# Progressing: 25.55 %
# Currently Running: HOUSEHOLD_2_450_CA_1
# Progressing: 25.6 %
# Currently Running: HOUSEHOLD_2_451_CA_1
# Progressing: 25.64 %
# Currently Running: HOUSEHOLD_2_453_CA_1
# Progressing: 25.68 %
# Currently Running: HOUSEHOLD_2_457_CA_1
# Progressing: 25.72 %
# Currently Running: HOUSEHOLD_2_465_CA_1
# Progressing: 25.76 %
# Currently Running: HOUSEHOLD_2_467_CA_1
# Progressing: 25.81 %
# Currently Running: HOUSEHOLD_2_468_CA_1
# Progressing: 25.85 %
# Currently Running: HOUSEHOLD_2_470_CA_1
# Progressing: 25.89 %
# Currently Running: HOUSEHOLD_2_472_CA_1
# Progressing: 25.93 %
# Currently Running: HOUSEHOLD_2_483_CA_1
# Progressing: 25.97 %
# Currently Running: HOUSEHOLD_2_485_CA_1
# Progressing: 26.01 %
# Currently Running: HOUSEHOLD_2_486_CA_1
# Progressing: 26.06 %
# Currently Running: HOUSEHOLD_2_488_CA_1
# Progressing: 26.1 %
# Currently Running: HOUSEHOLD_2_490_CA_1
# Progressing: 26.14 %
# Currently Running: HOUSEHOLD_2_492_CA_1
# Progressing: 26.18 %
# Currently Running: HOUSEHOLD_2_493_CA_1
# Progressing: 26.22 %
# Currently Running: HOUSEHOLD_2_496_CA_1
# Progressing: 26.27 %
# Currently Running: HOUSEHOLD_2_499_CA_1
# Progressing: 26.31 %
# Currently Running: HOUSEHOLD_2_500_CA_1
# Progressing: 26.35 %
# Currently Running: HOUSEHOLD_2_501_CA_1
# Progressing: 26.39 %
# Currently Running: HOUSEHOLD_2_505_CA_1
# Progressing: 26.43 %
# Currently Running: HOUSEHOLD_2_506_CA_1
# Progressing: 26.47 %
# Currently Running: HOUSEHOLD_2_509_CA_1
# Progressing: 26.52 %
# Currently Running: HOUSEHOLD_2_510_CA_1
# Progressing: 26.56 %
# Currently Running: HOUSEHOLD_2_511_CA_1
# Progressing: 26.6 %
# Currently Running: HOUSEHOLD_2_512_CA_1
# Progressing: 26.64 %
# Currently Running: HOUSEHOLD_2_514_CA_1
# Progressing: 26.68 %
# Currently Running: HOUSEHOLD_1_003_CA_2
# Progressing: 26.73 %
# Currently Running: HOUSEHOLD_1_005_CA_2
# Progressing: 26.77 %
# Currently Running: HOUSEHOLD_1_006_CA_2
# Progressing: 26.81 %
# Currently Running: HOUSEHOLD_1_007_CA_2
# Progressing: 26.85 %
# Currently Running: HOUSEHOLD_1_009_CA_2
# Progressing: 26.89 %
# Currently Running: HOUSEHOLD_1_011_CA_2
# Progressing: 26.93 %
# Currently Running: HOUSEHOLD_1_012_CA_2
# Progressing: 26.98 %
# Currently Running: HOUSEHOLD_1_014_CA_2
# Progressing: 27.02 %
# Currently Running: HOUSEHOLD_1_016_CA_2
# Progressing: 27.06 %
# Currently Running: HOUSEHOLD_1_017_CA_2
# Progressing: 27.1 %
# Currently Running: HOUSEHOLD_1_019_CA_2
# Progressing: 27.14 %
# Currently Running: HOUSEHOLD_1_020_CA_2
# Progressing: 27.19 %
# Currently Running: HOUSEHOLD_1_021_CA_2
# Progressing: 27.23 %
# Currently Running: HOUSEHOLD_1_022_CA_2
# Progressing: 27.27 %
# Currently Running: HOUSEHOLD_1_023_CA_2
# Progressing: 27.31 %
# Currently Running: HOUSEHOLD_1_024_CA_2
# Progressing: 27.35 %
# Currently Running: HOUSEHOLD_1_025_CA_2
# Progressing: 27.39 %
# Currently Running: HOUSEHOLD_1_027_CA_2
# Progressing: 27.44 %
# Currently Running: HOUSEHOLD_1_029_CA_2
# Progressing: 27.48 %
# Currently Running: HOUSEHOLD_1_030_CA_2
# Progressing: 27.52 %
# Currently Running: HOUSEHOLD_1_034_CA_2
# Progressing: 27.56 %
# Currently Running: HOUSEHOLD_1_038_CA_2
# Progressing: 27.6 %
# Currently Running: HOUSEHOLD_1_039_CA_2
# Progressing: 27.65 %
# Currently Running: HOUSEHOLD_1_040_CA_2
# Progressing: 27.69 %
# Currently Running: HOUSEHOLD_1_043_CA_2
# Progressing: 27.73 %
# Currently Running: HOUSEHOLD_1_044_CA_2
# Progressing: 27.77 %
# Currently Running: HOUSEHOLD_1_045_CA_2
# Progressing: 27.81 %
# Currently Running: HOUSEHOLD_1_046_CA_2
# Progressing: 27.85 %
# Currently Running: HOUSEHOLD_1_047_CA_2
# Progressing: 27.9 %
# Currently Running: HOUSEHOLD_1_048_CA_2
# Progressing: 27.94 %
# Currently Running: HOUSEHOLD_1_050_CA_2
# Progressing: 27.98 %
# Currently Running: HOUSEHOLD_1_051_CA_2
# Progressing: 28.02 %
# Currently Running: HOUSEHOLD_1_053_CA_2
# Progressing: 28.06 %
# Currently Running: HOUSEHOLD_1_054_CA_2
# Progressing: 28.11 %
# Currently Running: HOUSEHOLD_1_055_CA_2
# Progressing: 28.15 %
# Currently Running: HOUSEHOLD_1_058_CA_2
# Progressing: 28.19 %
# Currently Running: HOUSEHOLD_1_060_CA_2
# Progressing: 28.23 %
# Currently Running: HOUSEHOLD_1_061_CA_2
# Progressing: 28.27 %
# Currently Running: HOUSEHOLD_1_066_CA_2
# Progressing: 28.31 %
# Currently Running: HOUSEHOLD_1_068_CA_2
# Progressing: 28.36 %
# Currently Running: HOUSEHOLD_1_069_CA_2
# Progressing: 28.4 %
# Currently Running: HOUSEHOLD_1_070_CA_2
# Progressing: 28.44 %
# Currently Running: HOUSEHOLD_1_071_CA_2
# Progressing: 28.48 %
# Currently Running: HOUSEHOLD_1_072_CA_2
# Progressing: 28.52 %
# Currently Running: HOUSEHOLD_1_073_CA_2
# Progressing: 28.57 %
# Currently Running: HOUSEHOLD_1_074_CA_2
# Progressing: 28.61 %
# Currently Running: HOUSEHOLD_1_075_CA_2
# Progressing: 28.65 %
# Currently Running: HOUSEHOLD_1_077_CA_2
# Progressing: 28.69 %
# Currently Running: HOUSEHOLD_1_078_CA_2
# Progressing: 28.73 %
# Currently Running: HOUSEHOLD_1_079_CA_2
# Progressing: 28.77 %
# Currently Running: HOUSEHOLD_1_080_CA_2
# Progressing: 28.82 %
# Currently Running: HOUSEHOLD_1_081_CA_2
# Progressing: 28.86 %
# Currently Running: HOUSEHOLD_1_082_CA_2
# Progressing: 28.9 %
# Currently Running: HOUSEHOLD_1_083_CA_2
# Progressing: 28.94 %
# Currently Running: HOUSEHOLD_1_086_CA_2
# Progressing: 28.98 %
# Currently Running: HOUSEHOLD_1_087_CA_2
# Progressing: 29.03 %
# Currently Running: HOUSEHOLD_1_091_CA_2
# Progressing: 29.07 %
# Currently Running: HOUSEHOLD_1_093_CA_2
# Progressing: 29.11 %
# Currently Running: HOUSEHOLD_1_094_CA_2
# Progressing: 29.15 %
# Currently Running: HOUSEHOLD_1_095_CA_2
# Progressing: 29.19 %
# Currently Running: HOUSEHOLD_1_096_CA_2
# Progressing: 29.23 %
# Currently Running: HOUSEHOLD_1_097_CA_2
# Progressing: 29.28 %
# Currently Running: HOUSEHOLD_1_098_CA_2
# Progressing: 29.32 %
# Currently Running: HOUSEHOLD_1_099_CA_2
# Progressing: 29.36 %
# Currently Running: HOUSEHOLD_1_100_CA_2
# Progressing: 29.4 %
# Currently Running: HOUSEHOLD_1_101_CA_2
# Progressing: 29.44 %
# Currently Running: HOUSEHOLD_1_102_CA_2
# Progressing: 29.49 %
# Currently Running: HOUSEHOLD_1_103_CA_2
# Progressing: 29.53 %
# Currently Running: HOUSEHOLD_1_106_CA_2
# Progressing: 29.57 %
# Currently Running: HOUSEHOLD_1_107_CA_2
# Progressing: 29.61 %
# Currently Running: HOUSEHOLD_1_109_CA_2
# Progressing: 29.65 %
# Currently Running: HOUSEHOLD_1_110_CA_2
# Progressing: 29.69 %
# Currently Running: HOUSEHOLD_1_112_CA_2
# Progressing: 29.74 %
# Currently Running: HOUSEHOLD_1_113_CA_2
# Progressing: 29.78 %
# Currently Running: HOUSEHOLD_1_114_CA_2
# Progressing: 29.82 %
# Currently Running: HOUSEHOLD_1_115_CA_2
# Progressing: 29.86 %
# Currently Running: HOUSEHOLD_1_118_CA_2
# Progressing: 29.9 %
# Currently Running: HOUSEHOLD_1_121_CA_2
# Progressing: 29.95 %
# Currently Running: HOUSEHOLD_1_122_CA_2
# Progressing: 29.99 %
# Currently Running: HOUSEHOLD_1_124_CA_2
# Progressing: 30.03 %
# Currently Running: HOUSEHOLD_1_125_CA_2
# Progressing: 30.07 %
# Currently Running: HOUSEHOLD_1_126_CA_2
# Progressing: 30.11 %
# Currently Running: HOUSEHOLD_1_127_CA_2
# Progressing: 30.15 %
# Currently Running: HOUSEHOLD_1_128_CA_2
# Progressing: 30.2 %
# Currently Running: HOUSEHOLD_1_129_CA_2
# Progressing: 30.24 %
# Currently Running: HOUSEHOLD_1_130_CA_2
# Progressing: 30.28 %
# Currently Running: HOUSEHOLD_1_131_CA_2
# Progressing: 30.32 %
# Currently Running: HOUSEHOLD_1_133_CA_2
# Progressing: 30.36 %
# Currently Running: HOUSEHOLD_1_134_CA_2
# Progressing: 30.41 %
# Currently Running: HOUSEHOLD_1_135_CA_2
# Progressing: 30.45 %
# Currently Running: HOUSEHOLD_1_138_CA_2
# Progressing: 30.49 %
# Currently Running: HOUSEHOLD_1_139_CA_2
# Progressing: 30.53 %
# Currently Running: HOUSEHOLD_1_141_CA_2
# Progressing: 30.57 %
# Currently Running: HOUSEHOLD_1_142_CA_2
# Progressing: 30.61 %
# Currently Running: HOUSEHOLD_1_143_CA_2
# Progressing: 30.66 %
# Currently Running: HOUSEHOLD_1_146_CA_2
# Progressing: 30.7 %
# Currently Running: HOUSEHOLD_1_149_CA_2
# Progressing: 30.74 %
# Currently Running: HOUSEHOLD_1_151_CA_2
# Progressing: 30.78 %
# Currently Running: HOUSEHOLD_1_153_CA_2
# Progressing: 30.82 %
# Currently Running: HOUSEHOLD_1_155_CA_2
# Progressing: 30.87 %
# Currently Running: HOUSEHOLD_1_156_CA_2
# Progressing: 30.91 %
# Currently Running: HOUSEHOLD_1_158_CA_2
# Progressing: 30.95 %
# Currently Running: HOUSEHOLD_1_159_CA_2
# Progressing: 30.99 %
# Currently Running: HOUSEHOLD_1_162_CA_2
# Progressing: 31.03 %
# Currently Running: HOUSEHOLD_1_164_CA_2
# Progressing: 31.07 %
# Currently Running: HOUSEHOLD_1_165_CA_2
# Progressing: 31.12 %
# Currently Running: HOUSEHOLD_1_167_CA_2
# Progressing: 31.16 %
# Currently Running: HOUSEHOLD_1_169_CA_2
# Progressing: 31.2 %
# Currently Running: HOUSEHOLD_1_170_CA_2
# Progressing: 31.24 %
# Currently Running: HOUSEHOLD_1_171_CA_2
# Progressing: 31.28 %
# Currently Running: HOUSEHOLD_1_172_CA_2
# Progressing: 31.33 %
# Currently Running: HOUSEHOLD_1_173_CA_2
# Progressing: 31.37 %
# Currently Running: HOUSEHOLD_1_175_CA_2
# Progressing: 31.41 %
# Currently Running: HOUSEHOLD_1_176_CA_2
# Progressing: 31.45 %
# Currently Running: HOUSEHOLD_1_177_CA_2
# Progressing: 31.49 %
# Currently Running: HOUSEHOLD_1_178_CA_2
# Progressing: 31.53 %
# Currently Running: HOUSEHOLD_1_179_CA_2
# Progressing: 31.58 %
# Currently Running: HOUSEHOLD_1_180_CA_2
# Progressing: 31.62 %
# Currently Running: HOUSEHOLD_1_181_CA_2
# Progressing: 31.66 %
# Currently Running: HOUSEHOLD_1_185_CA_2
# Progressing: 31.7 %
# Currently Running: HOUSEHOLD_1_187_CA_2
# Progressing: 31.74 %
# Currently Running: HOUSEHOLD_1_188_CA_2
# Progressing: 31.79 %
# Currently Running: HOUSEHOLD_1_190_CA_2
# Progressing: 31.83 %
# Currently Running: HOUSEHOLD_1_191_CA_2
# Progressing: 31.87 %
# Currently Running: HOUSEHOLD_1_192_CA_2
# Progressing: 31.91 %
# Currently Running: HOUSEHOLD_1_194_CA_2
# Progressing: 31.95 %
# Currently Running: HOUSEHOLD_1_195_CA_2
# Progressing: 31.99 %
# Currently Running: HOUSEHOLD_1_196_CA_2
# Progressing: 32.04 %
# Currently Running: HOUSEHOLD_1_197_CA_2
# Progressing: 32.08 %
# Currently Running: HOUSEHOLD_1_198_CA_2
# Progressing: 32.12 %
# Currently Running: HOUSEHOLD_1_200_CA_2
# Progressing: 32.16 %
# Currently Running: HOUSEHOLD_1_201_CA_2
# Progressing: 32.2 %
# Currently Running: HOUSEHOLD_1_202_CA_2
# Progressing: 32.25 %
# Currently Running: HOUSEHOLD_1_204_CA_2
# Progressing: 32.29 %
# Currently Running: HOUSEHOLD_1_205_CA_2
# Progressing: 32.33 %
# Currently Running: HOUSEHOLD_1_208_CA_2
# Progressing: 32.37 %
# Currently Running: HOUSEHOLD_1_211_CA_2
# Progressing: 32.41 %
# Currently Running: HOUSEHOLD_1_212_CA_2
# Progressing: 32.46 %
# Currently Running: HOUSEHOLD_1_213_CA_2
# Progressing: 32.5 %
# Currently Running: HOUSEHOLD_1_214_CA_2
# Progressing: 32.54 %
# Currently Running: HOUSEHOLD_1_215_CA_2
# Progressing: 32.58 %
# Currently Running: HOUSEHOLD_1_217_CA_2
# Progressing: 32.62 %
# Currently Running: HOUSEHOLD_1_218_CA_2
# Progressing: 32.66 %
# Currently Running: HOUSEHOLD_1_220_CA_2
# Progressing: 32.71 %
# Currently Running: HOUSEHOLD_1_221_CA_2
# Progressing: 32.75 %
# Currently Running: HOUSEHOLD_1_225_CA_2
# Progressing: 32.79 %
# Currently Running: HOUSEHOLD_1_226_CA_2
# Progressing: 32.83 %
# Currently Running: HOUSEHOLD_1_227_CA_2
# Progressing: 32.87 %
# Currently Running: HOUSEHOLD_1_228_CA_2
# Progressing: 32.92 %
# Currently Running: HOUSEHOLD_1_229_CA_2
# Progressing: 32.96 %
# Currently Running: HOUSEHOLD_1_231_CA_2
# Progressing: 33.0 %
# Currently Running: HOUSEHOLD_1_232_CA_2
# Progressing: 33.04 %
# Currently Running: HOUSEHOLD_1_234_CA_2
# Progressing: 33.08 %
# ...
# Progressing: 89.04 %
# Currently Running: HOUSEHOLD_1_351_CA_4
# Progressing: 89.08 %
# Currently Running: HOUSEHOLD_1_353_CA_4
# Progressing: 89.13 %
# Currently Running: HOUSEHOLD_1_354_CA_4
# Progressing: 89.17 %
# Currently Running: HOUSEHOLD_1_356_CA_4
# Progressing: 89.21 %
# Currently Running: HOUSEHOLD_1_358_CA_4
# Progressing: 89.25 %
# Currently Running: HOUSEHOLD_1_360_CA_4
# Progressing: 89.29 %
# Currently Running: HOUSEHOLD_1_361_CA_4
# Progressing: 89.34 %
# Currently Running: HOUSEHOLD_1_362_CA_4
# Progressing: 89.38 %
# Currently Running: HOUSEHOLD_1_363_CA_4
# Progressing: 89.42 %
# Currently Running: HOUSEHOLD_1_364_CA_4
# Progressing: 89.46 %
# Currently Running: HOUSEHOLD_1_365_CA_4
# Progressing: 89.5 %
# Currently Running: HOUSEHOLD_1_366_CA_4
# Progressing: 89.54 %
# Currently Running: HOUSEHOLD_1_369_CA_4
# Progressing: 89.59 %
# Currently Running: HOUSEHOLD_1_370_CA_4
# Progressing: 89.63 %
# Currently Running: HOUSEHOLD_1_372_CA_4
# Progressing: 89.67 %
# Currently Running: HOUSEHOLD_1_373_CA_4
# Progressing: 89.71 %
# Currently Running: HOUSEHOLD_1_376_CA_4
# Progressing: 89.75 %
# Currently Running: HOUSEHOLD_1_377_CA_4
# Progressing: 89.8 %
# Currently Running: HOUSEHOLD_1_380_CA_4
# Progressing: 89.84 %
# Currently Running: HOUSEHOLD_1_381_CA_4
# Progressing: 89.88 %
# Currently Running: HOUSEHOLD_1_382_CA_4
# Progressing: 89.92 %
# Currently Running: HOUSEHOLD_1_383_CA_4
# Progressing: 89.96 %
# Currently Running: HOUSEHOLD_1_384_CA_4
# Progressing: 90.0 %
# Currently Running: HOUSEHOLD_1_385_CA_4
# Progressing: 90.05 %
# Currently Running: HOUSEHOLD_1_386_CA_4
# Progressing: 90.09 %
# Currently Running: HOUSEHOLD_1_387_CA_4
# Progressing: 90.13 %
# Currently Running: HOUSEHOLD_1_389_CA_4
# Progressing: 90.17 %
# Currently Running: HOUSEHOLD_1_390_CA_4
# Progressing: 90.21 %
# Currently Running: HOUSEHOLD_1_393_CA_4
# Progressing: 90.26 %
# Currently Running: HOUSEHOLD_1_394_CA_4
# Progressing: 90.3 %
# Currently Running: HOUSEHOLD_1_395_CA_4
# Progressing: 90.34 %
# Currently Running: HOUSEHOLD_1_396_CA_4
# Progressing: 90.38 %
# Currently Running: HOUSEHOLD_1_397_CA_4
# Progressing: 90.42 %
# Currently Running: HOUSEHOLD_1_398_CA_4
# Progressing: 90.46 %
# Currently Running: HOUSEHOLD_1_399_CA_4
# Progressing: 90.51 %
# Currently Running: HOUSEHOLD_1_403_CA_4
# Progressing: 90.55 %
# Currently Running: HOUSEHOLD_1_404_CA_4
# Progressing: 90.59 %
# Currently Running: HOUSEHOLD_1_405_CA_4
# Progressing: 90.63 %
# Currently Running: HOUSEHOLD_1_407_CA_4
# Progressing: 90.67 %
# Currently Running: HOUSEHOLD_1_408_CA_4
# Progressing: 90.72 %
# Currently Running: HOUSEHOLD_1_409_CA_4
# Progressing: 90.76 %
# Currently Running: HOUSEHOLD_1_411_CA_4
# Progressing: 90.8 %
# Currently Running: HOUSEHOLD_1_412_CA_4
# Progressing: 90.84 %
# Currently Running: HOUSEHOLD_1_413_CA_4
# Progressing: 90.88 %
# Currently Running: HOUSEHOLD_1_415_CA_4
# Progressing: 90.92 %
# Currently Running: HOUSEHOLD_1_417_CA_4
# Progressing: 90.97 %
# Currently Running: HOUSEHOLD_1_418_CA_4
# Progressing: 91.01 %
# Currently Running: HOUSEHOLD_1_419_CA_4
# Progressing: 91.05 %
# Currently Running: HOUSEHOLD_1_420_CA_4
# Progressing: 91.09 %
# Currently Running: HOUSEHOLD_1_422_CA_4
# Progressing: 91.13 %
# Currently Running: HOUSEHOLD_1_424_CA_4
# Progressing: 91.18 %
# Currently Running: HOUSEHOLD_1_425_CA_4
# Progressing: 91.22 %
# Currently Running: HOUSEHOLD_1_426_CA_4
# Progressing: 91.26 %
# Currently Running: HOUSEHOLD_1_427_CA_4
# Progressing: 91.3 %
# Currently Running: HOUSEHOLD_1_428_CA_4
# Progressing: 91.34 %
# Currently Running: HOUSEHOLD_1_429_CA_4
# Progressing: 91.38 %
# Currently Running: HOUSEHOLD_1_430_CA_4
# Progressing: 91.43 %
# Currently Running: HOUSEHOLD_1_433_CA_4
# Progressing: 91.47 %
# Currently Running: HOUSEHOLD_1_434_CA_4
# Progressing: 91.51 %
# Currently Running: HOUSEHOLD_1_437_CA_4
# Progressing: 91.55 %
# Currently Running: HOUSEHOLD_1_438_CA_4
# Progressing: 91.59 %
# Currently Running: HOUSEHOLD_1_439_CA_4
# Progressing: 91.64 %
# Currently Running: HOUSEHOLD_1_440_CA_4
# Progressing: 91.68 %
# Currently Running: HOUSEHOLD_1_441_CA_4
# Progressing: 91.72 %
# Currently Running: HOUSEHOLD_1_442_CA_4
# Progressing: 91.76 %
# Currently Running: HOUSEHOLD_1_443_CA_4
# Progressing: 91.8 %
# Currently Running: HOUSEHOLD_1_444_CA_4
# Progressing: 91.84 %
# Currently Running: HOUSEHOLD_1_445_CA_4
# Progressing: 91.89 %
# Currently Running: HOUSEHOLD_1_446_CA_4
# Progressing: 91.93 %
# Currently Running: HOUSEHOLD_1_447_CA_4
# Progressing: 91.97 %
# Currently Running: HOUSEHOLD_1_448_CA_4
# Progressing: 92.01 %
# Currently Running: HOUSEHOLD_1_450_CA_4
# Progressing: 92.05 %
# Currently Running: HOUSEHOLD_1_451_CA_4
# Progressing: 92.1 %
# Currently Running: HOUSEHOLD_1_452_CA_4
# Progressing: 92.14 %
# Currently Running: HOUSEHOLD_1_453_CA_4
# Progressing: 92.18 %
# Currently Running: HOUSEHOLD_1_455_CA_4
# Progressing: 92.22 %
# Currently Running: HOUSEHOLD_1_456_CA_4
# Progressing: 92.26 %
# Currently Running: HOUSEHOLD_1_457_CA_4
# Progressing: 92.3 %
# Currently Running: HOUSEHOLD_1_458_CA_4
# Progressing: 92.35 %
# Currently Running: HOUSEHOLD_1_459_CA_4
# Progressing: 92.39 %
# Currently Running: HOUSEHOLD_1_465_CA_4
# Progressing: 92.43 %
# Currently Running: HOUSEHOLD_1_466_CA_4
# Progressing: 92.47 %
# Currently Running: HOUSEHOLD_1_467_CA_4
# Progressing: 92.51 %
# Currently Running: HOUSEHOLD_1_468_CA_4
# Progressing: 92.56 %
# Currently Running: HOUSEHOLD_1_469_CA_4
# Progressing: 92.6 %
# Currently Running: HOUSEHOLD_1_471_CA_4
# Progressing: 92.64 %
# Currently Running: HOUSEHOLD_1_472_CA_4
# Progressing: 92.68 %
# Currently Running: HOUSEHOLD_1_473_CA_4
# Progressing: 92.72 %
# Currently Running: HOUSEHOLD_1_474_CA_4
# Progressing: 92.76 %
# Currently Running: HOUSEHOLD_1_475_CA_4
# Progressing: 92.81 %
# Currently Running: HOUSEHOLD_1_478_CA_4
# Progressing: 92.85 %
# Currently Running: HOUSEHOLD_1_479_CA_4
# Progressing: 92.89 %
# Currently Running: HOUSEHOLD_1_480_CA_4
# Progressing: 92.93 %
# Currently Running: HOUSEHOLD_1_481_CA_4
# Progressing: 92.97 %
# Currently Running: HOUSEHOLD_1_482_CA_4
# Progressing: 93.02 %
# Currently Running: HOUSEHOLD_1_485_CA_4
# Progressing: 93.06 %
# Currently Running: HOUSEHOLD_1_486_CA_4
# Progressing: 93.1 %
# Currently Running: HOUSEHOLD_1_488_CA_4
# Progressing: 93.14 %
# Currently Running: HOUSEHOLD_1_489_CA_4
# Progressing: 93.18 %
# Currently Running: HOUSEHOLD_1_490_CA_4
# Progressing: 93.22 %
# Currently Running: HOUSEHOLD_1_491_CA_4
# Progressing: 93.27 %
# Currently Running: HOUSEHOLD_1_492_CA_4
# Progressing: 93.31 %
# Currently Running: HOUSEHOLD_1_493_CA_4
# Progressing: 93.35 %
# Currently Running: HOUSEHOLD_1_494_CA_4
# Progressing: 93.39 %
# Currently Running: HOUSEHOLD_1_497_CA_4
# Progressing: 93.43 %
# Currently Running: HOUSEHOLD_1_498_CA_4
# Progressing: 93.48 %
# Currently Running: HOUSEHOLD_1_499_CA_4
# Progressing: 93.52 %
# Currently Running: HOUSEHOLD_1_500_CA_4
# Progressing: 93.56 %
# Currently Running: HOUSEHOLD_1_503_CA_4
# Progressing: 93.6 %
# Currently Running: HOUSEHOLD_1_505_CA_4
# Progressing: 93.64 %
# Currently Running: HOUSEHOLD_1_507_CA_4
# Progressing: 93.68 %
# Currently Running: HOUSEHOLD_1_510_CA_4
# Progressing: 93.73 %
# Currently Running: HOUSEHOLD_1_511_CA_4
# Progressing: 93.77 %
# Currently Running: HOUSEHOLD_1_514_CA_4
# Progressing: 93.81 %
# Currently Running: HOUSEHOLD_1_515_CA_4
# Progressing: 93.85 %
# Currently Running: HOUSEHOLD_1_516_CA_4
# Progressing: 93.89 %
# Currently Running: HOUSEHOLD_1_517_CA_4
# Progressing: 93.94 %
# Currently Running: HOUSEHOLD_1_518_CA_4
# Progressing: 93.98 %
# Currently Running: HOUSEHOLD_1_519_CA_4
# Progressing: 94.02 %
# Currently Running: HOUSEHOLD_1_520_CA_4
# Progressing: 94.06 %
# Currently Running: HOUSEHOLD_1_521_CA_4
# Progressing: 94.1 %
# Currently Running: HOUSEHOLD_1_522_CA_4
# Progressing: 94.14 %
# Currently Running: HOUSEHOLD_1_524_CA_4
# Progressing: 94.19 %
# Currently Running: HOUSEHOLD_1_527_CA_4
# Progressing: 94.23 %
# Currently Running: HOUSEHOLD_1_528_CA_4
# Progressing: 94.27 %
# Currently Running: HOUSEHOLD_1_529_CA_4
# Progressing: 94.31 %
# Currently Running: HOUSEHOLD_1_530_CA_4
# Progressing: 94.35 %
# Currently Running: HOUSEHOLD_1_531_CA_4
# Progressing: 94.4 %
# Currently Running: HOUSEHOLD_1_534_CA_4
# Progressing: 94.44 %
# Currently Running: HOUSEHOLD_1_535_CA_4
# Progressing: 94.48 %
# Currently Running: HOUSEHOLD_1_536_CA_4
# Progressing: 94.52 %
# Currently Running: HOUSEHOLD_1_538_CA_4
# Progressing: 94.56 %
# Currently Running: HOUSEHOLD_1_539_CA_4
# Progressing: 94.6 %
# Currently Running: HOUSEHOLD_1_540_CA_4
# Progressing: 94.65 %
# Currently Running: HOUSEHOLD_1_541_CA_4
# Progressing: 94.69 %
# Currently Running: HOUSEHOLD_2_002_CA_4
# Progressing: 94.73 %
# Currently Running: HOUSEHOLD_2_011_CA_4
# Progressing: 94.77 %
# Currently Running: HOUSEHOLD_2_024_CA_4
# Progressing: 94.81 %
# Currently Running: HOUSEHOLD_2_036_CA_4
# Progressing: 94.86 %
# Currently Running: HOUSEHOLD_2_037_CA_4
# Progressing: 94.9 %
# Currently Running: HOUSEHOLD_2_044_CA_4
# Progressing: 94.94 %
# Currently Running: HOUSEHOLD_2_047_CA_4
# Progressing: 94.98 %
# Currently Running: HOUSEHOLD_2_049_CA_4
# Progressing: 95.02 %
# Currently Running: HOUSEHOLD_2_050_CA_4
# Progressing: 95.06 %
# Currently Running: HOUSEHOLD_2_054_CA_4
# Progressing: 95.11 %
# Currently Running: HOUSEHOLD_2_059_CA_4
# Progressing: 95.15 %
# Currently Running: HOUSEHOLD_2_064_CA_4
# Progressing: 95.19 %
# Currently Running: HOUSEHOLD_2_070_CA_4
# Progressing: 95.23 %
# Currently Running: HOUSEHOLD_2_072_CA_4
# Progressing: 95.27 %
# Currently Running: HOUSEHOLD_2_074_CA_4
# Progressing: 95.32 %
# Currently Running: HOUSEHOLD_2_075_CA_4
# Progressing: 95.36 %
# Currently Running: HOUSEHOLD_2_076_CA_4
# Progressing: 95.4 %
# Currently Running: HOUSEHOLD_2_081_CA_4
# Progressing: 95.44 %
# Currently Running: HOUSEHOLD_2_084_CA_4
# Progressing: 95.48 %
# Currently Running: HOUSEHOLD_2_096_CA_4
# Progressing: 95.52 %
# Currently Running: HOUSEHOLD_2_102_CA_4
# Progressing: 95.57 %
# Currently Running: HOUSEHOLD_2_110_CA_4
# Progressing: 95.61 %
# Currently Running: HOUSEHOLD_2_113_CA_4
# Progressing: 95.65 %
# Currently Running: HOUSEHOLD_2_118_CA_4
# Progressing: 95.69 %
# Currently Running: HOUSEHOLD_2_119_CA_4
# Progressing: 95.73 %
# Currently Running: HOUSEHOLD_2_123_CA_4
# Progressing: 95.78 %
# Currently Running: HOUSEHOLD_2_135_CA_4
# Progressing: 95.82 %
# Currently Running: HOUSEHOLD_2_136_CA_4
# Progressing: 95.86 %
# Currently Running: HOUSEHOLD_2_140_CA_4
# Progressing: 95.9 %
# Currently Running: HOUSEHOLD_2_142_CA_4
# Progressing: 95.94 %
# Currently Running: HOUSEHOLD_2_159_CA_4
# Progressing: 95.98 %
# Currently Running: HOUSEHOLD_2_160_CA_4
# Progressing: 96.03 %
# Currently Running: HOUSEHOLD_2_172_CA_4
# Progressing: 96.07 %
# Currently Running: HOUSEHOLD_2_176_CA_4
# Progressing: 96.11 %
# Currently Running: HOUSEHOLD_2_183_CA_4
# Progressing: 96.15 %
# Currently Running: HOUSEHOLD_2_184_CA_4
# Progressing: 96.19 %
# Currently Running: HOUSEHOLD_2_191_CA_4
# Progressing: 96.24 %
# Currently Running: HOUSEHOLD_2_196_CA_4
# Progressing: 96.28 %
# Currently Running: HOUSEHOLD_2_197_CA_4
# Progressing: 96.32 %
# Currently Running: HOUSEHOLD_2_199_CA_4
# Progressing: 96.36 %
# Currently Running: HOUSEHOLD_2_201_CA_4
# Progressing: 96.4 %
# Currently Running: HOUSEHOLD_2_212_CA_4
# Progressing: 96.45 %
# Currently Running: HOUSEHOLD_2_213_CA_4
# Progressing: 96.49 %
# Currently Running: HOUSEHOLD_2_217_CA_4
# Progressing: 96.53 %
# Currently Running: HOUSEHOLD_2_219_CA_4
# Progressing: 96.57 %
# Currently Running: HOUSEHOLD_2_222_CA_4
# Progressing: 96.61 %
# Currently Running: HOUSEHOLD_2_228_CA_4
# Progressing: 96.65 %
# Currently Running: HOUSEHOLD_2_246_CA_4
# Progressing: 96.7 %
# Currently Running: HOUSEHOLD_2_248_CA_4
# Progressing: 96.74 %
# Currently Running: HOUSEHOLD_2_250_CA_4
# Progressing: 96.78 %
# Currently Running: HOUSEHOLD_2_262_CA_4
# Progressing: 96.82 %
# Currently Running: HOUSEHOLD_2_264_CA_4
# Progressing: 96.86 %
# Currently Running: HOUSEHOLD_2_265_CA_4
# Progressing: 96.91 %
# Currently Running: HOUSEHOLD_2_277_CA_4
# Progressing: 96.95 %
# Currently Running: HOUSEHOLD_2_284_CA_4
# Progressing: 96.99 %
# Currently Running: HOUSEHOLD_2_286_CA_4
# Progressing: 97.03 %
# Currently Running: HOUSEHOLD_2_288_CA_4
# Progressing: 97.07 %
# Currently Running: HOUSEHOLD_2_294_CA_4
# Progressing: 97.11 %
# Currently Running: HOUSEHOLD_2_295_CA_4
# Progressing: 97.16 %
# Currently Running: HOUSEHOLD_2_297_CA_4
# Progressing: 97.2 %
# Currently Running: HOUSEHOLD_2_298_CA_4
# Progressing: 97.24 %
# Currently Running: HOUSEHOLD_2_299_CA_4
# Progressing: 97.28 %
# Currently Running: HOUSEHOLD_2_308_CA_4
# Progressing: 97.32 %
# Currently Running: HOUSEHOLD_2_310_CA_4
# Progressing: 97.37 %
# Currently Running: HOUSEHOLD_2_312_CA_4
# Progressing: 97.41 %
# Currently Running: HOUSEHOLD_2_313_CA_4
# Progressing: 97.45 %
# Currently Running: HOUSEHOLD_2_319_CA_4
# Progressing: 97.49 %
# Currently Running: HOUSEHOLD_2_322_CA_4
# Progressing: 97.53 %
# Currently Running: HOUSEHOLD_2_325_CA_4
# Progressing: 97.57 %
# Currently Running: HOUSEHOLD_2_329_CA_4
# Progressing: 97.62 %
# Currently Running: HOUSEHOLD_2_335_CA_4
# Progressing: 97.66 %
# Currently Running: HOUSEHOLD_2_336_CA_4
# Progressing: 97.7 %
# Currently Running: HOUSEHOLD_2_338_CA_4
# Progressing: 97.74 %
# Currently Running: HOUSEHOLD_2_341_CA_4
# Progressing: 97.78 %
# Currently Running: HOUSEHOLD_2_342_CA_4
# Progressing: 97.83 %
# Currently Running: HOUSEHOLD_2_343_CA_4
# Progressing: 97.87 %
# Currently Running: HOUSEHOLD_2_348_CA_4
# Progressing: 97.91 %
# Currently Running: HOUSEHOLD_2_349_CA_4
# Progressing: 97.95 %
# Currently Running: HOUSEHOLD_2_350_CA_4
# Progressing: 97.99 %
# Currently Running: HOUSEHOLD_2_354_CA_4
# Progressing: 98.03 %
# Currently Running: HOUSEHOLD_2_359_CA_4
# Progressing: 98.08 %
# Currently Running: HOUSEHOLD_2_366_CA_4
# Progressing: 98.12 %
# Currently Running: HOUSEHOLD_2_368_CA_4
# Progressing: 98.16 %
# Currently Running: HOUSEHOLD_2_369_CA_4
# Progressing: 98.2 %
# Currently Running: HOUSEHOLD_2_371_CA_4
# Progressing: 98.24 %
# Currently Running: HOUSEHOLD_2_374_CA_4
# Progressing: 98.29 %
# Currently Running: HOUSEHOLD_2_375_CA_4
# Progressing: 98.33 %
# Currently Running: HOUSEHOLD_2_376_CA_4
# Progressing: 98.37 %
# Currently Running: HOUSEHOLD_2_382_CA_4
# Progressing: 98.41 %
# Currently Running: HOUSEHOLD_2_388_CA_4
# Progressing: 98.45 %
# Currently Running: HOUSEHOLD_2_389_CA_4
# Progressing: 98.49 %
# Currently Running: HOUSEHOLD_2_395_CA_4
# Progressing: 98.54 %
# Currently Running: HOUSEHOLD_2_402_CA_4
# Progressing: 98.58 %
# Currently Running: HOUSEHOLD_2_403_CA_4
# Progressing: 98.62 %
# Currently Running: HOUSEHOLD_2_404_CA_4
# Progressing: 98.66 %
# Currently Running: HOUSEHOLD_2_409_CA_4
# Progressing: 98.7 %
# Currently Running: HOUSEHOLD_2_410_CA_4
# Progressing: 98.75 %
# Currently Running: HOUSEHOLD_2_411_CA_4
# Progressing: 98.79 %
# Currently Running: HOUSEHOLD_2_421_CA_4
# Progressing: 98.83 %
# Currently Running: HOUSEHOLD_2_423_CA_4
# Progressing: 98.87 %
# Currently Running: HOUSEHOLD_2_424_CA_4
# Progressing: 98.91 %
# Currently Running: HOUSEHOLD_2_426_CA_4
# Progressing: 98.95 %
# Currently Running: HOUSEHOLD_2_427_CA_4
# Progressing: 99.0 %
# Currently Running: HOUSEHOLD_2_437_CA_4
# Progressing: 99.04 %
# Currently Running: HOUSEHOLD_2_440_CA_4
# Progressing: 99.08 %
# Currently Running: HOUSEHOLD_2_442_CA_4
# Progressing: 99.12 %
# Currently Running: HOUSEHOLD_2_443_CA_4
# Progressing: 99.16 %
# Currently Running: HOUSEHOLD_2_450_CA_4
# Progressing: 99.21 %
# Currently Running: HOUSEHOLD_2_451_CA_4
# Progressing: 99.25 %
# Currently Running: HOUSEHOLD_2_453_CA_4
# Progressing: 99.29 %
# Currently Running: HOUSEHOLD_2_467_CA_4
# Progressing: 99.33 %
# Currently Running: HOUSEHOLD_2_468_CA_4
# Progressing: 99.37 %
# Currently Running: HOUSEHOLD_2_470_CA_4
# Progressing: 99.41 %
# Currently Running: HOUSEHOLD_2_483_CA_4
# Progressing: 99.46 %
# Currently Running: HOUSEHOLD_2_485_CA_4
# Progressing: 99.5 %
# Currently Running: HOUSEHOLD_2_486_CA_4
# Progressing: 99.54 %
# Currently Running: HOUSEHOLD_2_490_CA_4
# Progressing: 99.58 %
# Currently Running: HOUSEHOLD_2_492_CA_4
# Progressing: 99.62 %
# Currently Running: HOUSEHOLD_2_493_CA_4
# Progressing: 99.67 %
# Currently Running: HOUSEHOLD_2_496_CA_4
# Progressing: 99.71 %
# Currently Running: HOUSEHOLD_2_499_CA_4
# Progressing: 99.75 %
# Currently Running: HOUSEHOLD_2_500_CA_4
# Progressing: 99.79 %
# Currently Running: HOUSEHOLD_2_505_CA_4
# Progressing: 99.83 %
# Currently Running: HOUSEHOLD_2_510_CA_4
# Progressing: 99.87 %
# Currently Running: HOUSEHOLD_2_511_CA_4
# Progressing: 99.92 %
# Currently Running: HOUSEHOLD_2_513_CA_4
# Progressing: 99.96 %
# This line of code took 8.219814602116655 minutes

# %%
df_output_rf_pattern
# Out:
#           Actual Data   Forecast               Product
# wm_yr_wk
# 11611             4.0   7.013193  HOUSEHOLD_1_003_CA_1
# 11612             2.0   6.905300  HOUSEHOLD_1_003_CA_1
# 11611             7.0  11.434510  HOUSEHOLD_1_004_CA_1
# 11612             9.0  10.358452  HOUSEHOLD_1_004_CA_1
# 11611             9.0   8.122895  HOUSEHOLD_1_005_CA_1
# ...               ...        ...                   ...
# 11612             1.0   2.573649  HOUSEHOLD_2_510_CA_4
# 11611             6.0   3.465943  HOUSEHOLD_2_511_CA_4
# 11612             3.0   3.196089  HOUSEHOLD_2_511_CA_4
# 11611             0.0   2.183538  HOUSEHOLD_2_513_CA_4
# 11612             0.0   1.825829  HOUSEHOLD_2_513_CA_4
#
# [4782 rows x 3 columns]

# %%
df_output_rf_pattern.to_csv('Smooth_Random_Forest_Forecast_Values.csv')

# %%
# User-defined funcion to calculate metrics

def get_metrics_result_all_params(data):
    metrics_df = {}
    metrics_df['MASE'] = mase_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['WMAPE'] = wmape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['SMAPE'] = smape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAPE'] = mape_calculation(data['Actual Data'], data['Forecast'])
    metrics_df['MAE'] = mean_absolute_error(data['Actual Data'], data['Forecast'])
    metrics_df['RMSE'] = np.sqrt(mean_squared_error(data['Actual Data'], data['Forecast']))
    return pd.Series(metrics_df)

# %%
# Start calculating metrics 
start = timer()

df_forecast_metrics = df_output_rf_pattern.groupby('Product').apply(get_metrics_result_all_params).reset_index()

end = timer()
print('This line of code took {} minutes'.format((end-start) / 60))
# Out:
# This line of code took 0.08883902199998678 minutes

# %%
df_forecast_metrics
# Out:
#                    Product      MASE     WMAPE     SMAPE      MAPE       MAE  \
# 0     HOUSEHOLD_1_001_CA_3  0.465810   18.6324   18.9099   21.4764  0.931619
# 1     HOUSEHOLD_1_002_CA_3  0.913400   78.2915   63.1246  111.3816  2.740201
# 2     HOUSEHOLD_1_002_CA_4  0.543723  108.7447  124.0188   38.7342  2.174894
# 3     HOUSEHOLD_1_003_CA_1  1.979623  131.9749   82.4428  160.2974  3.959247
# 4     HOUSEHOLD_1_003_CA_2       inf  156.9357   87.8122  156.9357  4.708072
# ...                    ...       ...       ...       ...       ...       ...
# 2386  HOUSEHOLD_2_512_CA_2  0.865685   14.4281   15.1761   13.8155  1.731369
# 2387  HOUSEHOLD_2_512_CA_3  0.481689   52.5479   56.0401   49.6400  5.780274
# 2388  HOUSEHOLD_2_513_CA_3  0.425998   52.9619   55.3148   47.2908  9.797951
# 2389  HOUSEHOLD_2_513_CA_4       inf       inf  200.0000       NaN  2.004684
# 2390  HOUSEHOLD_2_514_CA_1  1.155439  231.0879  118.5921   45.6763  1.155439
#
#            RMSE
# 0      1.055538
# 1      2.927965
# 2      2.263062
# 3      4.070706
# 4      4.721381
# ...         ...
# 2386   2.009594
# 2387   6.791140
# 2388  12.115389
# 2389   2.012646
# 2390   1.350255
#
# [2391 rows x 7 columns]

# %%
df_forecast_metrics.to_csv('Random_Forest_Smooth_Forecast_Metrics.csv')
